# %% [markdown]
# From: https://github.com/Quorumetrix/Blender_scripts/blob/main/Mesh%20Decimation%20Pipeline.ipynb

# %%
import pandas as pd
import numpy as np
import os
import time
import h5py
import pyvista as pv

# %%
celltypes = pd.read_csv("data/220309_cell_type_classification.csv", index_col=[0])
vasc = celltypes[celltypes.cell_type == 'vasculature']
vasc_list = vasc.cell_segid.to_list()
# vasc_list

# %%
# import pandas as pd
# import numpy as np
# import os
# import time
# import h5py
# import pyvista as pv

# Set up paths and parameters
obj_path = 'data/neuron_meshes_v185/'
dec_prcnt = 95
dec_path = 'data/neuron_meshes_v185/dec/'

# Load cellids into a list
celltypes = pd.read_csv("data/220309_cell_type_classification.csv", index_col=[0])
vasc = celltypes[celltypes.cell_type == 'vasculature']
vasc_list = vasc.cell_segid.to_list()

def read_h5_file(file_path):
    with h5py.File(file_path, 'r') as f:
        vertices = np.array(f['vertices'])
        faces = np.array(f['faces'])
    return vertices, faces

def create_pyvista_mesh(vertices, faces):
    # PyVista expects faces to be in the format (n, v1, v2, v3, ...)
    faces_with_size = np.hstack([np.full((faces.shape[0], 1), faces.shape[1]), faces])
    return pv.PolyData(vertices, faces_with_size)

def process_obj(cellid, dec_prcnt, obj_path, dec_path):
    start_time = time.time()
    
    # Create the full path to the file
    file_path = os.path.join(obj_path, str(cellid) + '.h5')
    print(f"Loading {file_path}")
    
    # Load the file
    vertices, faces = read_h5_file(file_path)
    load_time = time.time()
    print(f"Loaded {file_path} in {load_time - start_time:.2f} seconds")
    
    # Create PyVista mesh
    mesh = create_pyvista_mesh(vertices, faces)
    print(f"Original mesh info: {mesh}")
    
    # Perform decimation
    print(f"Decimating {file_path} by {dec_prcnt}%")
    simplified_mesh = mesh.decimate(target_reduction=dec_prcnt / 100)  # Reduce to x% of the original mesh
    decimate_time = time.time()
    print(f"Decimated {file_path} in {decimate_time - load_time:.2f} seconds")
    
    # Print simplified mesh information
    print(f"Simplified mesh info: {simplified_mesh}")
    
    # Ensure the output directory exists
    if not os.path.exists(dec_path):
        os.makedirs(dec_path)
    
    # Save the simplified mesh in PLY format
    output_filename = os.path.basename(file_path).replace('.h5', '.ply')
    output_path = os.path.join(dec_path, output_filename)
    
    try:
        simplified_mesh.save(output_path)
        save_time = time.time()
        print(f"Saved {output_path} in {save_time - decimate_time:.2f} seconds")
    except Exception as e:
        print(f"Error saving {output_path}: {e}")
    
    total_time = time.time() - start_time
    print(f"Total time: {total_time // 60} minutes and {total_time % 60:.2f} seconds")

# Process each cellid in the astro_list
for cellid in vasc_list:
    process_obj(cellid, dec_prcnt, obj_path, dec_path)
# Out:
# Loading data/neuron_meshes_v185/648518346342804483.h5
# Loaded data/neuron_meshes_v185/648518346342804483.h5 in 0.03 seconds
# Original mesh info: PolyData (0x1c9edb1e948)
#   N Cells:	79652
#   N Points:	39788
#   N Strips:	0
#   X Bounds:	4.512e+05, 4.657e+05
#   Y Bounds:	2.510e+05, 2.987e+05
#   Z Bounds:	8.158e+02, 7.380e+03
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346342804483.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346342804483.h5 in 0.39 seconds
# Simplified mesh info: PolyData (0x1c9edb98588)
#   N Cells:	3981
#   N Points:	1975
#   N Strips:	0
#   X Bounds:	4.512e+05, 4.656e+05
#   Y Bounds:	2.511e+05, 2.987e+05
#   Z Bounds:	8.198e+02, 7.380e+03
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346342804483.ply in 0.01 seconds
# Total time: 0.0 minutes and 0.42 seconds
# Loading data/neuron_meshes_v185/648518346341422370.h5
# Loaded data/neuron_meshes_v185/648518346341422370.h5 in 0.00 seconds
# Original mesh info: PolyData (0x1c9edb98588)
#   N Cells:	320
#   N Points:	162
#   N Strips:	0
#   X Bounds:	1.780e+05, 1.815e+05
#   Y Bounds:	2.858e+05, 2.893e+05
#   Z Bounds:	3.695e+03, 3.782e+03
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346341422370.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346341422370.h5 in 0.00 seconds
# Simplified mesh info: PolyData (0x1c9edb98408)
#   N Cells:	15
#   N Points:	12
#   N Strips:	0
#   X Bounds:	1.781e+05, 1.815e+05
#   Y Bounds:	2.864e+05, 2.892e+05
#   Z Bounds:	3.701e+03, 3.779e+03
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346341422370.ply in 0.00 seconds
# Total time: 0.0 minutes and 0.01 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.86 seconds
# Original mesh info: PolyData (0x1c9edb98408)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 179.85 seconds
# Simplified mesh info: PolyData (0x1c9edb982e8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.80 seconds
# Total time: 3.0 minutes and 2.50 seconds
# Loading data/neuron_meshes_v185/648518346349375478.h5
# Loaded data/neuron_meshes_v185/648518346349375478.h5 in 0.12 seconds
# Original mesh info: PolyData (0x1c9edb98408)
#   N Cells:	553842
#   N Points:	276473
#   N Strips:	0
#   X Bounds:	3.839e+05, 4.559e+05
#   Y Bounds:	1.521e+05, 1.917e+05
#   Z Bounds:	4.370e+04, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349375478.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349375478.h5 in 4.76 seconds
# Simplified mesh info: PolyData (0x1c9edb985e8)
#   N Cells:	27691
#   N Points:	13754
#   N Strips:	0
#   X Bounds:	3.839e+05, 4.555e+05
#   Y Bounds:	1.521e+05, 1.917e+05
#   Z Bounds:	4.370e+04, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349375478.ply in 0.03 seconds
# Total time: 0.0 minutes and 4.91 seconds
# Loading data/neuron_meshes_v185/648518346343497543.h5
# Loaded data/neuron_meshes_v185/648518346343497543.h5 in 0.01 seconds
# Original mesh info: PolyData (0x1c9edb98408)
#   N Cells:	14434
#   N Points:	7215
#   N Strips:	0
#   X Bounds:	1.742e+05, 1.823e+05
#   Y Bounds:	2.647e+05, 2.911e+05
#   Z Bounds:	3.936e+03, 4.549e+03
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346343497543.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346343497543.h5 in 0.06 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	721
#   N Points:	363
#   N Strips:	0
#   X Bounds:	1.742e+05, 1.822e+05
#   Y Bounds:	2.646e+05, 2.910e+05
#   Z Bounds:	3.934e+03, 4.547e+03
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346343497543.ply in 0.00 seconds
# Total time: 0.0 minutes and 0.07 seconds
# Loading data/neuron_meshes_v185/648518346348189552.h5
# Loaded data/neuron_meshes_v185/648518346348189552.h5 in 0.13 seconds
# Original mesh info: PolyData (0x1c9edb98108)
#   N Cells:	927936
#   N Points:	463456
#   N Strips:	0
#   X Bounds:	4.275e+05, 4.749e+05
#   Y Bounds:	1.574e+05, 2.370e+05
#   Z Bounds:	4.813e+04, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346348189552.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346348189552.h5 in 8.08 seconds
# Simplified mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	46396
#   N Points:	23451
#   N Strips:	0
#   X Bounds:	4.275e+05, 4.749e+05
#   Y Bounds:	1.574e+05, 2.365e+05
#   Z Bounds:	4.814e+04, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346348189552.ply in 0.06 seconds
# Total time: 0.0 minutes and 8.27 seconds
# Loading data/neuron_meshes_v185/648518346344072053.h5
# Loaded data/neuron_meshes_v185/648518346344072053.h5 in 0.01 seconds
# Original mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	24192
#   N Points:	12102
#   N Strips:	0
#   X Bounds:	4.198e+05, 4.289e+05
#   Y Bounds:	2.928e+05, 3.069e+05
#   Z Bounds:	8.042e+02, 2.703e+03
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346344072053.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346344072053.h5 in 0.10 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	1208
#   N Points:	609
#   N Strips:	0
#   X Bounds:	4.198e+05, 4.288e+05
#   Y Bounds:	2.928e+05, 3.069e+05
#   Z Bounds:	8.194e+02, 2.701e+03
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346344072053.ply in 0.00 seconds
# Total time: 0.0 minutes and 0.11 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.98 seconds
# Original mesh info: PolyData (0x1c9edb98108)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 189.91 seconds
# Simplified mesh info: PolyData (0x1c9edb98228)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.80 seconds
# Total time: 3.0 minutes and 12.69 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.05 seconds
# Original mesh info: PolyData (0x1c9edb98108)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 194.36 seconds
# Simplified mesh info: PolyData (0x1c9edb98d08)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.76 seconds
# Total time: 3.0 minutes and 17.17 seconds
# Loading data/neuron_meshes_v185/648518346348121670.h5
# Loaded data/neuron_meshes_v185/648518346348121670.h5 in 0.25 seconds
# Original mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	1308228
#   N Points:	653834
#   N Strips:	0
#   X Bounds:	4.119e+05, 4.568e+05
#   Y Bounds:	1.768e+05, 2.410e+05
#   Z Bounds:	8.067e+02, 4.075e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346348121670.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346348121670.h5 in 12.34 seconds
# Simplified mesh info: PolyData (0x1c9edb98c48)
#   N Cells:	65411
#   N Points:	32382
#   N Strips:	0
#   X Bounds:	4.120e+05, 4.568e+05
#   Y Bounds:	1.768e+05, 2.410e+05
#   Z Bounds:	8.106e+02, 4.070e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346348121670.ply in 0.06 seconds
# Total time: 0.0 minutes and 12.65 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.12 seconds
# Original mesh info: PolyData (0x1c9edb98c48)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 183.80 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.73 seconds
# Total time: 3.0 minutes and 6.65 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.21 seconds
# Original mesh info: PolyData (0x1c9edb98c48)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 183.76 seconds
# Simplified mesh info: PolyData (0x1c9edb98228)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.78 seconds
# Total time: 3.0 minutes and 6.75 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.02 seconds
# Original mesh info: PolyData (0x1c9edb98c48)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 188.31 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.70 seconds
# Total time: 3.0 minutes and 11.03 seconds
# Loading data/neuron_meshes_v185/648518346344328018.h5
# Loaded data/neuron_meshes_v185/648518346344328018.h5 in 0.03 seconds
# Original mesh info: PolyData (0x1c9edb98708)
#   N Cells:	56130
#   N Points:	28009
#   N Strips:	0
#   X Bounds:	1.866e+05, 1.962e+05
#   Y Bounds:	2.047e+05, 2.206e+05
#   Z Bounds:	7.310e+04, 7.955e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346344328018.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346344328018.h5 in 0.30 seconds
# Simplified mesh info: PolyData (0x1c9edb7d9a8)
#   N Cells:	2806
#   N Points:	1392
#   N Strips:	0
#   X Bounds:	1.866e+05, 1.961e+05
#   Y Bounds:	2.047e+05, 2.205e+05
#   Z Bounds:	7.310e+04, 7.954e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346344328018.ply in 0.02 seconds
# Total time: 0.0 minutes and 0.35 seconds
# Loading data/neuron_meshes_v185/648518346344456391.h5
# Loaded data/neuron_meshes_v185/648518346344456391.h5 in 0.01 seconds
# Original mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	2504
#   N Points:	1254
#   N Strips:	0
#   X Bounds:	1.905e+05, 1.964e+05
#   Y Bounds:	1.919e+05, 2.019e+05
#   Z Bounds:	8.590e+04, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346344456391.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346344456391.h5 in 0.01 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	124
#   N Points:	64
#   N Strips:	0
#   X Bounds:	1.904e+05, 1.964e+05
#   Y Bounds:	1.920e+05, 2.018e+05
#   Z Bounds:	8.590e+04, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346344456391.ply in 0.00 seconds
# Total time: 0.0 minutes and 0.02 seconds
# Loading data/neuron_meshes_v185/648518346344505300.h5
# Loaded data/neuron_meshes_v185/648518346344505300.h5 in 0.01 seconds
# Original mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	8568
#   N Points:	4280
#   N Strips:	0
#   X Bounds:	1.886e+05, 2.022e+05
#   Y Bounds:	2.000e+05, 2.125e+05
#   Z Bounds:	8.590e+04, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346344505300.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346344505300.h5 in 0.03 seconds
# Simplified mesh info: PolyData (0x1c9edb98d08)
#   N Cells:	427
#   N Points:	214
#   N Strips:	0
#   X Bounds:	1.887e+05, 2.022e+05
#   Y Bounds:	2.001e+05, 2.124e+05
#   Z Bounds:	8.590e+04, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346344505300.ply in 0.00 seconds
# Total time: 0.0 minutes and 0.04 seconds
# Loading data/neuron_meshes_v185/648518346341763956.h5
# Loaded data/neuron_meshes_v185/648518346341763956.h5 in 0.00 seconds
# Original mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	748
#   N Points:	376
#   N Strips:	0
#   X Bounds:	2.545e+05, 2.603e+05
#   Y Bounds:	2.955e+05, 2.967e+05
#   Z Bounds:	1.282e+04, 1.311e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346341763956.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346341763956.h5 in 0.00 seconds
# Simplified mesh info: PolyData (0x1c9edb98408)
#   N Cells:	37
#   N Points:	23
#   N Strips:	0
#   X Bounds:	2.545e+05, 2.602e+05
#   Y Bounds:	2.956e+05, 2.967e+05
#   Z Bounds:	1.282e+04, 1.306e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346341763956.ply in 0.00 seconds
# Total time: 0.0 minutes and 0.01 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.14 seconds
# Original mesh info: PolyData (0x1c9edb98408)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 178.84 seconds
# Simplified mesh info: PolyData (0x1c9edb982e8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.67 seconds
# Total time: 3.0 minutes and 1.65 seconds
# Loading data/neuron_meshes_v185/648518346345118988.h5
# Loaded data/neuron_meshes_v185/648518346345118988.h5 in 0.01 seconds
# Original mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	92
#   N Points:	48
#   N Strips:	0
#   X Bounds:	2.071e+05, 2.076e+05
#   Y Bounds:	1.941e+05, 1.945e+05
#   Z Bounds:	2.358e+04, 2.387e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346345118988.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346345118988.h5 in 0.01 seconds
# Simplified mesh info: PolyData (0x1c9edb98408)
#   N Cells:	2
#   N Points:	4
#   N Strips:	0
#   X Bounds:	2.072e+05, 2.076e+05
#   Y Bounds:	1.941e+05, 1.944e+05
#   Z Bounds:	2.361e+04, 2.385e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346345118988.ply in 0.00 seconds
# Total time: 0.0 minutes and 0.02 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.13 seconds
# Original mesh info: PolyData (0x1c9edb1e948)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 174.14 seconds
# Simplified mesh info: PolyData (0x1c9edb98d08)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.73 seconds
# Total time: 2.0 minutes and 57.01 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.16 seconds
# Original mesh info: PolyData (0x1c9edb98408)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 176.00 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.75 seconds
# Total time: 2.0 minutes and 58.92 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.11 seconds
# Original mesh info: PolyData (0x1c9edb98108)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 186.08 seconds
# Simplified mesh info: PolyData (0x1c9edb98228)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.75 seconds
# Total time: 3.0 minutes and 8.94 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.93 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 179.49 seconds
# Simplified mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.71 seconds
# Total time: 3.0 minutes and 2.13 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.93 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 178.35 seconds
# Simplified mesh info: PolyData (0x1c9edb98408)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.73 seconds
# Total time: 3.0 minutes and 1.01 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.98 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 179.33 seconds
# Simplified mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.72 seconds
# Total time: 3.0 minutes and 2.02 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.14 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 178.18 seconds
# Simplified mesh info: PolyData (0x1c9edb982e8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.68 seconds
# Total time: 3.0 minutes and 1.00 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.07 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 179.86 seconds
# Simplified mesh info: PolyData (0x1c9edb98d08)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.77 seconds
# Total time: 3.0 minutes and 2.69 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.22 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 179.42 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.74 seconds
# Total time: 3.0 minutes and 2.38 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.33 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 180.06 seconds
# Simplified mesh info: PolyData (0x1c9edb983a8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.75 seconds
# Total time: 3.0 minutes and 3.14 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.21 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 182.30 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.74 seconds
# Total time: 3.0 minutes and 5.25 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.07 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 186.55 seconds
# Simplified mesh info: PolyData (0x1c9edb986a8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.84 seconds
# Total time: 3.0 minutes and 9.46 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.92 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 193.79 seconds
# Simplified mesh info: PolyData (0x1c9edb983a8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.79 seconds
# Total time: 3.0 minutes and 16.50 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.09 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 194.37 seconds
# Simplified mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.70 seconds
# Total time: 3.0 minutes and 17.16 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.52 seconds
# Original mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 195.24 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.76 seconds
# Total time: 3.0 minutes and 18.53 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.36 seconds
# Original mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 193.77 seconds
# Simplified mesh info: PolyData (0x1c9edb983a8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.81 seconds
# Total time: 3.0 minutes and 16.94 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.48 seconds
# Original mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 186.67 seconds
# Simplified mesh info: PolyData (0x1c9edb98d08)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.76 seconds
# Total time: 3.0 minutes and 9.92 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.32 seconds
# Original mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 184.42 seconds
# Simplified mesh info: PolyData (0x1c9edb98d68)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.66 seconds
# Total time: 3.0 minutes and 7.39 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.13 seconds
# Original mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 180.21 seconds
# Simplified mesh info: PolyData (0x1c9edb985e8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.83 seconds
# Total time: 3.0 minutes and 3.17 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.93 seconds
# Original mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 184.34 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.82 seconds
# Total time: 3.0 minutes and 7.09 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.88 seconds
# Original mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 195.95 seconds
# Simplified mesh info: PolyData (0x1c9edb1e948)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.75 seconds
# Total time: 3.0 minutes and 18.58 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.06 seconds
# Original mesh info: PolyData (0x1c9edb98d68)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 191.35 seconds
# Simplified mesh info: PolyData (0x1c9edb983a8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.78 seconds
# Total time: 3.0 minutes and 14.20 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.11 seconds
# Original mesh info: PolyData (0x1c9edb98d68)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 183.06 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.80 seconds
# Total time: 3.0 minutes and 5.97 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.51 seconds
# Original mesh info: PolyData (0x1c9edb98d68)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 189.08 seconds
# Simplified mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.78 seconds
# Total time: 3.0 minutes and 12.37 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.17 seconds
# Original mesh info: PolyData (0x1c9edb98d68)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 188.64 seconds
# Simplified mesh info: PolyData (0x1c9edb98588)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.78 seconds
# Total time: 3.0 minutes and 11.60 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.30 seconds
# Original mesh info: PolyData (0x1c9edb98d68)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 183.94 seconds
# Simplified mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.68 seconds
# Total time: 3.0 minutes and 6.92 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.16 seconds
# Original mesh info: PolyData (0x1c9edb98d68)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 177.67 seconds
# Simplified mesh info: PolyData (0x1c9edb98d08)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.72 seconds
# Total time: 3.0 minutes and 0.56 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.31 seconds
# Original mesh info: PolyData (0x1c9edb98d08)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 177.70 seconds
# Simplified mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.69 seconds
# Total time: 3.0 minutes and 0.70 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.83 seconds
# Original mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 178.14 seconds
# Simplified mesh info: PolyData (0x1c9edb983a8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.74 seconds
# Total time: 3.0 minutes and 0.72 seconds
# Loading data/neuron_meshes_v185/648518346342104735.h5
# Loaded data/neuron_meshes_v185/648518346342104735.h5 in 0.04 seconds
# Original mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	63416
#   N Points:	31562
#   N Strips:	0
#   X Bounds:	3.213e+05, 3.445e+05
#   Y Bounds:	2.955e+05, 3.064e+05
#   Z Bounds:	6.809e+04, 7.616e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346342104735.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346342104735.h5 in 0.29 seconds
# Simplified mesh info: PolyData (0x1c9edb983a8)
#   N Cells:	3168
#   N Points:	1556
#   N Strips:	0
#   X Bounds:	3.214e+05, 3.443e+05
#   Y Bounds:	2.955e+05, 3.064e+05
#   Z Bounds:	6.844e+04, 7.615e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346342104735.ply in 0.01 seconds
# Total time: 0.0 minutes and 0.33 seconds
# Loading data/neuron_meshes_v185/648518346343459827.h5
# Loaded data/neuron_meshes_v185/648518346343459827.h5 in 0.02 seconds
# Original mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	75686
#   N Points:	37827
#   N Strips:	0
#   X Bounds:	1.922e+05, 2.023e+05
#   Y Bounds:	2.762e+05, 2.937e+05
#   Z Bounds:	4.278e+04, 4.962e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346343459827.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346343459827.h5 in 0.43 seconds
# Simplified mesh info: PolyData (0x1c9edb1eca8)
#   N Cells:	3783
#   N Points:	1883
#   N Strips:	0
#   X Bounds:	1.922e+05, 2.023e+05
#   Y Bounds:	2.762e+05, 2.937e+05
#   Z Bounds:	4.278e+04, 4.962e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346343459827.ply in 0.01 seconds
# Total time: 0.0 minutes and 0.46 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.94 seconds
# Original mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 178.64 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.73 seconds
# Total time: 3.0 minutes and 1.31 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.94 seconds
# Original mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 178.40 seconds
# Simplified mesh info: PolyData (0x1c9edb983a8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.67 seconds
# Total time: 3.0 minutes and 1.01 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.18 seconds
# Original mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 178.02 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.68 seconds
# Total time: 3.0 minutes and 0.88 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.16 seconds
# Original mesh info: PolyData (0x1c9edb98408)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 178.62 seconds
# Simplified mesh info: PolyData (0x1c9edb986a8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.70 seconds
# Total time: 3.0 minutes and 1.48 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.21 seconds
# Original mesh info: PolyData (0x1c9edb98408)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 179.16 seconds
# Simplified mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.67 seconds
# Total time: 3.0 minutes and 2.03 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.33 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 178.48 seconds
# Simplified mesh info: PolyData (0x1c9edb985e8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.68 seconds
# Total time: 3.0 minutes and 1.49 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.23 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 180.21 seconds
# Simplified mesh info: PolyData (0x1c9edb98408)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.81 seconds
# Total time: 3.0 minutes and 3.25 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.85 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 182.90 seconds
# Simplified mesh info: PolyData (0x1c9edb985e8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.66 seconds
# Total time: 3.0 minutes and 5.42 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.94 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 178.28 seconds
# Simplified mesh info: PolyData (0x1c9edb986a8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.77 seconds
# Total time: 3.0 minutes and 0.99 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.95 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 177.59 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.68 seconds
# Total time: 3.0 minutes and 0.23 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 1.96 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 179.02 seconds
# Simplified mesh info: PolyData (0x1c9edb98408)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.69 seconds
# Total time: 3.0 minutes and 1.67 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.17 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 181.77 seconds
# Simplified mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.67 seconds
# Total time: 3.0 minutes and 4.61 seconds
# Loading data/neuron_meshes_v185/648518346342796989.h5
# Loaded data/neuron_meshes_v185/648518346342796989.h5 in 0.08 seconds
# Original mesh info: PolyData (0x1c9edb98228)
#   N Cells:	484422
#   N Points:	241651
#   N Strips:	0
#   X Bounds:	4.082e+05, 4.736e+05
#   Y Bounds:	2.558e+05, 2.748e+05
#   Z Bounds:	3.658e+04, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346342796989.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346342796989.h5 in 3.80 seconds
# Simplified mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	24220
#   N Points:	11906
#   N Strips:	0
#   X Bounds:	4.083e+05, 4.736e+05
#   Y Bounds:	2.559e+05, 2.747e+05
#   Z Bounds:	3.669e+04, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346342796989.ply in 0.02 seconds
# Total time: 0.0 minutes and 3.90 seconds
# Loading data/neuron_meshes_v185/648518346348121670.h5
# Loaded data/neuron_meshes_v185/648518346348121670.h5 in 0.19 seconds
# Original mesh info: PolyData (0x1c9edb980a8)
#   N Cells:	1308228
#   N Points:	653834
#   N Strips:	0
#   X Bounds:	4.119e+05, 4.568e+05
#   Y Bounds:	1.768e+05, 2.410e+05
#   Z Bounds:	8.067e+02, 4.075e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346348121670.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346348121670.h5 in 11.55 seconds
# Simplified mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	65411
#   N Points:	32382
#   N Strips:	0
#   X Bounds:	4.120e+05, 4.568e+05
#   Y Bounds:	1.768e+05, 2.410e+05
#   Z Bounds:	8.106e+02, 4.070e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346348121670.ply in 0.06 seconds
# Total time: 0.0 minutes and 11.80 seconds
# Loading data/neuron_meshes_v185/648518346348121670.h5
# Loaded data/neuron_meshes_v185/648518346348121670.h5 in 0.17 seconds
# Original mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	1308228
#   N Points:	653834
#   N Strips:	0
#   X Bounds:	4.119e+05, 4.568e+05
#   Y Bounds:	1.768e+05, 2.410e+05
#   Z Bounds:	8.067e+02, 4.075e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346348121670.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346348121670.h5 in 11.47 seconds
# Simplified mesh info: PolyData (0x1c9edb98d68)
#   N Cells:	65411
#   N Points:	32382
#   N Strips:	0
#   X Bounds:	4.120e+05, 4.568e+05
#   Y Bounds:	1.768e+05, 2.410e+05
#   Z Bounds:	8.106e+02, 4.070e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346348121670.ply in 0.07 seconds
# Total time: 0.0 minutes and 11.70 seconds
# Loading data/neuron_meshes_v185/648518346348121670.h5
# Loaded data/neuron_meshes_v185/648518346348121670.h5 in 0.17 seconds
# Original mesh info: PolyData (0x1c9edb98d68)
#   N Cells:	1308228
#   N Points:	653834
#   N Strips:	0
#   X Bounds:	4.119e+05, 4.568e+05
#   Y Bounds:	1.768e+05, 2.410e+05
#   Z Bounds:	8.067e+02, 4.075e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346348121670.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346348121670.h5 in 11.57 seconds
# Simplified mesh info: PolyData (0x1c9edb98108)
#   N Cells:	65411
#   N Points:	32382
#   N Strips:	0
#   X Bounds:	4.120e+05, 4.568e+05
#   Y Bounds:	1.768e+05, 2.410e+05
#   Z Bounds:	8.106e+02, 4.070e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346348121670.ply in 0.05 seconds
# Total time: 0.0 minutes and 11.79 seconds
# Loading data/neuron_meshes_v185/648518346348189552.h5
# Loaded data/neuron_meshes_v185/648518346348189552.h5 in 0.14 seconds
# Original mesh info: PolyData (0x1c9edb98108)
#   N Cells:	927936
#   N Points:	463456
#   N Strips:	0
#   X Bounds:	4.275e+05, 4.749e+05
#   Y Bounds:	1.574e+05, 2.370e+05
#   Z Bounds:	4.813e+04, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346348189552.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346348189552.h5 in 7.77 seconds
# Simplified mesh info: PolyData (0x1c9edb986a8)
#   N Cells:	46396
#   N Points:	23451
#   N Strips:	0
#   X Bounds:	4.275e+05, 4.749e+05
#   Y Bounds:	1.574e+05, 2.365e+05
#   Z Bounds:	4.814e+04, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346348189552.ply in 0.04 seconds
# Total time: 0.0 minutes and 7.94 seconds
# Loading data/neuron_meshes_v185/648518346349375478.h5
# Loaded data/neuron_meshes_v185/648518346349375478.h5 in 0.10 seconds
# Original mesh info: PolyData (0x1c9edb98108)
#   N Cells:	553842
#   N Points:	276473
#   N Strips:	0
#   X Bounds:	3.839e+05, 4.559e+05
#   Y Bounds:	1.521e+05, 1.917e+05
#   Z Bounds:	4.370e+04, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349375478.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349375478.h5 in 4.29 seconds
# Simplified mesh info: PolyData (0x1c9edb985e8)
#   N Cells:	27691
#   N Points:	13754
#   N Strips:	0
#   X Bounds:	3.839e+05, 4.555e+05
#   Y Bounds:	1.521e+05, 1.917e+05
#   Z Bounds:	4.370e+04, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349375478.ply in 0.02 seconds
# Total time: 0.0 minutes and 4.41 seconds
# Loading data/neuron_meshes_v185/648518346349061101.h5
# Loaded data/neuron_meshes_v185/648518346349061101.h5 in 0.02 seconds
# Original mesh info: PolyData (0x1c9edb98108)
#   N Cells:	87978
#   N Points:	43793
#   N Strips:	0
#   X Bounds:	4.140e+05, 4.225e+05
#   Y Bounds:	1.575e+05, 1.649e+05
#   Z Bounds:	3.341e+04, 4.322e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349061101.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349061101.h5 in 0.43 seconds
# Simplified mesh info: PolyData (0x1c9edb1eca8)
#   N Cells:	4397
#   N Points:	2145
#   N Strips:	0
#   X Bounds:	4.140e+05, 4.225e+05
#   Y Bounds:	1.575e+05, 1.649e+05
#   Z Bounds:	3.342e+04, 4.322e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349061101.ply in 0.01 seconds
# Total time: 0.0 minutes and 0.46 seconds
# Loading data/neuron_meshes_v185/648518346349375478.h5
# Loaded data/neuron_meshes_v185/648518346349375478.h5 in 0.07 seconds
# Original mesh info: PolyData (0x1c9edb98108)
#   N Cells:	553842
#   N Points:	276473
#   N Strips:	0
#   X Bounds:	3.839e+05, 4.559e+05
#   Y Bounds:	1.521e+05, 1.917e+05
#   Z Bounds:	4.370e+04, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349375478.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349375478.h5 in 4.30 seconds
# Simplified mesh info: PolyData (0x1c9edb98ca8)
#   N Cells:	27691
#   N Points:	13754
#   N Strips:	0
#   X Bounds:	3.839e+05, 4.555e+05
#   Y Bounds:	1.521e+05, 1.917e+05
#   Z Bounds:	4.370e+04, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349375478.ply in 0.02 seconds
# Total time: 0.0 minutes and 4.39 seconds
# Loading data/neuron_meshes_v185/648518346349375478.h5
# Loaded data/neuron_meshes_v185/648518346349375478.h5 in 0.07 seconds
# Original mesh info: PolyData (0x1c9edb98108)
#   N Cells:	553842
#   N Points:	276473
#   N Strips:	0
#   X Bounds:	3.839e+05, 4.559e+05
#   Y Bounds:	1.521e+05, 1.917e+05
#   Z Bounds:	4.370e+04, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349375478.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349375478.h5 in 4.37 seconds
# Simplified mesh info: PolyData (0x1c9edb1e948)
#   N Cells:	27691
#   N Points:	13754
#   N Strips:	0
#   X Bounds:	3.839e+05, 4.555e+05
#   Y Bounds:	1.521e+05, 1.917e+05
#   Z Bounds:	4.370e+04, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349375478.ply in 0.02 seconds
# Total time: 0.0 minutes and 4.46 seconds
# Loading data/neuron_meshes_v185/648518346349526102.h5
# Loaded data/neuron_meshes_v185/648518346349526102.h5 in 2.15 seconds
# Original mesh info: PolyData (0x1c9edb98108)
#   N Cells:	15226510
#   N Points:	7607137
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.464e+05, 3.113e+05
#   Z Bounds:	8.132e+02, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526102.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526102.h5 in 177.77 seconds
# Simplified mesh info: PolyData (0x1c9edb985e8)
#   N Cells:	761325
#   N Points:	379193
#   N Strips:	0
#   X Bounds:	1.891e+05, 4.795e+05
#   Y Bounds:	1.465e+05, 3.113e+05
#   Z Bounds:	8.156e+02, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526102.ply in 0.67 seconds
# Total time: 3.0 minutes and 0.59 seconds

# %%
# # if the batch stall, uncomment and use the following code to pick up where it left off, by index number

# import pandas as pd
# import numpy as np
# import os
# import time
# import h5py
# import pyvista as pv

# # Set up paths and parameters
# obj_path = 'data/neuron_meshes_v185/'
# dec_prcnt = 95
# dec_path = 'data/neuron_meshes_v185/dec/'

# # Load cellids into a list
# celltypes = pd.read_csv("data/220309_cell_type_classification.csv", index_col=[0])
# vasc = celltypes[celltypes.cell_type == 'vasculature']
# vasc_list = vasc.cell_segid.to_list()

# def read_h5_file(file_path):
#     with h5py.File(file_path, 'r') as f:
#         vertices = np.array(f['vertices'])
#         faces = np.array(f['faces'])
#     return vertices, faces

# def create_pyvista_mesh(vertices, faces):
#     # PyVista expects faces to be in the format (n, v1, v2, v3, ...)
#     faces_with_size = np.hstack([np.full((faces.shape[0], 1), faces.shape[1]), faces])
#     return pv.PolyData(vertices, faces_with_size)

# def process_obj(cellid, dec_prcnt, obj_path, dec_path):
#     start_time = time.time()
    
#     # Create the full path to the file
#     file_path = os.path.join(obj_path, str(cellid) + '.h5')
#     print(f"Loading {file_path}")
    
#     # Load the file
#     vertices, faces = read_h5_file(file_path)
#     load_time = time.time()
#     print(f"Loaded {file_path} in {load_time - start_time:.2f} seconds")
    
#     # Create PyVista mesh
#     mesh = create_pyvista_mesh(vertices, faces)
#     print(f"Original mesh info: {mesh}")
    
#     # Perform decimation
#     print(f"Decimating {file_path} by {dec_prcnt}%")
#     simplified_mesh = mesh.decimate(target_reduction=dec_prcnt / 100)  # Reduce to x% of the original mesh
#     decimate_time = time.time()
#     print(f"Decimated {file_path} in {decimate_time - load_time:.2f} seconds")
    
#     # Print simplified mesh information
#     print(f"Simplified mesh info: {simplified_mesh}")
    
#     # Ensure the output directory exists
#     if not os.path.exists(dec_path):
#         os.makedirs(dec_path)
    
#     # Save the simplified mesh in PLY format
#     output_filename = os.path.basename(file_path).replace('.h5', '.ply')
#     output_path = os.path.join(dec_path, output_filename)
    
#     try:
#         simplified_mesh.save(output_path)
#         save_time = time.time()
#         print(f"Saved {output_path} in {save_time - decimate_time:.2f} seconds")
#     except Exception as e:
#         print(f"Error saving {output_path}: {e}")
    
#     total_time = time.time() - start_time
#     print(f"Total time: {total_time // 60} minutes and {total_time % 60:.2f} seconds")

# # Function to process a batch of cellids starting from a specific index
# def process_batch(astro_list, start_index, dec_prcnt, obj_path, dec_path):
#     for i in range(start_index, len(astro_list)):
#         cellid = astro_list[i]
#         process_obj(cellid, dec_prcnt, obj_path, dec_path)

# # Set the start index (change this value to the desired starting index)
# start_index = 10

# # Process each cellid in the astro_list starting from the specified index
# process_batch(vasc_list, start_index, dec_prcnt, obj_path, dec_path)
