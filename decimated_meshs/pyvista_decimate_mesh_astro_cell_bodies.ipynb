# %% [markdown]
# From: https://github.com/Quorumetrix/Blender_scripts/blob/main/Mesh%20Decimation%20Pipeline.ipynb

# %%
import pandas as pd
import numpy as np
import os
import time
import h5py
import pyvista as pv

# Set up paths and parameters
obj_path = 'data/neuron_meshes_v185/'
dec_prcnt = 95
dec_path = 'data/neuron_meshes_v185/dec/'

# Load astrocyte cellids into a list
astrocytes = pd.read_csv('data/astrocytes.csv', index_col=[0])
astro_list = astrocytes.cell_segid.to_list()

def read_h5_file(file_path):
    with h5py.File(file_path, 'r') as f:
        vertices = np.array(f['vertices'])
        faces = np.array(f['faces'])
    return vertices, faces

def create_pyvista_mesh(vertices, faces):
    # PyVista expects faces to be in the format (n, v1, v2, v3, ...)
    faces_with_size = np.hstack([np.full((faces.shape[0], 1), faces.shape[1]), faces])
    return pv.PolyData(vertices, faces_with_size)

def process_obj(cellid, dec_prcnt, obj_path, dec_path):
    start_time = time.time()
    
    # Create the full path to the file
    file_path = os.path.join(obj_path, str(cellid) + '.h5')
    print(f"Loading {file_path}")
    
    # Load the file
    vertices, faces = read_h5_file(file_path)
    load_time = time.time()
    print(f"Loaded {file_path} in {load_time - start_time:.2f} seconds")
    
    # Create PyVista mesh
    mesh = create_pyvista_mesh(vertices, faces)
    print(f"Original mesh info: {mesh}")
    
    # Perform decimation
    print(f"Decimating {file_path} by {dec_prcnt}%")
    simplified_mesh = mesh.decimate(target_reduction=dec_prcnt / 100)  # Reduce to x% of the original mesh
    decimate_time = time.time()
    print(f"Decimated {file_path} in {decimate_time - load_time:.2f} seconds")
    
    # Print simplified mesh information
    print(f"Simplified mesh info: {simplified_mesh}")
    
    # Ensure the output directory exists
    if not os.path.exists(dec_path):
        os.makedirs(dec_path)
    
    # Save the simplified mesh in PLY format
    output_filename = os.path.basename(file_path).replace('.h5', '.ply')
    output_path = os.path.join(dec_path, output_filename)
    
    try:
        simplified_mesh.save(output_path)
        save_time = time.time()
        print(f"Saved {output_path} in {save_time - decimate_time:.2f} seconds")
    except Exception as e:
        print(f"Error saving {output_path}: {e}")
    
    total_time = time.time() - start_time
    print(f"Total time: {total_time // 60} minutes and {total_time % 60:.2f} seconds")

# Process each cellid in the astro_list
for cellid in astro_list:
    process_obj(cellid, dec_prcnt, obj_path, dec_path)
# Out:
# Loading data/neuron_meshes_v185/648518346349517321.h5
# Loaded data/neuron_meshes_v185/648518346349517321.h5 in 1.63 seconds
# Original mesh info: PolyData (0x1dbad3e7588)
#   N Cells:	13765854
#   N Points:	6883249
#   N Strips:	0
#   X Bounds:	3.113e+05, 4.022e+05
#   Y Bounds:	1.623e+05, 3.024e+05
#   Z Bounds:	8.080e+02, 5.673e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349517321.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349517321.h5 in 162.29 seconds
# Simplified mesh info: PolyData (0x1dbad3e73a8)
#   N Cells:	688291
#   N Points:	338460
#   N Strips:	0
#   X Bounds:	3.115e+05, 4.022e+05
#   Y Bounds:	1.624e+05, 3.023e+05
#   Z Bounds:	7.957e+02, 5.661e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349517321.ply in 0.79 seconds
# Total time: 2.0 minutes and 44.71 seconds
# Loading data/neuron_meshes_v185/648518346341392909.h5
# Loaded data/neuron_meshes_v185/648518346341392909.h5 in 1.68 seconds
# Original mesh info: PolyData (0x1dbad3e7528)
#   N Cells:	12864774
#   N Points:	6436931
#   N Strips:	0
#   X Bounds:	2.155e+05, 3.754e+05
#   Y Bounds:	1.488e+05, 2.949e+05
#   Z Bounds:	8.075e+02, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346341392909.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346341392909.h5 in 148.54 seconds
# Simplified mesh info: PolyData (0x1dbad3e7828)
#   N Cells:	643237
#   N Points:	318719
#   N Strips:	0
#   X Bounds:	2.155e+05, 3.754e+05
#   Y Bounds:	1.488e+05, 2.948e+05
#   Z Bounds:	7.848e+02, 8.625e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346341392909.ply in 0.72 seconds
# Total time: 2.0 minutes and 30.95 seconds
# Loading data/neuron_meshes_v185/648518346349536799.h5
# Loaded data/neuron_meshes_v185/648518346349536799.h5 in 1.85 seconds
# Original mesh info: PolyData (0x1dbad3e7a68)
#   N Cells:	14447084
#   N Points:	7229278
#   N Strips:	0
#   X Bounds:	2.050e+05, 4.723e+05
#   Y Bounds:	1.455e+05, 2.992e+05
#   Z Bounds:	8.007e+02, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349536799.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349536799.h5 in 165.62 seconds
# Simplified mesh info: PolyData (0x1dbad3e73a8)
#   N Cells:	722353
#   N Points:	358434
#   N Strips:	0
#   X Bounds:	2.051e+05, 4.723e+05
#   Y Bounds:	1.455e+05, 2.991e+05
#   Z Bounds:	7.928e+02, 8.625e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349536799.ply in 0.72 seconds
# Total time: 2.0 minutes and 48.20 seconds
# Loading data/neuron_meshes_v185/648518346349525537.h5
# Loaded data/neuron_meshes_v185/648518346349525537.h5 in 0.30 seconds
# Original mesh info: PolyData (0x1dbad3e7828)
#   N Cells:	1780682
#   N Points:	890389
#   N Strips:	0
#   X Bounds:	2.081e+05, 3.434e+05
#   Y Bounds:	2.349e+05, 3.051e+05
#   Z Bounds:	3.590e+04, 7.970e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349525537.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349525537.h5 in 15.27 seconds
# Simplified mesh info: PolyData (0x1dbad3e79a8)
#   N Cells:	89033
#   N Points:	44230
#   N Strips:	0
#   X Bounds:	2.082e+05, 3.431e+05
#   Y Bounds:	2.349e+05, 3.050e+05
#   Z Bounds:	3.594e+04, 7.964e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349525537.ply in 0.07 seconds
# Total time: 0.0 minutes and 15.63 seconds
# Loading data/neuron_meshes_v185/648518346349525544.h5
# Loaded data/neuron_meshes_v185/648518346349525544.h5 in 1.05 seconds
# Original mesh info: PolyData (0x1dbad3e7b28)
#   N Cells:	9172428
#   N Points:	4583360
#   N Strips:	0
#   X Bounds:	2.562e+05, 3.521e+05
#   Y Bounds:	2.325e+05, 2.992e+05
#   Z Bounds:	8.040e+02, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349525544.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349525544.h5 in 89.19 seconds
# Simplified mesh info: PolyData (0x1dbad3e7888)
#   N Cells:	458621
#   N Points:	227028
#   N Strips:	0
#   X Bounds:	2.563e+05, 3.522e+05
#   Y Bounds:	2.326e+05, 2.992e+05
#   Z Bounds:	7.877e+02, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349525544.ply in 0.41 seconds
# Total time: 1.0 minutes and 30.65 seconds
# Loading data/neuron_meshes_v185/648518346349526583.h5
# Loaded data/neuron_meshes_v185/648518346349526583.h5 in 0.50 seconds
# Original mesh info: PolyData (0x1dbad3e7588)
#   N Cells:	4161240
#   N Points:	2078444
#   N Strips:	0
#   X Bounds:	2.985e+05, 4.086e+05
#   Y Bounds:	1.505e+05, 2.964e+05
#   Z Bounds:	3.514e+04, 8.628e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349526583.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349526583.h5 in 37.66 seconds
# Simplified mesh info: PolyData (0x1dbad3e7948)
#   N Cells:	208061
#   N Points:	102715
#   N Strips:	0
#   X Bounds:	2.985e+05, 4.086e+05
#   Y Bounds:	1.505e+05, 2.962e+05
#   Z Bounds:	3.517e+04, 8.629e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349526583.ply in 0.16 seconds
# Total time: 0.0 minutes and 38.32 seconds
# Loading data/neuron_meshes_v185/648518346349490239.h5
# Loaded data/neuron_meshes_v185/648518346349490239.h5 in 2.36 seconds
# Original mesh info: PolyData (0x1dbad3e7a08)
#   N Cells:	20641040
#   N Points:	10321500
#   N Strips:	0
#   X Bounds:	2.069e+05, 4.449e+05
#   Y Bounds:	1.519e+05, 3.082e+05
#   Z Bounds:	1.457e+04, 8.628e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349490239.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349490239.h5 in 275.17 seconds
# Simplified mesh info: PolyData (0x1dbad3e79a8)
#   N Cells:	1032052
#   N Points:	510438
#   N Strips:	0
#   X Bounds:	2.070e+05, 4.448e+05
#   Y Bounds:	1.520e+05, 3.082e+05
#   Z Bounds:	1.473e+04, 8.630e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349490239.ply in 1.14 seconds
# Total time: 4.0 minutes and 38.67 seconds
# Loading data/neuron_meshes_v185/648518346349524070.h5
# Loaded data/neuron_meshes_v185/648518346349524070.h5 in 2.25 seconds
# Original mesh info: PolyData (0x1dbad3e7948)
#   N Cells:	13604326
#   N Points:	6803753
#   N Strips:	0
#   X Bounds:	2.211e+05, 4.795e+05
#   Y Bounds:	1.515e+05, 3.113e+05
#   Z Bounds:	8.101e+02, 8.628e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349524070.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349524070.h5 in 155.25 seconds
# Simplified mesh info: PolyData (0x1dbad3e78e8)
#   N Cells:	680215
#   N Points:	337144
#   N Strips:	0
#   X Bounds:	2.212e+05, 4.795e+05
#   Y Bounds:	1.515e+05, 3.113e+05
#   Z Bounds:	8.023e+02, 8.630e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349524070.ply in 0.80 seconds
# Total time: 2.0 minutes and 38.29 seconds
# Loading data/neuron_meshes_v185/648518346349386860.h5
# Loaded data/neuron_meshes_v185/648518346349386860.h5 in 1.10 seconds
# Original mesh info: PolyData (0x1dbad3e7768)
#   N Cells:	6379602
#   N Points:	3186551
#   N Strips:	0
#   X Bounds:	3.680e+05, 4.522e+05
#   Y Bounds:	1.661e+05, 2.515e+05
#   Z Bounds:	8.056e+02, 5.262e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349386860.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349386860.h5 in 76.12 seconds
# Simplified mesh info: PolyData (0x1dbad3e79a8)
#   N Cells:	318980
#   N Points:	157303
#   N Strips:	0
#   X Bounds:	3.681e+05, 4.521e+05
#   Y Bounds:	1.664e+05, 2.514e+05
#   Z Bounds:	7.889e+02, 5.265e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349386860.ply in 0.34 seconds
# Total time: 1.0 minutes and 17.55 seconds
# Loading data/neuron_meshes_v185/648518346349508722.h5
# Loaded data/neuron_meshes_v185/648518346349508722.h5 in 2.05 seconds
# Original mesh info: PolyData (0x1dbad3e78e8)
#   N Cells:	11713962
#   N Points:	5863123
#   N Strips:	0
#   X Bounds:	2.394e+05, 3.246e+05
#   Y Bounds:	2.469e+05, 3.018e+05
#   Z Bounds:	3.362e+04, 7.567e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349508722.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349508722.h5 in 131.06 seconds
# Simplified mesh info: PolyData (0x1dbad3e7a08)
#   N Cells:	585698
#   N Points:	286528
#   N Strips:	0
#   X Bounds:	2.395e+05, 3.245e+05
#   Y Bounds:	2.470e+05, 3.018e+05
#   Z Bounds:	3.365e+04, 7.534e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349508722.ply in 0.60 seconds
# Total time: 2.0 minutes and 13.71 seconds
# Loading data/neuron_meshes_v185/648518346349536888.h5
# Loaded data/neuron_meshes_v185/648518346349536888.h5 in 4.61 seconds

# %%
# # if the batch stall, uncomment and use the following code to pick up where it left off, by index number

# import pandas as pd
# import numpy as np
# import os
# import time
# import h5py
# import pyvista as pv

# # Set up paths and parameters
# obj_path = 'data/neuron_meshes_v185/'
# dec_prcnt = 95
# dec_path = 'data/neuron_meshes_v185/dec/'

# # Load astrocyte cellids into a list
# astrocytes = pd.read_csv('data/astrocytes.csv', index_col=[0])
# astro_list = astrocytes.cell_segid.to_list()

# def read_h5_file(file_path):
#     with h5py.File(file_path, 'r') as f:
#         vertices = np.array(f['vertices'])
#         faces = np.array(f['faces'])
#     return vertices, faces

# def create_pyvista_mesh(vertices, faces):
#     # PyVista expects faces to be in the format (n, v1, v2, v3, ...)
#     faces_with_size = np.hstack([np.full((faces.shape[0], 1), faces.shape[1]), faces])
#     return pv.PolyData(vertices, faces_with_size)

# def process_obj(cellid, dec_prcnt, obj_path, dec_path):
#     start_time = time.time()
    
#     # Create the full path to the file
#     file_path = os.path.join(obj_path, str(cellid) + '.h5')
#     print(f"Loading {file_path}")
    
#     # Load the file
#     vertices, faces = read_h5_file(file_path)
#     load_time = time.time()
#     print(f"Loaded {file_path} in {load_time - start_time:.2f} seconds")
    
#     # Create PyVista mesh
#     mesh = create_pyvista_mesh(vertices, faces)
#     print(f"Original mesh info: {mesh}")
    
#     # Perform decimation
#     print(f"Decimating {file_path} by {dec_prcnt}%")
#     simplified_mesh = mesh.decimate(target_reduction=dec_prcnt / 100)  # Reduce to x% of the original mesh
#     decimate_time = time.time()
#     print(f"Decimated {file_path} in {decimate_time - load_time:.2f} seconds")
    
#     # Print simplified mesh information
#     print(f"Simplified mesh info: {simplified_mesh}")
    
#     # Ensure the output directory exists
#     if not os.path.exists(dec_path):
#         os.makedirs(dec_path)
    
#     # Save the simplified mesh in PLY format
#     output_filename = os.path.basename(file_path).replace('.h5', '.ply')
#     output_path = os.path.join(dec_path, output_filename)
    
#     try:
#         simplified_mesh.save(output_path)
#         save_time = time.time()
#         print(f"Saved {output_path} in {save_time - decimate_time:.2f} seconds")
#     except Exception as e:
#         print(f"Error saving {output_path}: {e}")
    
#     total_time = time.time() - start_time
#     print(f"Total time: {total_time // 60} minutes and {total_time % 60:.2f} seconds")

# # Function to process a batch of cellids starting from a specific index
# def process_batch(astro_list, start_index, dec_prcnt, obj_path, dec_path):
#     for i in range(start_index, len(astro_list)):
#         cellid = astro_list[i]
#         process_obj(cellid, dec_prcnt, obj_path, dec_path)

# # Set the start index (change this value to the desired starting index)
# start_index = 10

# # Process each cellid in the astro_list starting from the specified index
# process_batch(astro_list, start_index, dec_prcnt, obj_path, dec_path)
# Out:
# Loading data/neuron_meshes_v185/648518346349536888.h5
# Loaded data/neuron_meshes_v185/648518346349536888.h5 in 5.03 seconds
# Original mesh info: PolyData (0x21f1b96fb28)
#   N Cells:	34423102
#   N Points:	17219497
#   N Strips:	0
#   X Bounds:	3.074e+05, 4.736e+05
#   Y Bounds:	1.556e+05, 3.099e+05
#   Z Bounds:	1.242e+04, 8.628e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349536888.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349536888.h5 in 45647.88 seconds
# Simplified mesh info: PolyData (0x21f1b96fac8)
#   N Cells:	1721154
#   N Points:	844640
#   N Strips:	0
#   X Bounds:	3.076e+05, 4.734e+05
#   Y Bounds:	1.557e+05, 3.100e+05
#   Z Bounds:	1.253e+04, 8.629e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349536888.ply in 2.12 seconds
# Total time: 760.0 minutes and 55.04 seconds
# Loading data/neuron_meshes_v185/648518346349516953.h5
# Loaded data/neuron_meshes_v185/648518346349516953.h5 in 2.58 seconds
# Original mesh info: PolyData (0x21f1b96f768)
#   N Cells:	19692822
#   N Points:	9857441
#   N Strips:	0
#   X Bounds:	3.200e+05, 4.527e+05
#   Y Bounds:	1.573e+05, 2.869e+05
#   Z Bounds:	7.998e+02, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349516953.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349516953.h5 in 252.60 seconds
# Simplified mesh info: PolyData (0x21f1b96fbe8)
#   N Cells:	984641
#   N Points:	483851
#   N Strips:	0
#   X Bounds:	3.200e+05, 4.525e+05
#   Y Bounds:	1.574e+05, 2.868e+05
#   Z Bounds:	7.804e+02, 8.624e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349516953.ply in 1.35 seconds
# Total time: 4.0 minutes and 16.53 seconds
# Loading data/neuron_meshes_v185/648518346349521062.h5
# Loaded data/neuron_meshes_v185/648518346349521062.h5 in 1.38 seconds
# Original mesh info: PolyData (0x21f1b96fac8)
#   N Cells:	7779580
#   N Points:	3881024
#   N Strips:	0
#   X Bounds:	2.127e+05, 4.749e+05
#   Y Bounds:	1.516e+05, 2.417e+05
#   Z Bounds:	3.850e+03, 8.628e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349521062.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349521062.h5 in 92.77 seconds
# Simplified mesh info: PolyData (0x21f1b96fd08)
#   N Cells:	388978
#   N Points:	192577
#   N Strips:	0
#   X Bounds:	2.128e+05, 4.749e+05
#   Y Bounds:	1.517e+05, 2.417e+05
#   Z Bounds:	3.942e+03, 8.630e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349521062.ply in 0.43 seconds
# Total time: 1.0 minutes and 34.58 seconds
# Loading data/neuron_meshes_v185/648518346342468778.h5
# Loaded data/neuron_meshes_v185/648518346342468778.h5 in 0.17 seconds
# Original mesh info: PolyData (0x21f1b96fd68)
#   N Cells:	1000764
#   N Points:	500896
#   N Strips:	0
#   X Bounds:	4.240e+05, 4.621e+05
#   Y Bounds:	2.772e+05, 3.115e+05
#   Z Bounds:	7.626e+03, 3.243e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346342468778.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346342468778.h5 in 10.67 seconds
# Simplified mesh info: PolyData (0x21f1b96ff48)
#   N Cells:	50037
#   N Points:	24569
#   N Strips:	0
#   X Bounds:	4.240e+05, 4.619e+05
#   Y Bounds:	2.773e+05, 3.115e+05
#   Z Bounds:	7.673e+03, 3.243e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346342468778.ply in 0.05 seconds
# Total time: 0.0 minutes and 10.90 seconds
# Loading data/neuron_meshes_v185/648518346342795947.h5
# Loaded data/neuron_meshes_v185/648518346342795947.h5 in 0.96 seconds
# Original mesh info: PolyData (0x21f1b96fc48)
#   N Cells:	5773868
#   N Points:	2888632
#   N Strips:	0
#   X Bounds:	3.726e+05, 4.651e+05
#   Y Bounds:	2.021e+05, 2.958e+05
#   Z Bounds:	8.022e+02, 7.990e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346342795947.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346342795947.h5 in 65.49 seconds
# Simplified mesh info: PolyData (0x21f1b96fac8)
#   N Cells:	288692
#   N Points:	142771
#   N Strips:	0
#   X Bounds:	3.727e+05, 4.650e+05
#   Y Bounds:	2.022e+05, 2.957e+05
#   Z Bounds:	7.859e+02, 7.985e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346342795947.ply in 0.27 seconds
# Total time: 1.0 minutes and 6.73 seconds
# Loading data/neuron_meshes_v185/648518346349524139.h5
# Loaded data/neuron_meshes_v185/648518346349524139.h5 in 0.54 seconds
# Original mesh info: PolyData (0x21f1b96fd08)
#   N Cells:	3119776
#   N Points:	1559194
#   N Strips:	0
#   X Bounds:	2.209e+05, 4.728e+05
#   Y Bounds:	1.485e+05, 3.088e+05
#   Z Bounds:	7.950e+02, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349524139.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349524139.h5 in 30.21 seconds
# Simplified mesh info: PolyData (0x21f1b96fe28)
#   N Cells:	155986
#   N Points:	78128
#   N Strips:	0
#   X Bounds:	2.209e+05, 4.728e+05
#   Y Bounds:	1.485e+05, 3.087e+05
#   Z Bounds:	7.967e+02, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349524139.ply in 0.10 seconds
# Total time: 0.0 minutes and 30.85 seconds
# Loading data/neuron_meshes_v185/648518346342917290.h5
# Loaded data/neuron_meshes_v185/648518346342917290.h5 in 2.15 seconds
# Original mesh info: PolyData (0x21f1b96fd68)
#   N Cells:	8447318
#   N Points:	4222471
#   N Strips:	0
#   X Bounds:	2.138e+05, 3.691e+05
#   Y Bounds:	1.464e+05, 2.255e+05
#   Z Bounds:	2.921e+04, 8.628e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346342917290.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346342917290.h5 in 87.07 seconds
# Simplified mesh info: PolyData (0x21f1b96f768)
#   N Cells:	422363
#   N Points:	208392
#   N Strips:	0
#   X Bounds:	2.138e+05, 3.690e+05
#   Y Bounds:	1.464e+05, 2.254e+05
#   Z Bounds:	2.935e+04, 8.629e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346342917290.ply in 0.42 seconds
# Total time: 1.0 minutes and 29.64 seconds
# Loading data/neuron_meshes_v185/648518346349528249.h5
# Loaded data/neuron_meshes_v185/648518346349528249.h5 in 0.12 seconds
# Original mesh info: PolyData (0x21f1b96fe28)
#   N Cells:	620452
#   N Points:	310090
#   N Strips:	0
#   X Bounds:	1.896e+05, 2.199e+05
#   Y Bounds:	2.262e+05, 2.672e+05
#   Z Bounds:	8.495e+03, 1.903e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349528249.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349528249.h5 in 4.95 seconds
# Simplified mesh info: PolyData (0x21f1b96fd08)
#   N Cells:	31021
#   N Points:	15447
#   N Strips:	0
#   X Bounds:	1.897e+05, 2.196e+05
#   Y Bounds:	2.262e+05, 2.672e+05
#   Z Bounds:	8.498e+03, 1.903e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349528249.ply in 0.03 seconds
# Total time: 0.0 minutes and 5.10 seconds
# Loading data/neuron_meshes_v185/648518346349528250.h5
# Loaded data/neuron_meshes_v185/648518346349528250.h5 in 1.45 seconds
# Original mesh info: PolyData (0x21f1b96fee8)
#   N Cells:	11056268
#   N Points:	5531926
#   N Strips:	0
#   X Bounds:	2.040e+05, 3.178e+05
#   Y Bounds:	1.496e+05, 3.015e+05
#   Z Bounds:	2.154e+04, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349528250.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349528250.h5 in 124.15 seconds
# Simplified mesh info: PolyData (0x21f1b96fe28)
#   N Cells:	552812
#   N Points:	271982
#   N Strips:	0
#   X Bounds:	2.041e+05, 3.178e+05
#   Y Bounds:	1.496e+05, 3.015e+05
#   Z Bounds:	2.175e+04, 8.624e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349528250.ply in 0.52 seconds
# Total time: 2.0 minutes and 6.12 seconds
# Loading data/neuron_meshes_v185/648518346349507266.h5
# Loaded data/neuron_meshes_v185/648518346349507266.h5 in 1.70 seconds
# Original mesh info: PolyData (0x21f1b96fd08)
#   N Cells:	10593460
#   N Points:	5296240
#   N Strips:	0
#   X Bounds:	3.756e+05, 4.712e+05
#   Y Bounds:	1.525e+05, 2.677e+05
#   Z Bounds:	8.125e+02, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349507266.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349507266.h5 in 117.87 seconds
# Simplified mesh info: PolyData (0x21f1b96ff48)
#   N Cells:	529673
#   N Points:	263735
#   N Strips:	0
#   X Bounds:	3.756e+05, 4.710e+05
#   Y Bounds:	1.526e+05, 2.677e+05
#   Z Bounds:	8.201e+02, 8.624e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349507266.ply in 0.56 seconds
# Total time: 2.0 minutes and 0.13 seconds
# Loading data/neuron_meshes_v185/648518346349498574.h5
# Loaded data/neuron_meshes_v185/648518346349498574.h5 in 0.66 seconds
# Original mesh info: PolyData (0x21f1b96fe88)
#   N Cells:	5163246
#   N Points:	2581875
#   N Strips:	0
#   X Bounds:	2.256e+05, 3.833e+05
#   Y Bounds:	1.576e+05, 3.006e+05
#   Z Bounds:	8.050e+02, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349498574.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349498574.h5 in 53.28 seconds
# Simplified mesh info: PolyData (0x21f1b96ffa8)
#   N Cells:	258162
#   N Points:	127763
#   N Strips:	0
#   X Bounds:	2.256e+05, 3.832e+05
#   Y Bounds:	1.580e+05, 3.005e+05
#   Z Bounds:	7.913e+02, 8.622e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349498574.ply in 0.21 seconds
# Total time: 0.0 minutes and 54.15 seconds
# Loading data/neuron_meshes_v185/648518346349528271.h5
# Loaded data/neuron_meshes_v185/648518346349528271.h5 in 1.87 seconds
# Original mesh info: PolyData (0x21f1b96fee8)
#   N Cells:	12479592
#   N Points:	6238994
#   N Strips:	0
#   X Bounds:	2.015e+05, 2.922e+05
#   Y Bounds:	1.828e+05, 2.712e+05
#   Z Bounds:	4.771e+04, 8.628e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349528271.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349528271.h5 in 142.93 seconds
# Simplified mesh info: PolyData (0x21f1b96ff48)
#   N Cells:	623979
#   N Points:	305825
#   N Strips:	0
#   X Bounds:	2.018e+05, 2.918e+05
#   Y Bounds:	1.830e+05, 2.710e+05
#   Z Bounds:	4.778e+04, 8.630e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349528271.ply in 0.62 seconds
# Total time: 2.0 minutes and 25.42 seconds
# Loading data/neuron_meshes_v185/648518346349525715.h5
# Loaded data/neuron_meshes_v185/648518346349525715.h5 in 3.67 seconds
# Original mesh info: PolyData (0x21f1b96fb88)
#   N Cells:	28097124
#   N Points:	14054050
#   N Strips:	0
#   X Bounds:	2.449e+05, 3.351e+05
#   Y Bounds:	1.492e+05, 2.872e+05
#   Z Bounds:	2.336e+04, 8.628e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349525715.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349525715.h5 in 10224.95 seconds
# Simplified mesh info: PolyData (0x21f1b96fd08)
#   N Cells:	1404856
#   N Points:	689203
#   N Strips:	0
#   X Bounds:	2.449e+05, 3.349e+05
#   Y Bounds:	1.494e+05, 2.871e+05
#   Z Bounds:	2.348e+04, 8.630e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349525715.ply in 2.10 seconds
# Total time: 170.0 minutes and 30.72 seconds
# Loading data/neuron_meshes_v185/648518346341399264.h5
# Loaded data/neuron_meshes_v185/648518346341399264.h5 in 0.37 seconds
# Original mesh info: PolyData (0x21f1b96ff48)
#   N Cells:	1432196
#   N Points:	715934
#   N Strips:	0
#   X Bounds:	3.251e+05, 4.787e+05
#   Y Bounds:	1.570e+05, 3.146e+05
#   Z Bounds:	2.777e+04, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346341399264.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346341399264.h5 in 15.82 seconds
# Simplified mesh info: PolyData (0x21f1b96fd68)
#   N Cells:	71609
#   N Points:	35335
#   N Strips:	0
#   X Bounds:	3.253e+05, 4.787e+05
#   Y Bounds:	1.571e+05, 3.146e+05
#   Z Bounds:	2.780e+04, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346341399264.ply in 0.09 seconds
# Total time: 0.0 minutes and 16.28 seconds
# Loading data/neuron_meshes_v185/648518346349536487.h5
# Loaded data/neuron_meshes_v185/648518346349536487.h5 in 0.46 seconds
# Original mesh info: PolyData (0x21f1b96fbe8)
#   N Cells:	2633380
#   N Points:	1315792
#   N Strips:	0
#   X Bounds:	2.068e+05, 2.536e+05
#   Y Bounds:	2.351e+05, 2.919e+05
#   Z Bounds:	8.067e+02, 2.171e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349536487.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349536487.h5 in 28.34 seconds
# Simplified mesh info: PolyData (0x21f1b96fee8)
#   N Cells:	131667
#   N Points:	64673
#   N Strips:	0
#   X Bounds:	2.068e+05, 2.536e+05
#   Y Bounds:	2.354e+05, 2.918e+05
#   Z Bounds:	7.997e+02, 2.172e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349536487.ply in 0.13 seconds
# Total time: 0.0 minutes and 28.93 seconds
# Loading data/neuron_meshes_v185/648518346349532924.h5
# Loaded data/neuron_meshes_v185/648518346349532924.h5 in 3.45 seconds
# Original mesh info: PolyData (0x21f1b96ffa8)
#   N Cells:	19553142
#   N Points:	9779811
#   N Strips:	0
#   X Bounds:	3.066e+05, 4.741e+05
#   Y Bounds:	1.599e+05, 3.113e+05
#   Z Bounds:	8.111e+02, 8.386e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349532924.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349532924.h5 in 254.06 seconds
# Simplified mesh info: PolyData (0x21f1b96fe88)
#   N Cells:	977657
#   N Points:	482163
#   N Strips:	0
#   X Bounds:	3.067e+05, 4.740e+05
#   Y Bounds:	1.599e+05, 3.112e+05
#   Z Bounds:	8.079e+02, 8.377e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349532924.ply in 1.14 seconds
# Total time: 4.0 minutes and 18.65 seconds
# Loading data/neuron_meshes_v185/648518346349527316.h5
# Loaded data/neuron_meshes_v185/648518346349527316.h5 in 0.63 seconds
# Original mesh info: PolyData (0x21f1b96fb88)
#   N Cells:	4279606
#   N Points:	2139383
#   N Strips:	0
#   X Bounds:	2.355e+05, 3.107e+05
#   Y Bounds:	2.371e+05, 3.031e+05
#   Z Bounds:	4.946e+04, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349527316.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349527316.h5 in 44.97 seconds
# Simplified mesh info: PolyData (0x21f1b96ff48)
#   N Cells:	213980
#   N Points:	105582
#   N Strips:	0
#   X Bounds:	2.356e+05, 3.106e+05
#   Y Bounds:	2.371e+05, 3.030e+05
#   Z Bounds:	4.957e+04, 8.630e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349527316.ply in 0.21 seconds
# Total time: 0.0 minutes and 45.82 seconds
# Loading data/neuron_meshes_v185/648518346349527317.h5
# Loaded data/neuron_meshes_v185/648518346349527317.h5 in 0.90 seconds
# Original mesh info: PolyData (0x21f1b96fc48)
#   N Cells:	6449472
#   N Points:	3228394
#   N Strips:	0
#   X Bounds:	2.399e+05, 3.474e+05
#   Y Bounds:	2.272e+05, 3.041e+05
#   Z Bounds:	5.665e+04, 8.628e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349527317.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349527317.h5 in 70.72 seconds
# Simplified mesh info: PolyData (0x21f1b96fbe8)
#   N Cells:	322473
#   N Points:	158384
#   N Strips:	0
#   X Bounds:	2.400e+05, 3.473e+05
#   Y Bounds:	2.273e+05, 3.041e+05
#   Z Bounds:	5.671e+04, 8.629e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349527317.ply in 0.31 seconds
# Total time: 1.0 minutes and 11.93 seconds
# Loading data/neuron_meshes_v185/648518346349527319.h5
# Loaded data/neuron_meshes_v185/648518346349527319.h5 in 2.67 seconds
# Original mesh info: PolyData (0x21f1b96fb28)
#   N Cells:	18340374
#   N Points:	9178823
#   N Strips:	0
#   X Bounds:	2.108e+05, 3.019e+05
#   Y Bounds:	1.418e+05, 2.488e+05
#   Z Bounds:	5.620e+03, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349527319.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349527319.h5 in 226.91 seconds
# Simplified mesh info: PolyData (0x21f1b96fe88)
#   N Cells:	917018
#   N Points:	453799
#   N Strips:	0
#   X Bounds:	2.113e+05, 3.017e+05
#   Y Bounds:	1.418e+05, 2.487e+05
#   Z Bounds:	5.631e+03, 8.629e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349527319.ply in 0.99 seconds
# Total time: 3.0 minutes and 50.57 seconds
# Loading data/neuron_meshes_v185/648518346342807831.h5
# Loaded data/neuron_meshes_v185/648518346342807831.h5 in 2.08 seconds
# Original mesh info: PolyData (0x21f1b96fd68)
#   N Cells:	16958892
#   N Points:	8485916
#   N Strips:	0
#   X Bounds:	2.215e+05, 4.701e+05
#   Y Bounds:	1.515e+05, 3.090e+05
#   Z Bounds:	8.193e+02, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346342807831.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346342807831.h5 in 204.71 seconds
# Simplified mesh info: PolyData (0x21f1b96fb28)
#   N Cells:	847943
#   N Points:	418122
#   N Strips:	0
#   X Bounds:	2.215e+05, 4.700e+05
#   Y Bounds:	1.515e+05, 3.089e+05
#   Z Bounds:	8.201e+02, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346342807831.ply in 0.89 seconds
# Total time: 3.0 minutes and 27.68 seconds
# Loading data/neuron_meshes_v185/648518346349537050.h5
# Loaded data/neuron_meshes_v185/648518346349537050.h5 in 0.98 seconds
# Original mesh info: PolyData (0x21f1b96fe88)
#   N Cells:	7275522
#   N Points:	3634847
#   N Strips:	0
#   X Bounds:	3.685e+05, 4.754e+05
#   Y Bounds:	1.557e+05, 3.101e+05
#   Z Bounds:	2.535e+04, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349537050.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349537050.h5 in 79.58 seconds
# Simplified mesh info: PolyData (0x21f1b96fbe8)
#   N Cells:	363775
#   N Points:	179702
#   N Strips:	0
#   X Bounds:	3.686e+05, 4.752e+05
#   Y Bounds:	1.558e+05, 3.100e+05
#   Z Bounds:	2.542e+04, 8.628e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349537050.ply in 0.38 seconds
# Total time: 1.0 minutes and 20.95 seconds
# Loading data/neuron_meshes_v185/648518346349538089.h5
# Loaded data/neuron_meshes_v185/648518346349538089.h5 in 2.60 seconds
# Original mesh info: PolyData (0x21f1b96fee8)
#   N Cells:	18711536
#   N Points:	9358310
#   N Strips:	0
#   X Bounds:	2.076e+05, 4.116e+05
#   Y Bounds:	1.769e+05, 3.065e+05
#   Z Bounds:	8.090e+02, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349538089.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349538089.h5 in 228.56 seconds
# Simplified mesh info: PolyData (0x21f1b96fc48)
#   N Cells:	935575
#   N Points:	458066
#   N Strips:	0
#   X Bounds:	2.077e+05, 4.116e+05
#   Y Bounds:	1.769e+05, 3.065e+05
#   Z Bounds:	8.197e+02, 8.626e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349538089.ply in 1.06 seconds
# Total time: 3.0 minutes and 52.23 seconds
# Loading data/neuron_meshes_v185/648518346341356348.h5
# Loaded data/neuron_meshes_v185/648518346341356348.h5 in 1.03 seconds
# Original mesh info: PolyData (0x21f1b96fbe8)
#   N Cells:	7856334
#   N Points:	3930921
#   N Strips:	0
#   X Bounds:	3.291e+05, 4.021e+05
#   Y Bounds:	1.909e+05, 3.087e+05
#   Z Bounds:	3.570e+04, 8.627e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346341356348.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346341356348.h5 in 84.62 seconds
# Simplified mesh info: PolyData (0x21f1b96fac8)
#   N Cells:	392815
#   N Points:	192692
#   N Strips:	0
#   X Bounds:	3.292e+05, 4.021e+05
#   Y Bounds:	1.909e+05, 3.086e+05
#   Z Bounds:	3.577e+04, 8.631e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346341356348.ply in 0.36 seconds
# Total time: 1.0 minutes and 26.01 seconds
# Loading data/neuron_meshes_v185/648518346349517141.h5
# Loaded data/neuron_meshes_v185/648518346349517141.h5 in 2.87 seconds
# Original mesh info: PolyData (0x21f1b96fc48)
#   N Cells:	19572478
#   N Points:	9786009
#   N Strips:	0
#   X Bounds:	2.154e+05, 4.217e+05
#   Y Bounds:	1.503e+05, 2.484e+05
#   Z Bounds:	8.028e+02, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349517141.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349517141.h5 in 245.67 seconds
# Simplified mesh info: PolyData (0x21f1b96fbe8)
#   N Cells:	978622
#   N Points:	483750
#   N Strips:	0
#   X Bounds:	2.155e+05, 4.217e+05
#   Y Bounds:	1.503e+05, 2.484e+05
#   Z Bounds:	8.040e+02, 8.621e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349517141.ply in 1.09 seconds
# Total time: 4.0 minutes and 9.62 seconds
# Loading data/neuron_meshes_v185/648518346349539158.h5
# Loaded data/neuron_meshes_v185/648518346349539158.h5 in 1.83 seconds
# Original mesh info: PolyData (0x21f1b96fac8)
#   N Cells:	13199094
#   N Points:	6603649
#   N Strips:	0
#   X Bounds:	2.066e+05, 4.003e+05
#   Y Bounds:	1.503e+05, 3.051e+05
#   Z Bounds:	7.990e+02, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349539158.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349539158.h5 in 154.56 seconds
# Simplified mesh info: PolyData (0x21f1b96fd08)
#   N Cells:	659953
#   N Points:	328226
#   N Strips:	0
#   X Bounds:	2.067e+05, 4.002e+05
#   Y Bounds:	1.503e+05, 3.050e+05
#   Z Bounds:	8.095e+02, 8.620e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349539158.ply in 0.73 seconds
# Total time: 2.0 minutes and 37.11 seconds
# Loading data/neuron_meshes_v185/648518346349525862.h5
# Loaded data/neuron_meshes_v185/648518346349525862.h5 in 0.74 seconds
# Original mesh info: PolyData (0x21f1b96fe88)
#   N Cells:	5618778
#   N Points:	2812257
#   N Strips:	0
#   X Bounds:	2.245e+05, 2.959e+05
#   Y Bounds:	1.430e+05, 2.899e+05
#   Z Bounds:	2.170e+04, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349525862.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349525862.h5 in 58.18 seconds
# Simplified mesh info: PolyData (0x21f1b96fe28)
#   N Cells:	280938
#   N Points:	139084
#   N Strips:	0
#   X Bounds:	2.245e+05, 2.953e+05
#   Y Bounds:	1.432e+05, 2.899e+05
#   Z Bounds:	2.176e+04, 8.622e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349525862.ply in 0.26 seconds
# Total time: 0.0 minutes and 59.18 seconds
# Loading data/neuron_meshes_v185/648518346344075119.h5
# Loaded data/neuron_meshes_v185/648518346344075119.h5 in 0.20 seconds
# Original mesh info: PolyData (0x21f1b96fb88)
#   N Cells:	1492318
#   N Points:	745269
#   N Strips:	0
#   X Bounds:	3.967e+05, 4.424e+05
#   Y Bounds:	2.847e+05, 3.090e+05
#   Z Bounds:	6.329e+03, 3.486e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346344075119.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346344075119.h5 in 13.20 seconds
# Simplified mesh info: PolyData (0x21f1b96fe88)
#   N Cells:	74615
#   N Points:	36809
#   N Strips:	0
#   X Bounds:	3.967e+05, 4.423e+05
#   Y Bounds:	2.849e+05, 3.090e+05
#   Z Bounds:	6.384e+03, 3.482e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346344075119.ply in 0.06 seconds
# Total time: 0.0 minutes and 13.47 seconds
# Loading data/neuron_meshes_v185/648518346341354380.h5
# Loaded data/neuron_meshes_v185/648518346341354380.h5 in 2.11 seconds
# Original mesh info: PolyData (0x21f1b96fdc8)
#   N Cells:	15934384
#   N Points:	7972118
#   N Strips:	0
#   X Bounds:	2.759e+05, 4.422e+05
#   Y Bounds:	1.753e+05, 3.103e+05
#   Z Bounds:	1.487e+04, 8.629e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346341354380.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346341354380.h5 in 190.85 seconds
# Simplified mesh info: PolyData (0x21f1b96fd68)
#   N Cells:	796719
#   N Points:	392057
#   N Strips:	0
#   X Bounds:	2.761e+05, 4.421e+05
#   Y Bounds:	1.756e+05, 3.102e+05
#   Z Bounds:	1.491e+04, 8.631e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346341354380.ply in 0.84 seconds
# Total time: 3.0 minutes and 13.80 seconds
# Loading data/neuron_meshes_v185/648518346349528465.h5
# Loaded data/neuron_meshes_v185/648518346349528465.h5 in 2.88 seconds
# Original mesh info: PolyData (0x21f1b96fc48)
#   N Cells:	19361080
#   N Points:	9680198
#   N Strips:	0
#   X Bounds:	3.327e+05, 4.718e+05
#   Y Bounds:	1.963e+05, 2.767e+05
#   Z Bounds:	2.195e+04, 7.695e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349528465.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349528465.h5 in 259.59 seconds
# Simplified mesh info: PolyData (0x21f1b96fb28)
#   N Cells:	968053
#   N Points:	472790
#   N Strips:	0
#   X Bounds:	3.327e+05, 4.717e+05
#   Y Bounds:	1.963e+05, 2.765e+05
#   Z Bounds:	2.220e+04, 7.688e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349528465.ply in 1.44 seconds
# Total time: 4.0 minutes and 23.90 seconds
# Loading data/neuron_meshes_v185/648518346349484948.h5
# Loaded data/neuron_meshes_v185/648518346349484948.h5 in 1.17 seconds
# Original mesh info: PolyData (0x21f1b96fe28)
#   N Cells:	6650314
#   N Points:	3319869
#   N Strips:	0
#   X Bounds:	4.022e+05, 4.749e+05
#   Y Bounds:	1.551e+05, 2.238e+05
#   Z Bounds:	3.438e+04, 8.628e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349484948.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349484948.h5 in 77.55 seconds
# Simplified mesh info: PolyData (0x21f1b96ffa8)
#   N Cells:	332514
#   N Points:	165252
#   N Strips:	0
#   X Bounds:	4.022e+05, 4.749e+05
#   Y Bounds:	1.552e+05, 2.238e+05
#   Z Bounds:	3.439e+04, 8.629e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349484948.ply in 0.32 seconds
# Total time: 1.0 minutes and 19.04 seconds
# Loading data/neuron_meshes_v185/648518346342797245.h5
# Loaded data/neuron_meshes_v185/648518346342797245.h5 in 0.88 seconds
# Original mesh info: PolyData (0x21f1b96fd08)
#   N Cells:	6184012
#   N Points:	3091130
#   N Strips:	0
#   X Bounds:	2.229e+05, 3.699e+05
#   Y Bounds:	1.481e+05, 2.993e+05
#   Z Bounds:	1.546e+04, 8.626e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346342797245.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346342797245.h5 in 70.14 seconds
# Simplified mesh info: PolyData (0x21f1b96fac8)
#   N Cells:	309200
#   N Points:	154069
#   N Strips:	0
#   X Bounds:	2.229e+05, 3.699e+05
#   Y Bounds:	1.482e+05, 2.991e+05
#   Z Bounds:	1.547e+04, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346342797245.ply in 0.36 seconds
# Total time: 1.0 minutes and 11.38 seconds
# Loading data/neuron_meshes_v185/648518346349521344.h5
# Loaded data/neuron_meshes_v185/648518346349521344.h5 in 0.17 seconds
# Original mesh info: PolyData (0x21f1b96ffa8)
#   N Cells:	1054362
#   N Points:	527467
#   N Strips:	0
#   X Bounds:	1.873e+05, 2.496e+05
#   Y Bounds:	2.543e+05, 2.953e+05
#   Z Bounds:	3.514e+04, 5.011e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349521344.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349521344.h5 in 9.70 seconds
# Simplified mesh info: PolyData (0x21f1b96fd68)
#   N Cells:	52718
#   N Points:	26319
#   N Strips:	0
#   X Bounds:	1.874e+05, 2.496e+05
#   Y Bounds:	2.544e+05, 2.952e+05
#   Z Bounds:	3.513e+04, 5.011e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349521344.ply in 0.05 seconds
# Total time: 0.0 minutes and 9.92 seconds
# Loading data/neuron_meshes_v185/648518346342795202.h5
# Loaded data/neuron_meshes_v185/648518346342795202.h5 in 1.69 seconds
# Original mesh info: PolyData (0x21f1b96fca8)
#   N Cells:	12050850
#   N Points:	6019747
#   N Strips:	0
#   X Bounds:	3.643e+05, 4.795e+05
#   Y Bounds:	1.559e+05, 3.138e+05
#   Z Bounds:	2.861e+03, 8.628e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346342795202.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346342795202.h5 in 149.31 seconds
# Simplified mesh info: PolyData (0x21f1b96ffa8)
#   N Cells:	602542
#   N Points:	296447
#   N Strips:	0
#   X Bounds:	3.645e+05, 4.794e+05
#   Y Bounds:	1.559e+05, 3.138e+05
#   Z Bounds:	2.874e+03, 8.627e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346342795202.ply in 0.94 seconds
# Total time: 2.0 minutes and 31.94 seconds
# Loading data/neuron_meshes_v185/648518346349530569.h5
# Loaded data/neuron_meshes_v185/648518346349530569.h5 in 1.91 seconds
# Original mesh info: PolyData (0x21f1b96fd68)
#   N Cells:	10839986
#   N Points:	5422461
#   N Strips:	0
#   X Bounds:	1.939e+05, 2.738e+05
#   Y Bounds:	2.418e+05, 2.983e+05
#   Z Bounds:	4.202e+04, 8.628e+04
#   N Arrays:	0
#
# Decimating data/neuron_meshes_v185/648518346349530569.h5 by 95%
# Decimated data/neuron_meshes_v185/648518346349530569.h5 in 126.71 seconds
# Simplified mesh info: PolyData (0x21f1b96fac8)
#   N Cells:	541998
#   N Points:	266855
#   N Strips:	0
#   X Bounds:	1.940e+05, 2.737e+05
#   Y Bounds:	2.418e+05, 2.983e+05
#   Z Bounds:	4.203e+04, 8.628e+04
#   N Arrays:	0
#
# Saved data/neuron_meshes_v185/dec/648518346349530569.ply in 0.63 seconds
# Total time: 2.0 minutes and 9.26 seconds
