# %% [markdown]
# # 0. Overall accuracy of Random Forest Classifier (rfc) original analysis
# - Correct assignments:   738/1137 **(0.65)**
# - Incorrect assignments: 399/1137 **(0.35)**
#
# # 1. CLEAN 125 analysis
# - for cellid 648518346349534614 7 mitos classified as apical in the original got correctly classified as basal in Clean 125 for a running total of 738+7 = 745/1137 correct and 399 - 7 = 392/1137 as incorrect
# - for cellid 648518346349539845, no improvement and loss of 1 mito assignemnt for accuracy, so running total is 744/1137 correct and 393/1137 incorrect
# - for 648518346349537071, this was one mito and Clean 125 got the assignment correct, so running total is back to 745/1137 correct and 392/1137 incorrect
# - for cellid 648518346349539097, 3 mitos were classified as apical by Clean 125 and should have been basal, slight loss in accuracy for a running total of 742/1137 correct and 395/1137 incorrect
# - for cellid 648518346349531254, 2 mitos were correctly classified by Clean 125 as basal, running total 744/1137 correct and 393/1137 incorrect
# - for 648518346349535192, 2 mitos were incorrectly assigned by Clean, so loss of two: 742/1137 correct and 395/1137 incorrect
# ### Overall about the same accuracy with Clean 125 training set of 742/1137 correct and 395/1137.
#
# # 2. Adding within cone 45 metric
# ### Apical results
# - correct 77/132 **(0.583)**
# - incorrect 55/132 **(0.417)**
#
# ### Basal results
# - 727/1005 **(0.723)** CORRECT
# - 278/1005 **(0.277)** INCORRECT
#
# ## Overall summary for withincone45 metric
# - correct = 77 + 727 = 804/1137 **(0.707)**
# - incorrect = 55 + 278 = 333/1137 **(0.293)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
pd.set_option('display.max_columns', None)

# %%
# open random forest classifier (rfc) results for the unknown dendritic classification
# unknown_dendritic_rfc_results = pd.read_csv('unknown_dendritic_CLEAN125_rfc_prediction_results.csv', index_col=[0])

unknown_dendritic_rfc_results = pd.read_csv('unknown_dendritic_rfc_prediction_results_withincone.csv', index_col=[0])

# %% [markdown]
# # RFC setting used to generate these predictions
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 1,
#  'verbose': 0,
#  'warm_start': False}

# %%
# add new col cellid_str with string type to fix plotly error
unknown_dendritic_rfc_results['cellid_str'] = unknown_dendritic_rfc_results.loc[:, 'cellid']

# convert to str
unknown_dendritic_df = unknown_dendritic_rfc_results.astype({'cellid_str':'string'})
unknown_dendritic_df
# Out:
#        index  mito_id  mito_vx  ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  \
# 0          4  1547760   211468         70706         45080          1364
# 1         11  1774335   516120         74524         41666           984
# 2         12  1662490     3004         71398         43960          1139
# 3         15  1547394   879336         70958         45388          1891
# 4         21  1541327   547340         70932         42378           866
# ...      ...      ...      ...           ...           ...           ...
# 1132  182307   545422   261204         51806         45212          1622
# 1133  182312   633845   366232         54084         38652          1164
# 1134  182313   973784  2897496         62588         42158           510
# 1135  182316  1310832   752504         66324         41486          1332
# 1136  182317  1305695  1116352         65634         39582          1837
#
#       bbox_beg_x_vx  bbox_beg_y_vx  bbox_beg_z_vx  bbox_end_x_vx  \
# 0             70248          44874           1328          71030
# 1             73392          41388            903          75434
# 2             71356          43932           1135          71440
# 3             70558          44828           1662          71340
# 4             70804          41794            785          71188
# ...             ...            ...            ...            ...
# 1132          51278          45042           1610          52394
# 1133          53490          38578           1120          54614
# 1134          59768          41724             74          65388
# 1135          66142          41328           1270          66814
# 1136          65510          39380           1756          65874
#
#       bbox_end_y_vx  bbox_end_z_vx              cellid  ctr_pos_x_nm  \
# 0             45284           1393  648518346349523993        282824
# 1             41838           1093  648518346349523993        298096
# 2             43992           1141  648518346349523993        285592
# 3             46262           2157  648518346349523993        283832
# 4             42902            946  648518346349523993        283728
# ...             ...            ...                 ...           ...
# 1132          45356           1635  648518346349492197        207224
# 1133          38726           1212  648518346349492197        216336
# 1134          42622           1025  648518346349492197        250352
# 1135          41942           1412  648518346349492197        265296
# 1136          39922           1905  648518346349492197        262536
#
#       ctr_pos_y_nm  ctr_pos_z_nm  surface_area  complexityindex  \
# 0           180320         54560      2.716770        10.804325
# 1           166664         39360      6.773440        28.109598
# 2           175840         45560      0.102391         2.866273
# 3           181552         75640     11.790898        51.080975
# 4           169512         34640      6.168662        18.879337
# ...            ...           ...           ...              ...
# 1132        180848         64880      3.089287        10.412219
# 1133        154608         46560      4.573971        17.190795
# 1134        168632         20400     30.240936        79.372160
# 1135        165944         53280      7.230910        16.087532
# 1136        158328         73480      9.031828        14.244683
#
#             compartment  centroid_x  centroid_y  centroid_z  cell_type  \
# 0     Unknown dendritic       70864       42368          24  pyramidal
# 1     Unknown dendritic       70864       42368          24  pyramidal
# 2     Unknown dendritic       70864       42368          24  pyramidal
# 3     Unknown dendritic       70864       42368          24  pyramidal
# 4     Unknown dendritic       70864       42368          24  pyramidal
# ...                 ...         ...         ...         ...        ...
# 1132  Unknown dendritic       67920       39584        2148  pyramidal
# 1133  Unknown dendritic       67920       39584        2148  pyramidal
# 1134  Unknown dendritic       67920       39584        2148  pyramidal
# 1135  Unknown dendritic       67920       39584        2148  pyramidal
# 1136  Unknown dendritic       67920       39584        2148  pyramidal
#
#         cell_subtype  ctr_distance_to_soma  bbox_dir_x  bbox_dir_y  \
# 0     pyramidal cell           3029.110100        -782        -410
# 1     pyramidal cell           3848.376801       -2042        -450
# 2     pyramidal cell           2015.650019         -84         -60
# 3     pyramidal cell           3551.749569        -782       -1434
# 4     pyramidal cell            844.800568        -384       -1108
# ...              ...                   ...         ...         ...
# 1132  pyramidal cell          17076.652365       -1116        -314
# 1133  pyramidal cell          13902.221981       -1124        -148
# 1134  pyramidal cell           6143.186795       -5620        -898
# 1135  pyramidal cell           2613.556198        -672        -614
# 1136  pyramidal cell           2307.058950        -364        -542
#
#       bbox_dir_z  bbox_distance          cellid_str  centroid_y-ctr_y  \
# 0            -65     885.352472  648518346349523993             False
# 1           -190    2099.610440  648518346349523993              True
# 2             -6     103.402128  648518346349523993             False
# 3           -495    1706.723469  648518346349523993             False
# 4           -161    1183.655778  648518346349523993             False
# ...          ...            ...                 ...               ...
# 1132         -25    1159.602087  648518346349492197             False
# 1133         -92    1137.428679  648518346349492197              True
# 1134        -951    5770.199737  648518346349492197             False
# 1135        -142     921.273032  648518346349492197             False
# 1136        -149     669.672308  648518346349492197              True
#
#       dist_to_soma_thresh_1500  above_soma  within_threshold_1500  \
# 0                        False           0                      0
# 1                        False           1                      0
# 2                        False           0                      0
# 3                        False           0                      0
# 4                         True           0                      1
# ...                        ...         ...                    ...
# 1132                     False           0                      0
# 1133                     False           1                      0
# 1134                     False           0                      0
# 1135                     False           0                      0
# 1136                     False           1                      0
#
#       new_ctr_pos_x_vx  new_ctr_pos_y_vx  new_ctr_pos_z_vx  \
# 0                 -158              2712              1340
# 1                 3660              -702               960
# 2                  534              1592              1115
# 3                   94              3020              1867
# 4                   68                10               842
# ...                ...               ...               ...
# 1132            -16114              5628              -526
# 1133            -13836              -932              -984
# 1134             -5332              2574             -1638
# 1135             -1596              1902              -816
# 1136             -2286                -2              -311
#
#       mito_ctr_radius_to_normal_for_theta45  radius_adj_ylength_theta45  \
# 0                               1349.282772                     -2712.0
# 1                               3783.807606                       702.0
# 2                               1236.277073                     -1592.0
# 3                               1869.364865                     -3020.0
# 4                                844.741381                       -10.0
# ...                                     ...                         ...
# 1132                           16122.582672                     -5628.0
# 1133                           13870.946327                       932.0
# 1134                            5577.926855                     -2574.0
# 1135                            1792.504393                     -1902.0
# 1136                            2307.058083                         2.0
#
#       within_cone_theta45  count          mean           std  min  \
# 0                       0  196.0   6307.454632   5294.853299  0.0
# 1                       0  196.0   7566.268937   5808.272535  0.0
# 2                       0  196.0   6073.269636   5674.473901  0.0
# 3                       0  196.0   6512.100850   5110.648731  0.0
# 4                       0  196.0   6163.671139   6160.340209  0.0
# ...                   ...    ...           ...           ...  ...
# 1132                    0  190.0  20341.084297   9787.632079  0.0
# 1133                    0  190.0  18092.233043  10010.550310  0.0
# 1134                    0  190.0  10991.697855   8796.647867  0.0
# 1135                    0  190.0   8718.497145   8399.523429  0.0
# 1136                    0  190.0   8966.157154   8883.816402  0.0
#
#                25%           50%           75%           max  kurtosis  \
# 0      2791.498779   4378.841631   8158.576625  26607.713618  5.541097
# 1      3782.081357   5032.257927   9528.231655  27537.681311  4.937059
# 2      2294.075603   3740.158135   8079.002508  26774.752081  5.567801
# 3      3205.207022   4563.925525   8208.348254  26230.706376  5.448838
# 4      1504.873059   3839.307731   8101.049803  28171.214315  5.607736
# ...            ...           ...           ...           ...       ...
# 1132  15003.853240  17033.270424  25006.554119  51026.602758  2.268589
# 1133  12552.559723  14057.313489  22983.893509  48606.099628  2.794063
# 1134   5289.077021   6715.396244  14679.910696  40098.947779  4.698357
# 1135   2469.147283   5702.917607  12741.309694  36325.865895  4.853222
# 1136   2080.736502   5393.930585  13906.359825  37023.165127  4.493109
#
#           skew rfc_predicted_compartment
# 0     2.220513                     Basal
# 1     2.058686                     Basal
# 2     2.236830                     Basal
# 3     2.191350                     Basal
# 4     2.249625                     Basal
# ...        ...                       ...
# 1132  1.241689                     Basal
# 1133  1.424764                     Basal
# 1134  2.012254                     Basal
# 1135  2.070600                     Basal
# 1136  1.997676                     Basal
#
# [1137 rows x 51 columns]

# %%
unknown_dendritic_df.cellid_str.dtype
# Out:
# string[python]

# %%
list_of_cellids = unknown_dendritic_df.cellid.unique()
list_of_cellids
# Out:
# array([648518346349523993, 648518346349533350, 648518346349538475,
#        648518346349539845, 648518346349539864, 648518346349536748,
#        648518346349532067, 648518346349534360, 648518346349534614,
#        648518346349535102, 648518346349539097, 648518346349537047,
#        648518346349531254, 648518346349539890, 648518346349538133,
#        648518346349538157, 648518346349540048, 648518346349537071,
#        648518346349537513, 648518346349536809, 648518346349536679,
#        648518346349535192, 648518346349538235, 648518346349524971,
#        648518346349493472, 648518346349537883, 648518346349492197],
#       dtype=int64)

# %%
len(unknown_dendritic_df.cellid.unique())
# Out:
# 27

# %%
list_of_cellids[0]
# Out:
# 648518346349523993

# %%
unknown_dendritic_df.rfc_predicted_compartment.value_counts()
# Out:
# Basal     1005
# Apical     132
# Name: rfc_predicted_compartment, dtype: int64

# %% [markdown]
# # Look at mitos assigned to apical compartment

# %% [markdown]
# ### View all mito assigned to apical dendrite compartment by the random forest classifier in [Neuroglancer](https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.05%2C%22segments%22:%5B%22648518346349533350%22%2C%22648518346349534614%22%2C%22648518346349535102%22%2C%22648518346349537071%22%2C%22648518346349538157%22%2C%22648518346349538235%22%2C%22648518346349539845%22%2C%22648518346349539864%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%221299116%22%2C%221421155%22%2C%221421377%22%2C%221421392%22%2C%221421455%22%2C%221421579%22%2C%221534618%22%2C%221883096%22%2C%221884146%22%2C%221884228%22%2C%221890449%22%2C%221890626%22%2C%222010133%22%2C%222010351%22%2C%222010474%22%2C%222010681%22%2C%222010754%22%2C%222592629%22%2C%222592661%22%2C%222593432%22%2C%222708427%22%2C%222709775%22%2C%222817428%22%2C%222822118%22%2C%222824088%22%2C%222824625%22%2C%222825064%22%2C%222825184%22%2C%222826530%22%2C%222828087%22%2C%222828453%22%2C%222829461%22%2C%222933643%22%2C%222935817%22%2C%223044661%22%2C%223153502%22%2C%223153917%22%2C%223158686%22%2C%223273270%22%2C%223815340%22%2C%223815405%22%2C%223927566%22%2C%223927604%22%2C%224037974%22%2C%224042999%22%2C%224043085%22%2C%22639983%22%2C%22746709%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:1879.3613276615747%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D).

# %%
# generate df of apical assignments only
unknown_dendritic_df_apical = unknown_dendritic_df[unknown_dendritic_df.rfc_predicted_compartment == "Apical"]
unknown_dendritic_df_apical
# Out:
#        index  mito_id  mito_vx  ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  \
# 78      5468   313773   294760         46312         70488          2009
# 95     29567  3045291   215692         97982         40558          1740
# 102    29585  3151287    26956         98612         40932          1754
# 123    29673  3040095   293092         97762         38150          1697
# 124    29680  2928804   314388         96290         39078          1747
# ...      ...      ...      ...           ...           ...           ...
# 1025  160446  2249587   359592         81558         44676           425
# 1026  160450  2355422   376088         83516         37628          1558
# 1028  160458  2010351  1117792         78066         41002           432
# 1068  171885   645180    28928         54704         42496          1533
# 1069  172034   644148    32384         53800         42126          1509
#
#       bbox_beg_x_vx  bbox_beg_y_vx  bbox_beg_z_vx  bbox_end_x_vx  \
# 78            46012          70160           1980          46662
# 95            97616          40142           1729          98386
# 102           98536          40760           1752          98710
# 123           97412          37466           1686          98196
# 124           95502          38664           1735          97096
# ...             ...            ...            ...            ...
# 1025          81478          44466            379          81726
# 1026          83404          37214           1484          83834
# 1028          77370          39742            274          78960
# 1068          54576          42414           1529          54820
# 1069          53612          42080           1505          53980
#
#       bbox_end_y_vx  bbox_end_z_vx              cellid  ctr_pos_x_nm  \
# 78            70728           2050  648518346349538475        185248
# 95            41008           1758  648518346349539845        391928
# 102           41088           1758  648518346349539845        394448
# 123           38844           1717  648518346349539845        391048
# 124           39568           1756  648518346349539845        385160
# ...             ...            ...                 ...           ...
# 1025          44808            482  648518346349538235        326232
# 1026          38112           1640  648518346349538235        334064
# 1028          42120            558  648518346349538235        312264
# 1068          42568           1543  648518346349537883        218816
# 1069          42180           1514  648518346349537883        215200
#
#       ctr_pos_y_nm  ctr_pos_z_nm  surface_area  complexityindex  \
# 78          281952         80360      3.164271         8.786425
# 95          162232         69600      3.001009        13.997877
# 102         163728         70160      0.587449         6.722464
# 123         152600         67880      3.856246        16.084759
# 124         156312         69880      4.251701        18.736324
# ...            ...           ...           ...              ...
# 1025        178704         17000      3.597113         8.673021
# 1026        150512         62320      4.544635        15.989922
# 1028        164008         17280     12.208489        35.090694
# 1068        169984         61320      0.657421         8.181294
# 1069        168504         60360      0.627042         5.664446
#
#             compartment  centroid_x  centroid_y  centroid_z  cell_type  \
# 78    Unknown dendritic       55184       68480         664  pyramidal
# 95    Unknown dendritic      103776       47792        1558  pyramidal
# 102   Unknown dendritic      103776       47792        1558  pyramidal
# 123   Unknown dendritic      103776       47792        1558  pyramidal
# 124   Unknown dendritic      103776       47792        1558  pyramidal
# ...                 ...         ...         ...         ...        ...
# 1025  Unknown dendritic       79360       49648         822  pyramidal
# 1026  Unknown dendritic       79360       49648         822  pyramidal
# 1028  Unknown dendritic       79360       49648         822  pyramidal
# 1068  Unknown dendritic       57952       46672        1541  pyramidal
# 1069  Unknown dendritic       57952       46672        1541  pyramidal
#
#         cell_subtype  ctr_distance_to_soma  bbox_dir_x  bbox_dir_y  \
# 78    pyramidal cell           9195.296243        -650        -568
# 95    pyramidal cell           9270.076375        -770        -866
# 102   pyramidal cell           8588.650185        -174        -328
# 123   pyramidal cell          11364.668099        -784       -1378
# 124   pyramidal cell          11489.547989       -1594        -904
# ...              ...                   ...         ...         ...
# 1025  pyramidal cell           5450.651062        -248        -342
# 1026  pyramidal cell          12739.483192        -430        -898
# 1028  pyramidal cell           8750.991487       -1590       -2378
# 1068  pyramidal cell           5290.420021        -244        -154
# 1069  pyramidal cell           6156.804691        -368        -100
#
#       bbox_dir_z  bbox_distance          cellid_str  centroid_y-ctr_y  \
# 78           -70     866.039260  648518346349538475             False
# 95           -29    1159.179451  648518346349539845              True
# 102           -6     371.343507  648518346349539845              True
# 123          -31    1585.717819  648518346349539845              True
# 124          -21    1832.619164  648518346349539845              True
# ...          ...            ...                 ...               ...
# 1025        -103     434.829852  648518346349538235              True
# 1026        -156    1007.789661  648518346349538235              True
# 1028        -284    2874.654762  648518346349538235              True
# 1068         -14     288.873675  648518346349537883              True
# 1069          -9     381.451176  648518346349537883              True
#
#       dist_to_soma_thresh_1500  above_soma  within_threshold_1500  \
# 78                       False           0                      0
# 95                       False           1                      0
# 102                      False           1                      0
# 123                      False           1                      0
# 124                      False           1                      0
# ...                        ...         ...                    ...
# 1025                     False           1                      0
# 1026                     False           1                      0
# 1028                     False           1                      0
# 1068                     False           1                      0
# 1069                     False           1                      0
#
#       new_ctr_pos_x_vx  new_ctr_pos_y_vx  new_ctr_pos_z_vx  \
# 78               -8872              2008              1345
# 95               -5794             -7234               182
# 102              -5164             -6860               196
# 123              -6014             -9642               139
# 124              -7486             -8714               189
# ...                ...               ...               ...
# 1025              2198             -4972              -397
# 1026              4156            -12020               736
# 1028             -1294             -8646              -390
# 1068             -3248             -4176                -8
# 1069             -4152             -4546               -32
#
#       mito_ctr_radius_to_normal_for_theta45  radius_adj_ylength_theta45  \
# 78                              8973.372220                     -2008.0
# 95                              5796.857770                      7234.0
# 102                             5167.718259                      6860.0
# 123                             6015.606121                      9642.0
# 124                             7488.385474                      8714.0
# ...                                     ...                         ...
# 1025                            2233.565087                      4972.0
# 1026                            4220.667246                     12020.0
# 1028                            1351.493988                      8646.0
# 1068                            3248.009852                      4176.0
# 1069                            4152.123312                      4546.0
#
#       within_cone_theta45  count          mean          std  min  \
# 78                      0  495.0  11599.250222  6853.007805  0.0
# 95                      1  642.0  13062.490018  6617.366285  0.0
# 102                     1  642.0  12523.524826  6599.903876  0.0
# 123                     1  642.0  14924.317335  6717.756325  0.0
# 124                     1  642.0  14929.053670  6678.924980  0.0
# ...                   ...    ...           ...          ...  ...
# 1025                    1  648.0  11207.991814  7153.667542  0.0
# 1026                    1  648.0  16974.776374  7124.030645  0.0
# 1028                    1  648.0  14185.053319  7430.371987  0.0
# 1068                    1  449.0   9561.409868  7243.543511  0.0
# 1069                    1  449.0  10322.773457  7194.305012  0.0
#
#                25%           50%           75%           max  kurtosis  \
# 78     8468.537968   9719.433574  10670.613525  38069.386980  5.105471
# 95     8933.031075  10882.911386  16654.061757  36972.540838  3.181692
# 102    8316.253408  10208.780100  16082.233157  36420.221032  3.393828
# 123   10947.115617  12875.557203  17786.329430  39324.886586  2.803958
# 124   10965.523241  13047.798473  18117.643587  38932.472526  2.624631
# ...            ...           ...           ...           ...       ...
# 1025   5572.468289   9102.215511  15978.051785  31657.096140  2.639061
# 1026  12329.737344  14432.270863  21133.929822  38336.378650  1.345872
# 1028   8657.190007  11033.084550  19368.896145  36703.621633  2.197556
# 1068   5052.190812   6771.048072  11484.592853  38046.563905  5.576412
# 1069   5946.878509   7592.156479  12132.614557  38938.766455  5.396370
#
#           skew rfc_predicted_compartment
# 78    2.045749                    Apical
# 95    1.557461                    Apical
# 102   1.625073                    Apical
# 123   1.415260                    Apical
# 124   1.365204                    Apical
# ...        ...                       ...
# 1025  1.470660                    Apical
# 1026  0.975027                    Apical
# 1028  1.324026                    Apical
# 1068  2.217396                    Apical
# 1069  2.163556                    Apical
#
# [132 rows x 51 columns]

# %%
# how many mitos were assigned by the rfc to the apical compartment
len(unknown_dendritic_df_apical)
# Out:
# 132

# %%
# these mitos come from which cellids
unknown_dendritic_df_apical.cellid.unique()
# Out:
# array([648518346349538475, 648518346349539845, 648518346349539864,
#        648518346349534360, 648518346349534614, 648518346349535102,
#        648518346349531254, 648518346349538157, 648518346349536809,
#        648518346349536679, 648518346349535192, 648518346349538235,
#        648518346349537883], dtype=int64)

# %% [markdown]
# ## Original vs clean 125
#
# - Here are the cellids with the original dataset
# 648518346349533350, 648518346349539845, 648518346349539864,
# 648518346349534614, 648518346349535102, 648518346349538157,
# 648518346349537071, 648518346349538235
#
# - Here are the cellids with the clean 125 dataset
# 648518346349533350, 648518346349539845, 648518346349539864,
# 648518346349535102, 648518346349539097, 648518346349531254,
# 648518346349535192, 648518346349538235
#
# ### 648518346349534614, 648518346349538157, 648518346349537071 were id'd in the original as apical
# - these got dropped from apical assignment when trained with Clean 125
# - for 648518346349534614, there were 7 mitos in original that got id'd as apical and manual inspection showed basal; the remaining 72 mitos for this cellid were correctly classified as basal; now in the Clean 125, all 79 are correctly classified to basal
# - for 648518346349539845, in the original analysis, one mito id 3044661 was correctly assigned to apical and the remain 10 were incorrectly assigned basal; these 10 should have been classified as basal by manual inspection; this neuron had 171 mitos that were split between apical and basal (see below); with the Clean 125 training, no improvement was made in identifying the apical and basal, and in fact, lost the one mito above, so slight loss of accuracy
# - for 648518346349537071, this was one mito and Clean 125 got the assignment correct
#
# ### 648518346349539097, 648518346349531254, 648518346349535192 are new when training with clean 125
# - for 648518346349539097, Clean 125 pulled in 3 mito ids, these should have been classified as basal
# - for cellid 648518346349531254, two (out of 24) were pulled in by Clean 125, so slight improvement in accuracy but Clean 125 didn't pull in the remaining 22 true apicals
# - for cellid 648518346349535192, these two mitos should be basal, but Clean 125 called them apical so slight loss

# %% [markdown]
# ## Original vs within cone 45
#
# - Here are the cellids with the original dataset
# - These contained 48 mitos
#
# 648518346349533350, 648518346349539845, 648518346349539864,
# 648518346349534614, 648518346349535102, 648518346349538157,
# 648518346349537071, 648518346349538235
#
# - Here are the cellids for within cone 45
# - These contained 132 mitos
#
# 648518346349538475, 648518346349539845, 648518346349539864,
# 648518346349534360, 648518346349534614, 648518346349535102,
# 648518346349531254, 648518346349538157, 648518346349536809,
# 648518346349536679, 648518346349535192, 648518346349538235,
# 648518346349537883
#
# ### Same in both:
# - 648518346349539845: 16 mitos (3045291, 3151287, 3040095, 2928804, 3268978, 2928182, 3040180, 3045034, 3150973, 3155898, 3146767, 3151315, 3264327, 3039415, 3044661, 3264711) all got assigned to apical which is correct compartments; this was one of the problematic ones that the original couldn't solve;
# - **(16 CORRECT)**
# - 648518346349539864: 17 mito (2824502, 2716002, 2825060, 2825130, 2824088, 2817428, 2822118, 2829461, 2828087, 2825184, 2720277, 2824625, 2825146, 2825064, 2826530, 2828453, 2824911) all got assigned to apical; I scored this as basal but it is very close to the apical dendrite which makes it difficult to properly classify (because it "looks" like an apical dendrite);
# - **(17 INCORRECT)**
# - 648518346349534614: 10 mitos (4037974, 3815340, 3362842, 3703706, 3927566, 3815405, 3927604, 4043085, 3927379, 4042999); another difficult edge case, however I scored these as basal in the original analysis based on orientation of the process
# - **(10 INCORRECT)**
# - 648518346349535102: 2 mitos (2841877, 2593432) were orignally scored as basal in this edge case, based on orientation; note that these two mitos are in different basal dendrites -- both are at 0 degrees from the xz plane;
# - **(2 INCORRECT)**
# - 648518346349538157: 6 mitos (1421455, 1421392, 1421155, 1421377, 1534618, 1421579) were scored as apical; in the original analysis I determined the following mitos were basal (1421155, 1534618, 1421392, 1421579, 1421455, 1421377); both sets called these same mito to be apical but I score it as a basal process.
# - **(6 INCORRECT)**
# - 648518346349538235: 36 of 37 mitos (2131795, 2132530, 2254075, 1890626, 2249873, 2239853, 2010133, 2137636, 2472501, 1890449, 1884146, 2137607, 2135945, 2254127, 2010474, 2010681, 2254503, 2010754, 2254649, 2127620, 2481723, 2368012, 2254817, 1884228, 2250108, 2132502, 2131721, 1883096, , 2250463, 2249960, 2250317, 2254137, 2367180, 2249587, 2355422, 2010351) classified as apical in within cone 45; in the original I assigned the "left" as a basal dendrite and "right" as apical dendrite; most of these were correctly classified as apical, but there were a few mitos that should have been classified into the basal dendrite (1299116)
# - **(36 CORRECT 1 INCORRECT)**
#
# ### Was in original but not in within cone 45
# - 648518346349533350: in the original analysis, I classified this as basal, so this is correct here for within cone 45
# - 648518346349537071: in the original analysis, I said this needed to stay as unknown dendritic
#
# ### New to within cone 45
# - 648518346349538475: mito 313773 should have been assigned to basal
# - **(1 INCORRECT)**
# - 648518346349534360: 2 mitos (2122556, 2122260); in the original, I said this looks like an apical dendrite but it is hard to tell for sure due to edge; I recommended keeping this as unknown dendrite rather than classifying as either
# - **(2 INCORRECT)** (even though this is a special case)
# - 648518346349531254: in this neuron, I scored the "left" process as apical and the right process as basal; 5 of 7 mitos were correctly scored as apical (1890582, 1885913, 1891080, 2010520, 1886041); and 2/7 mitos 2010407, 2243337 should have been scored basal instead of apical
# - **(5 CORRECT 2 INCORRECT)**
# -  648518346349536809: 3 mitos (1197237, 1081467, 1075751) assigned apical but I scored this keep as unknown dendritic in the original analysis
# - **(3 INCORRECT)**
# - 648518346349536679: 20 mitos (974881, 1309292, 1187020, 1086152, 1187079, 1197826, 1308002, 1420168, 1421416, 1530291, 1308138, 1312472, 752087, 751611, 1307982, 1770295, 1085129, 1191964, 1651144, 1186954) assigned to apical compartment, which now appears to be classifying correctly as apical (in the original the classifier called this basal)
# - **(20 CORRECT)**
# - 648518346349535192: 9 mitos (1652268, 1651752, 1645991, 1652572, 1651570, 1652511, 1652479, 1646089, 1651573) classified as apical here; in the original I decided this was basal based on orientation but it is a difficult case due to being near the edge
# - **(9 INCORRECT)**
# - 648518346349537883: two mitos (645180, 644148) should be scored as basal; there were four mitos in the original that I score this as a basal process, even though it is truncated and very close to what appears to be the apical dendrite
# - **(2 INCORRECT)**
#
# ## Summary of apical compartment assignments in within cone 45 classifier
# ### correct 77/132 **(0.583)**
# ### incorrect 55/132 **(0.417)**

# %%
# how many cellids have mitos assigned to the apical compartment
len(unknown_dendritic_df_apical.cellid.unique())
# Out:
# 13

# %%
# generate a list of the mito ids that were assigned by the rfc to the apical compartment
unknown_dendritic_df_apical.mito_id.unique()
# Out:
# array([ 313773, 3045291, 3151287, 3040095, 2928804, 3268978, 2928182,
#        3040180, 3045034, 3150973, 3155898, 3146767, 3151315, 3264327,
#        3039415, 3044661, 3264711, 2824502, 2716002, 2825060, 2825130,
#        2824088, 2817428, 2822118, 2829461, 2828087, 2825184, 2720277,
#        2824625, 2825146, 2825064, 2826530, 2828453, 2824911, 2122556,
#        2122260, 4037974, 3815340, 3362842, 3703706, 3927566, 3815405,
#        3927604, 4043085, 3927379, 4042999, 2841877, 2593432, 1890582,
#        1885913, 2010407, 2243337, 1891080, 2010520, 1886041, 1421455,
#        1421392, 1421155, 1421377, 1534618, 1421579, 1197237, 1081467,
#        1075751,  974881, 1309292, 1187020, 1086152, 1187079, 1197826,
#        1308002, 1420168, 1421416, 1530291, 1308138, 1312472,  752087,
#         751611, 1307982, 1770295, 1085129, 1191964, 1651144, 1186954,
#        1652268, 1651752, 1645991, 1652572, 1651570, 1652511, 1652479,
#        1646089, 1651573, 2131795, 2132530, 2254075, 1890626, 2249873,
#        2239853, 2010133, 2137636, 2472501, 1890449, 1884146, 2137607,
#        2135945, 2254127, 2010474, 2010681, 2254503, 2010754, 2254649,
#        2127620, 2481723, 2368012, 2254817, 1884228, 2250108, 2132502,
#        2131721, 1883096, 1299116, 2250463, 2249960, 2250317, 2254137,
#        2367180, 2249587, 2355422, 2010351,  645180,  644148], dtype=int64)

# %%
# math check
len(unknown_dendritic_df_apical.mito_id.unique())
# Out:
# 132

# %% [markdown]
# ## Reveal apical assignments in Neuroglancer by cellid
# This is used to manually verify if the rfc was correct in its assignment
# There are 8 cellids associated with these apical assignments
# Manually change cellid_iloc from 0 to 7 to view each neuron one by one
#
# ## Original vs clean 125 training set
# There were 48 mitos assigned to apical in the original training set
# There were 96 mitos (double) assigned to apical when the clean 125 was used for training
#
# ## Original vs within cone 45 training set
# There were 48 mitos assigned to apical in the original training set
# There were 132 mitos assigned to apical in the within cone 45 set

# %%
cellid_iloc = 1

list_of_cellids = unknown_dendritic_df_apical.cellid.unique()
mito = unknown_dendritic_df_apical
lookup = list_of_cellids[cellid_iloc]
query = mito[mito["cellid"] == lookup]
query_list = query["mito_id"].to_list()
spacer = "%22%2C%22"
query_list_join = spacer.join(map(str,query_list))
baseURL = 'https://neuromancer-seung-import.appspot.com/'
nglink_a = '#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22'
nglink_b = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%22'
nglink_c = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D'
neuroglancerURL = baseURL + nglink_a + str(lookup) + nglink_b + query_list_join + nglink_c
print(neuroglancerURL)
# Out:
# https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349539845%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%223045291%22%2C%223151287%22%2C%223040095%22%2C%222928804%22%2C%223268978%22%2C%222928182%22%2C%223040180%22%2C%223045034%22%2C%223150973%22%2C%223155898%22%2C%223146767%22%2C%223151315%22%2C%223264327%22%2C%223039415%22%2C%223044661%22%2C%223264711%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D

# %%
# how many mitos that were classified as belonging to the apical compartment are in this cell
len(query_list)
# Out:
# 16

# %%
list_of_cellids[cellid_iloc]
# Out:
# 648518346349539845

# %%
print(query_list)
# Out:
# [3045291, 3151287, 3040095, 2928804, 3268978, 2928182, 3040180, 3045034, 3150973, 3155898, 3146767, 3151315, 3264327, 3039415, 3044661, 3264711]

# %%
# query

# %% [markdown]
# ## Check in Neuroglancer for difficult to verify cases (apical version)
# Use this to visualize mitos compartment assignments as performed by the Turner et al Cell 2022 dataset

# %%
# Generate ng view for cellid ids of interest
# This was used for further inspection of the following cellids, which were more difficult to manually verify
# 648518346349539864; I classified this as a basal dendrite; it is very close to the apical dendrite which made it difficult to classify properly
# 648518346349538157; this should be classified as basal not apical; also of note is that this dendrite has most of its mito segmented as soma mitos (but clearly are not); this would be an errorenous assignment in the original dataset by Turner et al.

cellid_of_interest = 648518346349538157
mitoabovesoma = pd.read_csv('../data/mito_above_soma.csv', index_col=[0])
mitoabovesoma_basal = mitoabovesoma[mitoabovesoma['compartment'] == 'Basal']
mitoabovesoma_apical = mitoabovesoma[mitoabovesoma['compartment'] == 'Apical']
mitoabovesoma_somatic = mitoabovesoma[mitoabovesoma['compartment'] == 'Somatic']
mitoabovesoma_unknowndendritic = mitoabovesoma[mitoabovesoma['compartment'] == 'Unknown dendritic']
mitoabovesoma_unknown = mitoabovesoma[mitoabovesoma['compartment'] == 'Unknown']
mitoabovesoma_axonal = mitoabovesoma[mitoabovesoma['compartment'] == 'Axonal']

# %%
# enter the compartment of interest in the line below; choose 'mitoabovesoma' for all compartments
mito = mitoabovesoma_somatic

lookup = cellid_of_interest
query = mito[mito["cellid"] == lookup]
query_list = query["mito_id"].to_list()
spacer = "%22%2C%22"
query_list_join = spacer.join(map(str,query_list))
baseURL = 'https://neuromancer-seung-import.appspot.com/'
nglink_a = '#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22'
nglink_b = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%22'
nglink_c = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D'
neuroglancerURL = baseURL + nglink_a + str(lookup) + nglink_b + query_list_join + nglink_c
print(neuroglancerURL)
# Out:
# https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349538157%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%221545807%22%2C%221549780%22%2C%221657186%22%2C%221545808%22%2C%221550011%22%2C%221541406%22%2C%221540624%22%2C%221540947%22%2C%22855543%22%2C%221550127%22%2C%221656170%22%2C%221298821%22%2C%221540184%22%2C%221656314%22%2C%221540393%22%2C%221539872%22%2C%221541207%22%2C%221421649%22%2C%221545291%22%2C%22964783%22%2C%221545778%22%2C%221544403%22%2C%221541416%22%2C%221545412%22%2C%221664609%22%2C%221660174%22%2C%221540316%22%2C%221540911%22%2C%221661144%22%2C%221544364%22%2C%221541304%22%2C%221549564%22%2C%221544546%22%2C%221544362%22%2C%221545298%22%2C%221421394%22%2C%221541007%22%2C%221544953%22%2C%221774515%22%2C%221657128%22%2C%221656260%22%2C%221545734%22%2C%221545333%22%2C%221541464%22%2C%221661234%22%2C%221544620%22%2C%221544415%22%2C%221668364%22%2C%221545216%22%2C%221661305%22%2C%221545313%22%2C%221545002%22%2C%221660243%22%2C%221545169%22%2C%221540706%22%2C%221421522%22%2C%221433884%22%2C%221544811%22%2C%221660932%22%2C%221545373%22%2C%221544766%22%2C%221541179%22%2C%221661222%22%2C%221661149%22%2C%221545711%22%2C%221656957%22%2C%221541162%22%2C%221657306%22%2C%221545021%22%2C%221657382%22%2C%221660248%22%2C%221774398%22%2C%221774136%22%2C%22854153%22%2C%221657333%22%2C%221540429%22%2C%221545743%22%2C%221541208%22%2C%221661021%22%2C%221656086%22%2C%221545147%22%2C%221421511%22%2C%221545266%22%2C%221549475%22%2C%221540782%22%2C%221545323%22%2C%221661540%22%2C%221304243%22%2C%221660085%22%2C%221544796%22%2C%221661336%22%2C%221660186%22%2C%221661422%22%2C%221545016%22%2C%221540789%22%2C%221420617%22%2C%221545059%22%2C%221660591%22%2C%221541096%22%2C%221660885%22%2C%221661319%22%2C%221297705%22%2C%221544602%22%2C%221544661%22%2C%221656679%22%2C%221540041%22%2C%221540282%22%2C%221541480%22%2C%221545155%22%2C%221539913%22%2C%221544753%22%2C%221544856%22%2C%221548145%22%2C%221548872%22%2C%221656877%22%2C%221545636%22%2C%221438595%22%2C%221540865%22%2C%221545396%22%2C%221661050%22%2C%221660910%22%2C%221661466%22%2C%221656266%22%2C%221433833%22%2C%221656494%22%2C%221544944%22%2C%221660077%22%2C%221774098%22%2C%221540565%22%2C%22637504%22%2C%221549272%22%2C%221544380%22%2C%221540761%22%2C%221544642%22%2C%221545590%22%2C%221660677%22%2C%221433942%22%2C%221550085%22%2C%221774140%22%2C%221545541%22%2C%221544389%22%2C%221784596%22%2C%221545432%22%2C%221545397%22%2C%221774980%22%2C%221656441%22%2C%221655983%22%2C%221660637%22%2C%221544237%22%2C%221660519%22%2C%221660153%22%2C%221540701%22%2C%221544912%22%2C%221541261%22%2C%221549132%22%2C%221540262%22%2C%221544358%22%2C%221541249%22%2C%221544994%22%2C%221433230%22%2C%221656741%22%2C%221655515%22%2C%221539929%22%2C%221548350%22%2C%221549107%22%2C%221664701%22%2C%221657346%22%2C%221661293%22%2C%221660102%22%2C%221544480%22%2C%221656737%22%2C%221656089%22%2C%221661281%22%2C%221545062%22%2C%221544628%22%2C%221661048%22%2C%221774288%22%2C%221549690%22%2C%221656711%22%2C%221534601%22%2C%221545440%22%2C%221549480%22%2C%221549649%22%2C%221545676%22%2C%221655547%22%2C%221657005%22%2C ...

# %% [markdown]
# ## Results of manual validation of apical assignments

# %% [markdown]
# ## Original
# 11/48 (0.229) classified as apical were true apical upon manual validation
# 37/48 (0.771) classified as apical were actually basal dendrites as determined by manual inspection

# %%
# original results are below
# the manual inspection was tabulated in Excel, exported to csv in the file below
#manual_validation_apical = pd.read_csv('round1_rfc_assignment_manual_validation_apical.csv')
#manual_validation_apical

# %%
# enter iloc value of interest if you wish to pull up the neuroglancer view for a row of interest
#iloc_value = 5
#print(manual_validation_apical.ng_link[iloc_value])

# %% [markdown]
# # Look at mitos assigned to basal compartment original analysis
# This is a much large list of mitos (n = 1089)
#
# # Clean 125
# This is a list of 1041; so 1089 - 1041 = 48 additional mitos got assignmented to apical instead of basal when using the Clean 125 training set
#
# ## Original vs within cone 45 training set
# There were 1089 mitos assigned to basal in the original training set
# There were 1005 mitos assigned to basal in the within cone 45 set
#
# - 648518346349523993: 40 mitos all correctly assigned to basal (this is an edge case which I am call all processes as basal based on orientation)
# - **(40 CORRECT)**
# - 648518346349533350 15 mitos all correctly assigned to basal
# - **(15 CORRECT)**
# - 648518346349538475 32 all correct
# - **(32 CORRECT)**
# - 648518346349539845: these 31 mitos (3156851, 2396394, 3049781, 3160223, 3053944, 3164597, 3156380, 2618034, 2508530, 2937928, 3268755, 3160838, 3268924, 2953478, 2395545, 2733190, 3061350, 3160012, 2846190, 2512383, 3269003, 2508540, 3164603, 2509043, 3062189, 3062418, 3160144, 3159857, 2938493, 3160540, 2400006) should have been assigned basal
# - **(31 INCORRECT)**
# - 648518346349539845: these 125 mitos were correctly assigned to basal; although just as in the original analysis, there are a dozen or so that should be classified as soma to begin with (this is an error in the Turner segmentation)
# - **(125 CORRECT)**
# - 648518346349539864: 15 mito all correct (even though this process is very close to apical)
# - **(15 CORRECT)**
# - 648518346349536748: 16 mito same issue as original analysis; these look like they could be axonal but hard to tell for certain; decision was to keep as 'unknown dendritic'
# - **(16 INCORRECT)**
# - 648518346349532067 9 mito -- identical analysis as in original -- this looks like an axon hillock but hard to known for sure; decision was to keep as 'unknown dendritic'
# - **(9 INCORRECT)**
# - 648518346349534614: 69 mitos correctly identified as basal (I determined this was basal by orientation even though this is an edge case
# - **(69 CORRECT)**
# - 648518346349535102: 57 mitos correct, even though this is an edge case
# - **(57 CORRECT)**
# - 648518346349539097: 80 mitos correct (based on orientation)
# - **(80 CORRECT)**
# - 648518346349537047 3 mitos correct (could be axon hillock but looks more like basal dendr)
# - **(3 CORRECT)**
# - 648518346349531254: 72 mitos -- these 19 mitos should have been classified as apical (1768668, 1773075, 1189911, 1778442, 1650211, 1778402, 1301533, 1891420, 1190204, 1772953, 1300841, 1299977, 1767137, 1648586, 1891196, 1648967, 1777820, 1533066, 1417199)
# - **(19 INCORRECT)**
# - these 53 mitos were correctly classified as basal by withincone45 analysis (3591662, 2245089, 3481010, 2243067, 3591624, 3481657, 2131044,
# 2484183, 2243516, 2359891, 2359574, 2361621, 2131052, 2243340, 2372677, 2372434, 2706882, 2825268, 2591923, 2243111, 2131054, 2130989, 2246789, 3263377, 2238180, 2232805, 2598246, 2130947, 2246159, 2245034, 2238455, 2010839, 2245938, 2608611, 2238315,
# 2728528, 2127971, 2251186, 2478162, 2130782, 2824951, 3370551, 2246163, 2251264, 3369210, 2607782, 2245148, 3153590, 2128360,
# 2245823, 2705507, 2475672, 2244740)
# - **(53 CORRECT)**
# - 648518346349539890: 93 mitos same result as in the original analysis -- this looks like it should be apical but the process is turned 90 degree on its side
# - **(93 INCORRECT)** But not the fault of the classifier!
# - 648518346349538133: 25 mitos correct
# - **(25 CORRECT)**
# - 648518346349540048: 30 mitos correct
# - **(30 CORRECT)**
# - 648518346349537071: 12 mitos; decision in original was to keep this as unknown dendritic even though it looks like it could be basal
# - **(12 INCORRECT)** (Special case)
# - 648518346349537513: 13 mitos; same as above; decision was to keep as unknown dendritic
# - **(13 INCORRECT)** (Special case)
# - 648518346349536809: 52 mitos (55 in original); same as above; decision to keep as unknown dendritic
# - **(52 INCORRECT)**
# - 648518346349536679: 12 mitos should have been classified as apical; one mito 1884059 was correctly classified as basal
# - **(1 CORRECT 12 INCORRECT)**
# - 648518346349535192: 38 mitos correctly classified as basal
# - **(38 CORRECT)**
# - 648518346349538235: 61 mitos; these 40 mitos were correctly identified as basal (1085740, 1426237, 1430335, 1784076, 1550799, 1783920, 546333, 1788475, 1548987, 1789919, 745428, 854181, 745743, 1294492, 1430283, 1313348, 1671612, 746186, 1789310, 1427974, 974567, 1671421, 1429058, 1427492, 1429169, 1423267, 1548754, 649815, 746709, 1430744, 1301081, 1430191, 867111, 1671719, 1665919, 1549392, 545202, 1200700, 1670409, 1664841)
# - **(40 CORRECT)**
# - these 21 mitos were incorrectly assigned to basal and should be apical (2364459, 3376180, 2711495, 3489544, 2361537, 2706638, 2591502, 3157827, 2940168, 2480439, 2591330, 3158855, 3714251, 2705414, 2590705, 2361375, 3600599, 2828667, 2366385, 2480572, 2594972)
# - **(21 INCORRECT)**
# - 648518346349524971: 7 mitos correctly identified as basal
# - **(7 CORRECT)**
# - 648518346349493472: 29 mitos correct
# - **(29 CORRECT)**
# - 648518346349537883: 2 mitos correct
# - **(2 CORRECT)**
# - 648518346349492197: 66 mitos correct
# - **(66 CORRECT)**
#
# ### 727/1005 (0.723) CORRECT
# ### 278/1005 (0.277) INCORRECT

# %%
# generate df of basal assignments only
unknown_dendritic_df_basal = unknown_dendritic_df[unknown_dendritic_df.rfc_predicted_compartment == "Basal"]
unknown_dendritic_df_basal
# Out:
#        index  mito_id  mito_vx  ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  \
# 0          4  1547760   211468         70706         45080          1364
# 1         11  1774335   516120         74524         41666           984
# 2         12  1662490     3004         71398         43960          1139
# 3         15  1547394   879336         70958         45388          1891
# 4         21  1541327   547340         70932         42378           866
# ...      ...      ...      ...           ...           ...           ...
# 1132  182307   545422   261204         51806         45212          1622
# 1133  182312   633845   366232         54084         38652          1164
# 1134  182313   973784  2897496         62588         42158           510
# 1135  182316  1310832   752504         66324         41486          1332
# 1136  182317  1305695  1116352         65634         39582          1837
#
#       bbox_beg_x_vx  bbox_beg_y_vx  bbox_beg_z_vx  bbox_end_x_vx  \
# 0             70248          44874           1328          71030
# 1             73392          41388            903          75434
# 2             71356          43932           1135          71440
# 3             70558          44828           1662          71340
# 4             70804          41794            785          71188
# ...             ...            ...            ...            ...
# 1132          51278          45042           1610          52394
# 1133          53490          38578           1120          54614
# 1134          59768          41724             74          65388
# 1135          66142          41328           1270          66814
# 1136          65510          39380           1756          65874
#
#       bbox_end_y_vx  bbox_end_z_vx              cellid  ctr_pos_x_nm  \
# 0             45284           1393  648518346349523993        282824
# 1             41838           1093  648518346349523993        298096
# 2             43992           1141  648518346349523993        285592
# 3             46262           2157  648518346349523993        283832
# 4             42902            946  648518346349523993        283728
# ...             ...            ...                 ...           ...
# 1132          45356           1635  648518346349492197        207224
# 1133          38726           1212  648518346349492197        216336
# 1134          42622           1025  648518346349492197        250352
# 1135          41942           1412  648518346349492197        265296
# 1136          39922           1905  648518346349492197        262536
#
#       ctr_pos_y_nm  ctr_pos_z_nm  surface_area  complexityindex  \
# 0           180320         54560      2.716770        10.804325
# 1           166664         39360      6.773440        28.109598
# 2           175840         45560      0.102391         2.866273
# 3           181552         75640     11.790898        51.080975
# 4           169512         34640      6.168662        18.879337
# ...            ...           ...           ...              ...
# 1132        180848         64880      3.089287        10.412219
# 1133        154608         46560      4.573971        17.190795
# 1134        168632         20400     30.240936        79.372160
# 1135        165944         53280      7.230910        16.087532
# 1136        158328         73480      9.031828        14.244683
#
#             compartment  centroid_x  centroid_y  centroid_z  cell_type  \
# 0     Unknown dendritic       70864       42368          24  pyramidal
# 1     Unknown dendritic       70864       42368          24  pyramidal
# 2     Unknown dendritic       70864       42368          24  pyramidal
# 3     Unknown dendritic       70864       42368          24  pyramidal
# 4     Unknown dendritic       70864       42368          24  pyramidal
# ...                 ...         ...         ...         ...        ...
# 1132  Unknown dendritic       67920       39584        2148  pyramidal
# 1133  Unknown dendritic       67920       39584        2148  pyramidal
# 1134  Unknown dendritic       67920       39584        2148  pyramidal
# 1135  Unknown dendritic       67920       39584        2148  pyramidal
# 1136  Unknown dendritic       67920       39584        2148  pyramidal
#
#         cell_subtype  ctr_distance_to_soma  bbox_dir_x  bbox_dir_y  \
# 0     pyramidal cell           3029.110100        -782        -410
# 1     pyramidal cell           3848.376801       -2042        -450
# 2     pyramidal cell           2015.650019         -84         -60
# 3     pyramidal cell           3551.749569        -782       -1434
# 4     pyramidal cell            844.800568        -384       -1108
# ...              ...                   ...         ...         ...
# 1132  pyramidal cell          17076.652365       -1116        -314
# 1133  pyramidal cell          13902.221981       -1124        -148
# 1134  pyramidal cell           6143.186795       -5620        -898
# 1135  pyramidal cell           2613.556198        -672        -614
# 1136  pyramidal cell           2307.058950        -364        -542
#
#       bbox_dir_z  bbox_distance          cellid_str  centroid_y-ctr_y  \
# 0            -65     885.352472  648518346349523993             False
# 1           -190    2099.610440  648518346349523993              True
# 2             -6     103.402128  648518346349523993             False
# 3           -495    1706.723469  648518346349523993             False
# 4           -161    1183.655778  648518346349523993             False
# ...          ...            ...                 ...               ...
# 1132         -25    1159.602087  648518346349492197             False
# 1133         -92    1137.428679  648518346349492197              True
# 1134        -951    5770.199737  648518346349492197             False
# 1135        -142     921.273032  648518346349492197             False
# 1136        -149     669.672308  648518346349492197              True
#
#       dist_to_soma_thresh_1500  above_soma  within_threshold_1500  \
# 0                        False           0                      0
# 1                        False           1                      0
# 2                        False           0                      0
# 3                        False           0                      0
# 4                         True           0                      1
# ...                        ...         ...                    ...
# 1132                     False           0                      0
# 1133                     False           1                      0
# 1134                     False           0                      0
# 1135                     False           0                      0
# 1136                     False           1                      0
#
#       new_ctr_pos_x_vx  new_ctr_pos_y_vx  new_ctr_pos_z_vx  \
# 0                 -158              2712              1340
# 1                 3660              -702               960
# 2                  534              1592              1115
# 3                   94              3020              1867
# 4                   68                10               842
# ...                ...               ...               ...
# 1132            -16114              5628              -526
# 1133            -13836              -932              -984
# 1134             -5332              2574             -1638
# 1135             -1596              1902              -816
# 1136             -2286                -2              -311
#
#       mito_ctr_radius_to_normal_for_theta45  radius_adj_ylength_theta45  \
# 0                               1349.282772                     -2712.0
# 1                               3783.807606                       702.0
# 2                               1236.277073                     -1592.0
# 3                               1869.364865                     -3020.0
# 4                                844.741381                       -10.0
# ...                                     ...                         ...
# 1132                           16122.582672                     -5628.0
# 1133                           13870.946327                       932.0
# 1134                            5577.926855                     -2574.0
# 1135                            1792.504393                     -1902.0
# 1136                            2307.058083                         2.0
#
#       within_cone_theta45  count          mean           std  min  \
# 0                       0  196.0   6307.454632   5294.853299  0.0
# 1                       0  196.0   7566.268937   5808.272535  0.0
# 2                       0  196.0   6073.269636   5674.473901  0.0
# 3                       0  196.0   6512.100850   5110.648731  0.0
# 4                       0  196.0   6163.671139   6160.340209  0.0
# ...                   ...    ...           ...           ...  ...
# 1132                    0  190.0  20341.084297   9787.632079  0.0
# 1133                    0  190.0  18092.233043  10010.550310  0.0
# 1134                    0  190.0  10991.697855   8796.647867  0.0
# 1135                    0  190.0   8718.497145   8399.523429  0.0
# 1136                    0  190.0   8966.157154   8883.816402  0.0
#
#                25%           50%           75%           max  kurtosis  \
# 0      2791.498779   4378.841631   8158.576625  26607.713618  5.541097
# 1      3782.081357   5032.257927   9528.231655  27537.681311  4.937059
# 2      2294.075603   3740.158135   8079.002508  26774.752081  5.567801
# 3      3205.207022   4563.925525   8208.348254  26230.706376  5.448838
# 4      1504.873059   3839.307731   8101.049803  28171.214315  5.607736
# ...            ...           ...           ...           ...       ...
# 1132  15003.853240  17033.270424  25006.554119  51026.602758  2.268589
# 1133  12552.559723  14057.313489  22983.893509  48606.099628  2.794063
# 1134   5289.077021   6715.396244  14679.910696  40098.947779  4.698357
# 1135   2469.147283   5702.917607  12741.309694  36325.865895  4.853222
# 1136   2080.736502   5393.930585  13906.359825  37023.165127  4.493109
#
#           skew rfc_predicted_compartment
# 0     2.220513                     Basal
# 1     2.058686                     Basal
# 2     2.236830                     Basal
# 3     2.191350                     Basal
# 4     2.249625                     Basal
# ...        ...                       ...
# 1132  1.241689                     Basal
# 1133  1.424764                     Basal
# 1134  2.012254                     Basal
# 1135  2.070600                     Basal
# 1136  1.997676                     Basal
#
# [1005 rows x 51 columns]

# %%
# how many mitos were assigned by the rfc to the apical compartment
len(unknown_dendritic_df_basal)
# Out:
# 1005

# %%
# these mitos come from which cellids
unknown_dendritic_df_basal.cellid.unique()
# Out:
# array([648518346349523993, 648518346349533350, 648518346349538475,
#        648518346349539845, 648518346349539864, 648518346349536748,
#        648518346349532067, 648518346349534614, 648518346349535102,
#        648518346349539097, 648518346349537047, 648518346349531254,
#        648518346349539890, 648518346349538133, 648518346349540048,
#        648518346349537071, 648518346349537513, 648518346349536809,
#        648518346349536679, 648518346349535192, 648518346349538235,
#        648518346349524971, 648518346349493472, 648518346349537883,
#        648518346349492197], dtype=int64)

# %%
# how many cellids have mitos assigned to the apical compartment
len(unknown_dendritic_df_basal.cellid.unique())
# Out:
# 25

# %%
# generate a list of the mito ids that were assigned by the rfc to the apical compartment
unknown_dendritic_df_basal.mito_id.unique()
# Out:
# array([1547760, 1774335, 1662490, ...,  973784, 1310832, 1305695],
#       dtype=int64)

# %%
# math check
len(unknown_dendritic_df_basal.mito_id.unique())
# Out:
# 1005

# %% [markdown]
# ## Reveal basal assignments in Neuroglancer by cellid
# This is used to manually verify if the rfc was correct in its assignment
# There are 26 cellids associated with these basal assignments
# Manually change cellid_iloc from 0 to 25 to view each neuron one by one

# %%
cellid_iloc = 3

list_of_cellids = unknown_dendritic_df_basal.cellid.unique()
mito = unknown_dendritic_df_basal
lookup = list_of_cellids[cellid_iloc]
query = mito[mito["cellid"] == lookup]
query_list = query["mito_id"].to_list()
spacer = "%22%2C%22"
query_list_join = spacer.join(map(str,query_list))
baseURL = 'https://neuromancer-seung-import.appspot.com/'
nglink_a = '#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22'
nglink_b = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%22'
nglink_c = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D'
neuroglancerURL = baseURL + nglink_a + str(lookup) + nglink_b + query_list_join + nglink_c
print(neuroglancerURL)
# Out:
# https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349539845%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%223156851%22%2C%223941827%22%2C%224059787%22%2C%223496644%22%2C%223496814%22%2C%224040693%22%2C%224070614%22%2C%223496828%22%2C%224058480%22%2C%222396394%22%2C%223936768%22%2C%224075025%22%2C%223949395%22%2C%223955492%22%2C%224172529%22%2C%224168259%22%2C%223049781%22%2C%223496744%22%2C%223160223%22%2C%223833333%22%2C%224058467%22%2C%224076917%22%2C%223713885%22%2C%223053944%22%2C%223960607%22%2C%223164597%22%2C%223607698%22%2C%223496331%22%2C%223709135%22%2C%223847636%22%2C%223953813%22%2C%223717384%22%2C%223156380%22%2C%223496648%22%2C%222618034%22%2C%222508530%22%2C%224058387%22%2C%224061872%22%2C%224171321%22%2C%223720510%22%2C%224040773%22%2C%223822987%22%2C%223961936%22%2C%223721532%22%2C%223933854%22%2C%223496728%22%2C%223833910%22%2C%223933041%22%2C%223833749%22%2C%222937928%22%2C%223843033%22%2C%223833739%22%2C%223831054%22%2C%223704552%22%2C%223496572%22%2C%223831214%22%2C%224048890%22%2C%223834058%22%2C%223961840%22%2C%223496556%22%2C%223967554%22%2C%224171865%22%2C%223826826%22%2C%223831057%22%2C%224092057%22%2C%223833836%22%2C%223717535%22%2C%223953546%22%2C%224059263%22%2C%223268755%22%2C%223160838%22%2C%224199846%22%2C%223966607%22%2C%224086642%22%2C%223966618%22%2C%223268924%22%2C%224040792%22%2C%222953478%22%2C%224087211%22%2C%224190863%22%2C%222395545%22%2C%224058849%22%2C%222733190%22%2C%223948746%22%2C%223496570%22%2C%223061350%22%2C%223160012%22%2C%223822218%22%2C%223722165%22%2C%223704079%22%2C%224052194%22%2C%223722223%22%2C%223950619%22%2C%223496471%22%2C%223838063%22%2C%223721119%22%2C%222846190%22%2C%223843067%22%2C%223824410%22%2C%223822766%22%2C%224044162%22%2C%223822477%22%2C%223699039%22%2C%224087393%22%2C%222512383%22%2C%223269003%22%2C%224048786%22%2C%222508540%22%2C%224168007%22%2C%224205418%22%2C%223967536%22%2C%223817730%22%2C%223164603%22%2C%222509043%22%2C%223062189%22%2C%223496328%22%2C%223831125%22%2C%223704323%22%2C%224050856%22%2C%223956689%22%2C%223062418%22%2C%224048245%22%2C%224076106%22%2C%223721249%22%2C%223831115%22%2C%224157984%22%2C%223831150%22%2C%224080725%22%2C%223160144%22%2C%224058046%22%2C%223957233%22%2C%223159857%22%2C%223826388%22%2C%223953165%22%2C%223708831%22%2C%222938493%22%2C%224294603%22%2C%223947868%22%2C%223953792%22%2C%224189353%22%2C%224044134%22%2C%223825073%22%2C%223831031%22%2C%223831060%22%2C%223160540%22%2C%223842953%22%2C%223720705%22%2C%223961237%22%2C%224048125%22%2C%224087056%22%2C%222400006%22%2C%224092278%22%2C%223932008%22%2C%223820456%22%2C%223833033%22%2C%223830889%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordin ...

# %%
# how many mitos that were classified as belonging to the apical compartment are in this cell
len(query_list)
# Out:
# 156

# %%
lookup
# Out:
# 648518346349539845

# %%
# uncomment if you need a list of mito ids

np.array(query_list)
# Out:
# array([3156851, 3941827, 4059787, 3496644, 3496814, 4040693, 4070614,
#        3496828, 4058480, 2396394, 3936768, 4075025, 3949395, 3955492,
#        4172529, 4168259, 3049781, 3496744, 3160223, 3833333, 4058467,
#        4076917, 3713885, 3053944, 3960607, 3164597, 3607698, 3496331,
#        3709135, 3847636, 3953813, 3717384, 3156380, 3496648, 2618034,
#        2508530, 4058387, 4061872, 4171321, 3720510, 4040773, 3822987,
#        3961936, 3721532, 3933854, 3496728, 3833910, 3933041, 3833749,
#        2937928, 3843033, 3833739, 3831054, 3704552, 3496572, 3831214,
#        4048890, 3834058, 3961840, 3496556, 3967554, 4171865, 3826826,
#        3831057, 4092057, 3833836, 3717535, 3953546, 4059263, 3268755,
#        3160838, 4199846, 3966607, 4086642, 3966618, 3268924, 4040792,
#        2953478, 4087211, 4190863, 2395545, 4058849, 2733190, 3948746,
#        3496570, 3061350, 3160012, 3822218, 3722165, 3704079, 4052194,
#        3722223, 3950619, 3496471, 3838063, 3721119, 2846190, 3843067,
#        3824410, 3822766, 4044162, 3822477, 3699039, 4087393, 2512383,
#        3269003, 4048786, 2508540, 4168007, 4205418, 3967536, 3817730,
#        3164603, 2509043, 3062189, 3496328, 3831125, 3704323, 4050856,
#        3956689, 3062418, 4048245, 4076106, 3721249, 3831115, 4157984,
#        3831150, 4080725, 3160144, 4058046, 3957233, 3159857, 3826388,
#        3953165, 3708831, 2938493, 4294603, 3947868, 3953792, 4189353,
#        4044134, 3825073, 3831031, 3831060, 3160540, 3842953, 3720705,
#        3961237, 4048125, 4087056, 2400006, 4092278, 3932008, 3820456,
#        3833033, 3830889])

# %%
# uncomment to view dataframe of mitos

# query

# %% [markdown]
# ## Check in Neuroglancer for difficult to verify cases (basal version)
# Use this to visualize mitos compartment assignments as performed by the Turner et al Cell 2022 dataset

# %%
# Generate ng view for cellid ids of interest
# This was used for further inspection of the following cellids, which were more difficult to manually verify
# cellid 648518346349523993; this is an edge of volume neuron; the dendrites all appear to be basal based on non-vertical orientation but it is impossible to know for certain

cellid_of_interest = list_of_cellids[cellid_iloc] # or enter a specific cellid of interest
mitoabovesoma = pd.read_csv('../data/mito_above_soma.csv', index_col=[0])
mitoabovesoma_basal = mitoabovesoma[mitoabovesoma['compartment'] == 'Basal']
mitoabovesoma_apical = mitoabovesoma[mitoabovesoma['compartment'] == 'Apical']
mitoabovesoma_somatic = mitoabovesoma[mitoabovesoma['compartment'] == 'Somatic']
mitoabovesoma_unknowndendritic = mitoabovesoma[mitoabovesoma['compartment'] == 'Unknown dendritic']
mitoabovesoma_unknown = mitoabovesoma[mitoabovesoma['compartment'] == 'Unknown']
mitoabovesoma_axonal = mitoabovesoma[mitoabovesoma['compartment'] == 'Axonal']

# %%
# enter the compartment of interest in the line below; choose 'mitoabovesoma' for all compartments
# if you get a four-panel view in neuroglancer, that means that there is no mito assignments for that particular compartment
mito = mitoabovesoma_apical

lookup2 = cellid_of_interest
query2 = mito[mito["cellid"] == lookup2]
query_list2 = query2["mito_id"].to_list()
spacer = "%22%2C%22"
query_list_join2 = spacer.join(map(str,query_list2))
baseURL = 'https://neuromancer-seung-import.appspot.com/'
nglink_a = '#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22'
nglink_b = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%22'
nglink_c = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D'
neuroglancerURL = baseURL + nglink_a + str(lookup2) + nglink_b + query_list_join2 + nglink_c
print(neuroglancerURL)
# Out:
# https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349538235%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%22%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D

# %%
# uncomment if you need to look up data on the mito list

# query2

# %% [markdown]
# ## Results of manual validation of basal assignments

# %%
print('index '+str(cellid_iloc)+': cellid '+str(lookup)+'; number of mitos: '+str(len(query_list)))
# Out:
# index 21: cellid 648518346349538235; number of mitos: 86

# %% [markdown]
# ### All mito that are correctly classified as basal by the rfc prediction
# - index 0: cellid 648518346349523993; number of mitos: 40
# - index 1: cellid 648518346349533350; number of mitos: 11
# - index 2: cellid 648518346349538475; number of mitos: 33
# - index 4: cellid 648518346349539864; number of mitos: 22
# - index 8: cellid 648518346349534614; number of mitos: 72; edge of volume neuron, although these appear to all be correctly identified as basal, based on the orientation of the processes
# - index 9: cellid 648518346349535102; number of mitos: 52; ditto
# - index 10: cellid 648518346349539097; number of mitos: 80; ditto, appears to be basal based on orientation
# - index 11: cellid 648518346349537047; number of mitos: 3; could be an axon hillock but looks more likely to be a basal dendrite
# - index 14: cellid 648518346349538133; number of mitos: 25; edge of volume neuron but seems clearly basal by orientation
# - index 15: cellid 648518346349540048; number of mitos: 30; edge of volume neuron but seems clearly basal by orientation
# - index 20: cellid 648518346349535192; number of mitos: 47
# - index 22: cellid 648518346349524971; number of mitos: 7
# - index 23: cellid 648518346349493472; number of mitos: 29; very little of soma is present however, this seems clearly basal by orientation
# - index 24: cellid 648518346349537883; number of mitos: 4; this appears to be basal even though the process is truncated and very close to the apical dendrite
# - index 25: cellid 648518346349492197; number of mitos: 66; edge neuron, this appears to be basal based on downward orientation
#
# ### Total classifed as basal and are confirmed as basal: 521
# 40+11+33+22+72+52+80+3+25+30+47+7+29+4+66 =

# %% [markdown]
# ### Incorrect assignment to basal that should have been classified as apical
# - index 19: cellid 648518346349536679; number of mitos: 33; this appears to be an apical dendrite even though this neuron is near the volume edge; see in [Neuroglancer](https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349536679%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%221085129%22%2C%221086152%22%2C%221087784%22%2C%221186954%22%2C%221187020%22%2C%221187079%22%2C%221191964%22%2C%221197285%22%2C%221197452%22%2C%221197826%22%2C%221198898%22%2C%221307982%22%2C%221308002%22%2C%221308138%22%2C%221309292%22%2C%221312472%22%2C%221420168%22%2C%221421416%22%2C%221530291%22%2C%221651144%22%2C%221770295%22%2C%221884059%22%2C%22634451%22%2C%22750834%22%2C%22751611%22%2C%22752087%22%2C%22752228%22%2C%22853857%22%2C%22854537%22%2C%22966384%22%2C%22973324%22%2C%22974207%22%2C%22974881%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B65565.5703125%2C43397.0703125%2C327.09771728515625%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B0.025046376511454582%2C0.9582146406173706%2C-0.046196699142456055%2C0.2811819016933441%5D%2C%22perspectiveZoom%22:904.6914987128356%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D)
#
# ### Total classified as basal but are actually apical: 33

# %% [markdown]
# ### Difficult cases; these will likely need to remain classified as unknown dendritic
# - index 5: cellid 648518346349536748; number of mitos: 16; Morphologically, this process looks like it is an axon (it is branched from the putative axon hillock); the synapse visualizer shows that there are no pre-syn suggesting it is a dendrite but morphologically, it looks like an axon; this should not have been classified as 'unknown dendritic' by the Turner algorithm; see in [Neuroglancer](https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349536748%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%221110444%22%2C%221110781%22%2C%221226503%22%2C%221227495%22%2C%22551428%22%2C%22657839%22%2C%22657973%22%2C%22659171%22%2C%22659275%22%2C%22659488%22%2C%22771854%22%2C%22771933%22%2C%22772690%22%2C%22880563%22%2C%22880606%22%2C%22998238%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B56946.66015625%2C50561.671875%2C1721.8668212890625%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B0.062064070254564285%2C0.0353650264441967%2C-0.02572326734662056%2C0.9971136450767517%5D%2C%22perspectiveZoom%22:452.3457493564178%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22cell_segmentation_v185%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D)
# - index 6: cellid 648518346349532067; number of mitos: 9; An edge of the volume neuron; by orientation looks like an axon hillock but there is not enough of the process to determine if it is an axon or a basal dendrite; see in [Neuroglancer](https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349532067%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%224118518%22%2C%224240389%22%2C%224240391%22%2C%224240423%22%2C%224240472%22%2C%224240479%22%2C%224240494%22%2C%224240544%22%2C%224240545%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B116143.4453125%2C73643.15625%2C2108.47314453125%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22showAxisLines%22:false%2C%22perspectiveOrientation%22:%5B0.18531009554862976%2C-0.06271055340766907%2C-0.06994727998971939%2C0.978179395198822%5D%2C%22perspectiveZoom%22:854.3606298156484%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22cell_segmentation_v185%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D)
# - index 7: cellid 648518346349534360; number of mitos: 2; edge of volume; looks like an apical dendrite but hard to determine for certain; see in [Neuroglancer](https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349534360%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%222122260%22%2C%222122556%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83477.8359375%2C42423.28515625%2C1908.1787109375%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B0.0809904932975769%2C0.6224336624145508%2C-0.07208359241485596%2C0.7751263380050659%5D%2C%22perspectiveZoom%22:904.6914987128356%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D)
# - index 13: cellid 648518346349539890; number of mitos: 93; near the edge of the volume which complicates interpretation; looks like these should be basal dendrites by orientation, but the morphology of the cell suggests the process in question is the apical dendrite turned 90 degrees on its side; see in [Neuroglancer](https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349539890%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%221006282%22%2C%222021236%22%2C%222021333%22%2C%222021783%22%2C%222135928%22%2C%222135953%22%2C%222135954%22%2C%222136080%22%2C%222136156%22%2C%222136362%22%2C%222136420%22%2C%222136495%22%2C%222136590%22%2C%222136782%22%2C%222136995%22%2C%222137180%22%2C%222239838%22%2C%222251557%22%2C%222253984%22%2C%222254049%22%2C%222254379%22%2C%222254401%22%2C%222259029%22%2C%222259111%22%2C%222264219%22%2C%222352170%22%2C%222355691%22%2C%222361034%22%2C%222363756%22%2C%222364250%22%2C%222367216%22%2C%222368091%22%2C%222368496%22%2C%222368520%22%2C%222368979%22%2C%222369148%22%2C%222380590%22%2C%222385236%22%2C%222385603%22%2C%222386207%22%2C%222386378%22%2C%222390280%22%2C%222390334%22%2C%222396073%22%2C%222396587%22%2C%222401827%22%2C%222477607%22%2C%222481757%22%2C%222482709%22%2C%222483302%22%2C%222484670%22%2C%222485248%22%2C%222485468%22%2C%222486167%22%2C%222486265%22%2C%222489785%22%2C%222495101%22%2C%222496793%22%2C%222497170%22%2C%222500182%22%2C%222500410%22%2C%222502793%22%2C%222503262%22%2C%222508285%22%2C%222508645%22%2C%222522570%22%2C%222527848%22%2C%222585440%22%2C%222599600%22%2C%222599929%22%2C%222608454%22%2C%222621566%22%2C%222622100%22%2C%222622898%22%2C%222646013%22%2C%222722967%22%2C%222724242%22%2C%222726304%22%2C%222730059%22%2C%222730077%22%2C%222730236%22%2C%222730708%22%2C%222844858%22%2C%222955208%22%2C%223070115%22%2C%223070528%22%2C%223070859%22%2C%223071664%22%2C%223289499%22%2C%223289985%22%2C%223290929%22%2C%223397519%22%2C%22888340%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B82019.09375%2C45297.18359375%2C324.25726318359375%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B0.11960885673761368%2C0.9729101657867432%2C0.10051172226667404%2C0.17040212452411652%5D%2C%22perspectiveZoom%22:904.6914987128356%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D)
# - index 16: cellid 648518346349537071; number of mitos: 11; appears to be basal but not enough of soma to know
# - index 17: cellid 648518346349537513; number of mitos: 13; this looks like an axon process coming off of a basal dendrite instead of the soma; these mitos were classified as unknown dendritic, which is true if this is a dendrite, but it looks like an axon hillock coming off of a axon-carrying basal dendrite; see [Neuroglancer](https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349537513%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%221724749%22%2C%221724948%22%2C%221725308%22%2C%221725445%22%2C%221725469%22%2C%221846747%22%2C%221846859%22%2C%221852316%22%2C%221852441%22%2C%221852488%22%2C%221852507%22%2C%221852546%22%2C%221852659%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B72041.78125%2C70495.5859375%2C1970.5035400390625%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22showAxisLines%22:false%2C%22perspectiveOrientation%22:%5B0.05819685757160187%2C-0.9912160634994507%2C0.0335722379386425%2C0.11391554772853851%5D%2C%22perspectiveZoom%22:452.3457493564178%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D)
# - index 18: cellid 648518346349536809; number of mitos: 55; edge of volume neuron; the process appears to be basal but hard to know for certain; see in [Neuroglancer](https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349536809%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%221073030%22%2C%221075751%22%2C%221078272%22%2C%221078803%22%2C%221079067%22%2C%221081467%22%2C%221085232%22%2C%221088514%22%2C%221089004%22%2C%221089497%22%2C%221093722%22%2C%221193911%22%2C%221194291%22%2C%221194472%22%2C%221194477%22%2C%221197237%22%2C%221197377%22%2C%221197816%22%2C%221201647%22%2C%221205828%22%2C%221306066%22%2C%221307583%22%2C%221307693%22%2C%221312362%22%2C%221312708%22%2C%221312716%22%2C%221313003%22%2C%221313531%22%2C%221425896%22%2C%221433259%22%2C%221434291%22%2C%221544548%22%2C%221544797%22%2C%221548236%22%2C%221548253%22%2C%221548291%22%2C%221548311%22%2C%221548544%22%2C%221548810%22%2C%221548818%22%2C%22542141%22%2C%22553648%22%2C%22554169%22%2C%22655383%22%2C%22660209%22%2C%22739777%22%2C%22746402%22%2C%22746584%22%2C%22854127%22%2C%22854899%22%2C%22873631%22%2C%22974454%22%2C%22978185%22%2C%22979636%22%2C%22984699%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B62731.19140625%2C46027.53125%2C370.08441162109375%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B0.0175847839564085%2C-0.7084158658981323%2C0.016393372789025307%2C0.7053857445716858%5D%2C%22perspectiveZoom%22:1127.027942857649%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D)

# %% [markdown]
# ### Summary of difficult cases
#
# ### 16 mitos (index 5) should be axon compartment (mistake by original Turner et al algorithm)
# - these mitos should be axon: 657973,  880606,  657839, 1227495,  880563, 1110781,  772690,
#         551428,  659488,  659171,  998238, 1110444, 1226503,  659275,
#         771854,  771933
# ###  9+13 = 22 mitos should be changed to unknown compartment
# - 9 mitos (index 6) and 13 (index 17) could be axon or dendrite so should be moved to "unknown" compartment
# - these mitos should be classified as unknown:
# - from index 6: cellid 648518346349532067: 4240479, 4240423, 4240494, 4240472, 4240545, 4240544, 4240389, 4240391, 4118518
# - from index 17: cellid 648518346349537513: 1852507, 1852441, 1725469, 1852659, 1852316, 1852546, 1724749, 1725445, 1846859, 1852488, 1724948, 1846747, 1725308
# ### 161 were impossible to determine so should remain as unknown dendrite
# - 2 + 93 + 11 + 55

# %% [markdown]
# ### Cells that require additional analysis; see next sections
# - index 3: cellid 648518346349539845; number of mitos: 171; About half are correctly classified as basal and the remaining belong to apical
# - index 12: cellid 648518346349531254; number of mitos: 79; one process is basal and one apical and it is difficult to determine which could be which
# - index 21: cellid 648518346349538235; number of mitos: 86; one process is basal and the other is apical

# %% [markdown]
# ### Additional processing of index 3: cellid 648518346349539845; number of mitos: 171

# %%
# analysis of index 3: cellid 648518346349539845; number of mitos: 171
# there are two processes with a good separation at x_position = 103,000
# a few of the mitochondria that should be classified as soma and not dendritic

index3_left = query[query['ctr_pos_x_vx'] < 103000] # This looks like the apical dendrite
index3_right = query[query['ctr_pos_x_vx'] >= 103000] # This looks like a basal dendrite with a few soma mito as well

# %%
# repeat of above cell for cellid 648518346349539845 using the withincone45 dataset

index3_left_45 = query[query['ctr_pos_x_vx'] < 103000] # This looks like the apical dendrite
index3_right_45 = query[query['ctr_pos_x_vx'] >= 103000] # This looks like a basal dendrite with a few soma mito as well

# %%
# isolate the mitos that should be classified as soma using 107000 threshold
index3_right_45_soma = index3_right_45[index3_right_45['ctr_pos_x_vx'] < 107000]
index3_right_45_basal = index3_right_45[index3_right_45['ctr_pos_x_vx'] >= 107000]

# %%
len(index3_left_45.mito_id.to_list())
# Out:
# 31

# %%
print(index3_left_45.mito_id.to_list())
# Out:
# [3156851, 2396394, 3049781, 3160223, 3053944, 3164597, 3156380, 2618034, 2508530, 2937928, 3268755, 3160838, 3268924, 2953478, 2395545, 2733190, 3061350, 3160012, 2846190, 2512383, 3269003, 2508540, 3164603, 2509043, 3062189, 3062418, 3160144, 3159857, 2938493, 3160540, 2400006]

# %%
len(index3_right_45_soma.mito_id.to_list())
# Out:
# 13

# %%
print(index3_right_45_soma.mito_id.to_list())
# Out:
# [3496644, 3496814, 3496828, 3496744, 3607698, 3496331, 3496648, 3496728, 3496572, 3496556, 3496570, 3496471, 3496328]

# %%
len(index3_right_45_basal.mito_id.to_list())
# Out:
# 112

# %%
print(index3_right_45_basal.mito_id.to_list())
# Out:
# [3941827, 4059787, 4040693, 4070614, 4058480, 3936768, 4075025, 3949395, 3955492, 4172529, 4168259, 3833333, 4058467, 4076917, 3713885, 3960607, 3709135, 3847636, 3953813, 3717384, 4058387, 4061872, 4171321, 3720510, 4040773, 3822987, 3961936, 3721532, 3933854, 3833910, 3933041, 3833749, 3843033, 3833739, 3831054, 3704552, 3831214, 4048890, 3834058, 3961840, 3967554, 4171865, 3826826, 3831057, 4092057, 3833836, 3717535, 3953546, 4059263, 4199846, 3966607, 4086642, 3966618, 4040792, 4087211, 4190863, 4058849, 3948746, 3822218, 3722165, 3704079, 4052194, 3722223, 3950619, 3838063, 3721119, 3843067, 3824410, 3822766, 4044162, 3822477, 3699039, 4087393, 4048786, 4168007, 4205418, 3967536, 3817730, 3831125, 3704323, 4050856, 3956689, 4048245, 4076106, 3721249, 3831115, 4157984, 3831150, 4080725, 4058046, 3957233, 3826388, 3953165, 3708831, 4294603, 3947868, 3953792, 4189353, 4044134, 3825073, 3831031, 3831060, 3842953, 3720705, 3961237, 4048125, 4087056, 4092278, 3932008, 3820456, 3833033, 3830889]

# %%
len(index3_left)
# Out:
# 31

# %%
len(index3_right)
# Out:
# 125

# %%
# Reveal index3_left in neuroglancer

cellid_iloc = 3

list_of_cellids = unknown_dendritic_df_basal.cellid.unique()
mito = unknown_dendritic_df_basal
lookup = list_of_cellids[cellid_iloc]
queryx = index3_right_45_basal #mito[mito["cellid"] == lookup] # remove _45 to go back to original dataset
query_listx = queryx["mito_id"].to_list()
spacer = "%22%2C%22"
query_list_joinx = spacer.join(map(str,query_listx))
baseURL = 'https://neuromancer-seung-import.appspot.com/'
nglink_a = '#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22'
nglink_b = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%22'
nglink_c = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D'
neuroglancerURL = baseURL + nglink_a + str(lookup) + nglink_b + query_list_joinx + nglink_c
#uncomment to show link: 
print(neuroglancerURL)
# Out:
# https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349539845%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%223941827%22%2C%224059787%22%2C%224040693%22%2C%224070614%22%2C%224058480%22%2C%223936768%22%2C%224075025%22%2C%223949395%22%2C%223955492%22%2C%224172529%22%2C%224168259%22%2C%223833333%22%2C%224058467%22%2C%224076917%22%2C%223713885%22%2C%223960607%22%2C%223709135%22%2C%223847636%22%2C%223953813%22%2C%223717384%22%2C%224058387%22%2C%224061872%22%2C%224171321%22%2C%223720510%22%2C%224040773%22%2C%223822987%22%2C%223961936%22%2C%223721532%22%2C%223933854%22%2C%223833910%22%2C%223933041%22%2C%223833749%22%2C%223843033%22%2C%223833739%22%2C%223831054%22%2C%223704552%22%2C%223831214%22%2C%224048890%22%2C%223834058%22%2C%223961840%22%2C%223967554%22%2C%224171865%22%2C%223826826%22%2C%223831057%22%2C%224092057%22%2C%223833836%22%2C%223717535%22%2C%223953546%22%2C%224059263%22%2C%224199846%22%2C%223966607%22%2C%224086642%22%2C%223966618%22%2C%224040792%22%2C%224087211%22%2C%224190863%22%2C%224058849%22%2C%223948746%22%2C%223822218%22%2C%223722165%22%2C%223704079%22%2C%224052194%22%2C%223722223%22%2C%223950619%22%2C%223838063%22%2C%223721119%22%2C%223843067%22%2C%223824410%22%2C%223822766%22%2C%224044162%22%2C%223822477%22%2C%223699039%22%2C%224087393%22%2C%224048786%22%2C%224168007%22%2C%224205418%22%2C%223967536%22%2C%223817730%22%2C%223831125%22%2C%223704323%22%2C%224050856%22%2C%223956689%22%2C%224048245%22%2C%224076106%22%2C%223721249%22%2C%223831115%22%2C%224157984%22%2C%223831150%22%2C%224080725%22%2C%224058046%22%2C%223957233%22%2C%223826388%22%2C%223953165%22%2C%223708831%22%2C%224294603%22%2C%223947868%22%2C%223953792%22%2C%224189353%22%2C%224044134%22%2C%223825073%22%2C%223831031%22%2C%223831060%22%2C%223842953%22%2C%223720705%22%2C%223961237%22%2C%224048125%22%2C%224087056%22%2C%224092278%22%2C%223932008%22%2C%223820456%22%2C%223833033%22%2C%223830889%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D

# %%
np.array(query_listx)
# Out:
# array([3156851, 2396394, 3049781, 3160223, 3053944, 3164597, 3156380,
#        2618034, 2508530, 2937928, 3268755, 3160838, 3268924, 2953478,
#        2395545, 2733190, 3061350, 3160012, 2846190, 2512383, 3269003,
#        2508540, 3164603, 2509043, 3062189, 3062418, 3160144, 3159857,
#        2938493, 3160540, 2400006])

# %% [markdown]
# #### These mito should be classified as apical (the rfc classifier was incorrect) n = 46
# 3156851, 3045291, 2396394, 3151287, 3049781, 3160223, 3053944,
# 3164597, 3156380, 3040095, 2928804, 2618034, 2508530, 3268978,
# 2928182, 2937928, 3040180, 3045034, 3268755, 3160838, 3150973,
# 3268924, 2953478, 2395545, 2733190, 3061350, 3155898, 3160012,
# 3146767, 2846190, 2512383, 3269003, 3151315, 2508540, 3164603,
# 2509043, 3062189, 3264327, 3062418, 3160144, 3039415, 3159857,
# 2938493, 3264711, 3160540, 2400006

# %%
index3_right
# Out:
#      mito_id  mito_vx  ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  \
# 89   3941827    58008        112768         46896          1432
# 90   4059787   101560        116470         45472          1512
# 91   3496644    52172        105706         48162          1551
# 92   3496814     5976        105806         48744          1549
# 93   4040693   268280        114690         41014          1026
# ..       ...      ...           ...           ...           ...
# 255  4092278   280284        114554         62612           839
# 256  3932008   648328        113792         42062          1520
# 257  3820456   340040        111628         42756          1544
# 258  3833033   390148        110210         48236          1293
# 259  3830889   506564        110254         47808           779
#
#      bbox_beg_x_vx  bbox_beg_y_vx  bbox_beg_z_vx  bbox_end_x_vx  \
# 89          112498          46816           1430         113024
# 90          116054          45360           1496         116880
# 91          105604          48120           1548         105834
# 92          105782          48724           1547         105838
# 93          114604          40722            966         114796
# ..             ...            ...            ...            ...
# 255         114470          61872            824         114660
# 256         112190          41446           1507         114994
# 257         111308          42688           1523         111968
# 258         110128          48162           1210         110306
# 259         110080          47698            654         110462
#
#      bbox_end_y_vx  bbox_end_z_vx              cellid  ctr_pos_x_nm  \
# 89           46946           1438  648518346349539845        451072
# 90           45556           1521  648518346349539845        465880
# 91           48212           1555  648518346349539845        422824
# 92           48766           1552  648518346349539845        423224
# 93           41474           1092  648518346349539845        458760
# ..             ...            ...                 ...           ...
# 255          63296            849  648518346349539845        458216
# 256          42632           1538  648518346349539845        455168
# 257          42816           1555  648518346349539845        446512
# 258          48336           1401  648518346349539845        440840
# 259          47924            922  648518346349539845        441016
#
#      ctr_pos_y_nm  ctr_pos_z_nm  surface_area  complexityindex  \
# 89         187584         57280      0.979014         6.719216
# 90         181888         60480      1.688904        11.253759
# 91         192648         62040      0.635454         2.271467
# 92         194976         61960      0.109632         0.889036
# 93         164056         41040      3.724692        17.299063
# ..            ...           ...           ...              ...
# 255        250448         33560      3.763039        16.343598
# 256        168248         60800      7.821484        27.428755
# 257        171024         61760      2.697519         4.090361
# 258        192944         51720      4.766243        17.139492
# 259        191232         31160      6.475675        25.498499
#
#            compartment  centroid_x  centroid_y  centroid_z  \
# 89   Unknown dendritic      103776       47792        1558
# 90   Unknown dendritic      103776       47792        1558
# 91   Unknown dendritic      103776       47792        1558
# 92   Unknown dendritic      103776       47792        1558
# 93   Unknown dendritic      103776       47792        1558
# ..                 ...         ...         ...         ...
# 255  Unknown dendritic      103776       47792        1558
# 256  Unknown dendritic      103776       47792        1558
# 257  Unknown dendritic      103776       47792        1558
# 258  Unknown dendritic      103776       47792        1558
# 259  Unknown dendritic      103776       47792        1558
#
#      ctr_distance_to_soma  bbox_dir_x  bbox_dir_y  bbox_dir_z  bbox_distance  \
# 89            9037.408699        -526        -130          -8     541.885597
# 90           12904.346245        -826        -196         -25     849.303833
# 91            1965.158772        -230         -92          -7     247.816464
# 92            2242.160788         -56         -42          -5      70.178344
# 93           12858.448740        -192        -752        -126     786.284936
# ..                    ...         ...         ...         ...            ...
# 255          18338.883417        -190       -1424         -25    1436.837152
# 256          11539.263408       -2804       -1186         -31    3044.663036
# 257           9328.204329        -660        -128         -32     673.058690
# 258           6454.743759        -178        -174        -191     313.753088
# 259           6524.690108        -382        -226        -268     518.482401
#
#      above_soma  within_threshold_1500  count          mean          std  min  \
# 89            1                      0  642.0  11570.545512  6548.159019  0.0
# 90            1                      0  642.0  14761.295282  6934.517695  0.0
# 91            0                      0  642.0   7501.190497  6366.899743  0.0
# 92            0                      0  642.0   7533.230618  6222.727719  0.0
# 93            1                      0  642.0  15233.454089  7220.703687  0.0
# ..          ...                    ...    ...           ...          ...  ...
# 255           0                      0  642.0  18205.335779  5723.499894  0.0
# 256           1                      0  642.0  14045.128241  7135.237479  0.0
# 257           1                      0  642.0  12317.413612  6954.725800  0.0
# 258           0                      0  642.0   9700.647440  6171.250549  0.0
# 259           0                      0  642.0   9780.746025  6247.330580  0.0
#
#               25%           50%           75%           max  kurtosis  \
# 89    7678.267110   9756.752456  14578.065405  33382.562514  3.411755
# 90   11242.210001  13473.665405  17953.187097  36914.161632  2.218695
# 91    2495.532744   5441.356462  11124.413910  27724.700918  4.278167
# 92    2678.658577   5587.393721  11190.185308  27291.483379  4.168325
# 93   11539.048909  13575.126705  17991.711379  36490.191408  2.035260
# ..            ...           ...           ...           ...       ...
# 255  16328.190172  17944.399059  20336.594034  41641.105377  1.294816
# 256  10221.147237  12277.337954  16942.633897  35292.385255  2.414222
# 257   8178.818917  10179.631312  15274.698356  33021.458190  2.937324
# 258   5715.933399   7600.746286  12458.688965  31284.166107  4.205628
# 259   5799.457059   7654.945619  12687.672057  31214.886977  4.092422
#
#          skew rfc_predicted_compartment          cellid_str
# 89   1.609587                     Basal  648518346349539845
# 90   1.212875                     Basal  648518346349539845
# 91   1.930296                     Basal  648518346349539845
# 92   1.901264                     Basal  648518346349539845
# 93   1.137291                     Basal  648518346349539845
# ..        ...                       ...                 ...
# 255  0.897342                     Basal  648518346349539845
# 256  1.272209                     Basal  648518346349539845
# 257  1.459688                     Basal  648518346349539845
# 258  1.855280                     Basal  648518346349539845
# 259  1.825559                     Basal  648518346349539845
#
# [125 rows x 40 columns]

# %%
# Reveal index3_right in neuroglancer

cellid_iloc = 3

list_of_cellids = unknown_dendritic_df_basal.cellid.unique()
mito = unknown_dendritic_df_basal
lookup = list_of_cellids[cellid_iloc]
queryy = index3_right #mito[mito["cellid"] == lookup]
query_listy = queryy["mito_id"].to_list()
spacer = "%22%2C%22"
query_list_joiny = spacer.join(map(str,query_listy))
baseURL = 'https://neuromancer-seung-import.appspot.com/'
nglink_a = '#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22'
nglink_b = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%22'
nglink_c = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D'
neuroglancerURL = baseURL + nglink_a + str(lookup) + nglink_b + query_list_joiny + nglink_c
# uncomment to show link: 
print(neuroglancerURL)
# Out:
# https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349539845%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%223941827%22%2C%224059787%22%2C%223496644%22%2C%223496814%22%2C%224040693%22%2C%224070614%22%2C%223496828%22%2C%224058480%22%2C%223936768%22%2C%224075025%22%2C%223949395%22%2C%223955492%22%2C%224172529%22%2C%224168259%22%2C%223496744%22%2C%223833333%22%2C%224058467%22%2C%224076917%22%2C%223713885%22%2C%223960607%22%2C%223607698%22%2C%223496331%22%2C%223709135%22%2C%223847636%22%2C%223953813%22%2C%223717384%22%2C%223496648%22%2C%224058387%22%2C%224061872%22%2C%224171321%22%2C%223720510%22%2C%224040773%22%2C%223822987%22%2C%223961936%22%2C%223721532%22%2C%223933854%22%2C%223496728%22%2C%223833910%22%2C%223933041%22%2C%223833749%22%2C%223843033%22%2C%223833739%22%2C%223831054%22%2C%223704552%22%2C%223496572%22%2C%223831214%22%2C%224048890%22%2C%223834058%22%2C%223961840%22%2C%223496556%22%2C%223967554%22%2C%224171865%22%2C%223826826%22%2C%223831057%22%2C%224092057%22%2C%223833836%22%2C%223717535%22%2C%223953546%22%2C%224059263%22%2C%224199846%22%2C%223966607%22%2C%224086642%22%2C%223966618%22%2C%224040792%22%2C%224087211%22%2C%224190863%22%2C%224058849%22%2C%223948746%22%2C%223496570%22%2C%223822218%22%2C%223722165%22%2C%223704079%22%2C%224052194%22%2C%223722223%22%2C%223950619%22%2C%223496471%22%2C%223838063%22%2C%223721119%22%2C%223843067%22%2C%223824410%22%2C%223822766%22%2C%224044162%22%2C%223822477%22%2C%223699039%22%2C%224087393%22%2C%224048786%22%2C%224168007%22%2C%224205418%22%2C%223967536%22%2C%223817730%22%2C%223496328%22%2C%223831125%22%2C%223704323%22%2C%224050856%22%2C%223956689%22%2C%224048245%22%2C%224076106%22%2C%223721249%22%2C%223831115%22%2C%224157984%22%2C%223831150%22%2C%224080725%22%2C%224058046%22%2C%223957233%22%2C%223826388%22%2C%223953165%22%2C%223708831%22%2C%224294603%22%2C%223947868%22%2C%223953792%22%2C%224189353%22%2C%224044134%22%2C%223825073%22%2C%223831031%22%2C%223831060%22%2C%223842953%22%2C%223720705%22%2C%223961237%22%2C%224048125%22%2C%224087056%22%2C%224092278%22%2C%223932008%22%2C%223820456%22%2C%223833033%22%2C%223830889%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D

# %%
index3_right_soma = index3_right[index3_right['ctr_pos_x_vx'] < 107000] # isolates the mitos that should be classified as soma
index3_right_basal = index3_right[index3_right['ctr_pos_x_vx'] >= 107000] # remaining mitos that are correctly classified as basal

# %%
len(index3_right_soma)
# Out:
# 13

# %%
np.array(index3_right_soma.mito_id.to_list())
# Out:
# array([3496644, 3496814, 3496828, 3496744, 3607698, 3496331, 3496648,
#        3496728, 3496572, 3496556, 3496570, 3496471, 3496328])

# %% [markdown]
# #### These mito ids should have been classified as soma mitos (error in original Turner et al Cell 2022 algorithm) n = 13
# 3496644, 3496814, 3496828, 3496744, 3607698, 3496331, 3496648,
# 3496728, 3496572, 3496556, 3496570, 3496471, 3496328

# %%
len(index3_right_basal)
# Out:
# 112

# %%
np.array(index3_right_basal.mito_id.to_list())
# Out:
# array([3941827, 4059787, 4040693, 4070614, 4058480, 3936768, 4075025,
#        3949395, 3955492, 4172529, 4168259, 3833333, 4058467, 4076917,
#        3713885, 3960607, 3709135, 3847636, 3953813, 3717384, 4058387,
#        4061872, 4171321, 3720510, 4040773, 3822987, 3961936, 3721532,
#        3933854, 3833910, 3933041, 3833749, 3843033, 3833739, 3831054,
#        3704552, 3831214, 4048890, 3834058, 3961840, 3967554, 4171865,
#        3826826, 3831057, 4092057, 3833836, 3717535, 3953546, 4059263,
#        4199846, 3966607, 4086642, 3966618, 4040792, 4087211, 4190863,
#        4058849, 3948746, 3822218, 3722165, 3704079, 4052194, 3722223,
#        3950619, 3838063, 3721119, 3843067, 3824410, 3822766, 4044162,
#        3822477, 3699039, 4087393, 4048786, 4168007, 4205418, 3967536,
#        3817730, 3831125, 3704323, 4050856, 3956689, 4048245, 4076106,
#        3721249, 3831115, 4157984, 3831150, 4080725, 4058046, 3957233,
#        3826388, 3953165, 3708831, 4294603, 3947868, 3953792, 4189353,
#        4044134, 3825073, 3831031, 3831060, 3842953, 3720705, 3961237,
#        4048125, 4087056, 4092278, 3932008, 3820456, 3833033, 3830889])

# %% [markdown]
# #### These mito ids were correctly classified by rfc as basal n = 112
# 3941827, 4059787, 4040693, 4070614, 4058480, 3936768, 4075025,
#        3949395, 3955492, 4172529, 4168259, 3833333, 4058467, 4076917,
#        3713885, 3960607, 3709135, 3847636, 3953813, 3717384, 4058387,
#        4061872, 4171321, 3720510, 4040773, 3822987, 3961936, 3721532,
#        3933854, 3833910, 3933041, 3833749, 3843033, 3833739, 3831054,
#        3704552, 3831214, 4048890, 3834058, 3961840, 3967554, 4171865,
#        3826826, 3831057, 4092057, 3833836, 3717535, 3953546, 4059263,
#        4199846, 3966607, 4086642, 3966618, 4040792, 4087211, 4190863,
#        4058849, 3948746, 3822218, 3722165, 3704079, 4052194, 3722223,
#        3950619, 3838063, 3721119, 3843067, 3824410, 3822766, 4044162,
#        3822477, 3699039, 4087393, 4048786, 4168007, 4205418, 3967536,
#        3817730, 3831125, 3704323, 4050856, 3956689, 4048245, 4076106,
#        3721249, 3831115, 4157984, 3831150, 4080725, 4058046, 3957233,
#        3826388, 3953165, 3708831, 4294603, 3947868, 3953792, 4189353,
#        4044134, 3825073, 3831031, 3831060, 3842953, 3720705, 3961237,
#        4048125, 4087056, 4092278, 3932008, 3820456, 3833033, 3830889

# %% [markdown]
# ### additional processing of index 12: cellid 648518346349531254;  number of mitos: 79

# %%
# analysis of index 12: cellid 648518346349531254;  number of mitos: 79
# there are two processes with a good separation at x_position = 77,500

index12_left = query[query['ctr_pos_x_vx'] < 77500] # This looks like the apical dendrite
index12_right = query[query['ctr_pos_x_vx'] >= 77500] # This looks like a basal dendrite

# %%
# This cellid 648518346349531254 is index 11 in the withincone45 analysis

# there are two processes with a good separation at x_position = 77,500

index11_left = query[query['ctr_pos_x_vx'] < 77500] # This looks like the apical dendrite
index11_right = query[query['ctr_pos_x_vx'] >= 77500] # This looks like a basal dendrite

# %%
len(index11_left)
# Out:
# 19

# %%
len(index11_right)
# Out:
# 53

# %%
# These should be assigned apical (the rfc classifier was incorrect) n = 24
np.array(index11_left.mito_id.to_list())
# Out:
# array([1768668, 1773075, 1189911, 1778442, 1650211, 1778402, 1301533,
#        1891420, 1190204, 1772953, 1300841, 1299977, 1767137, 1648586,
#        1891196, 1648967, 1777820, 1533066, 1417199])

# %%
index11_left.mito_id.to_list()
# Out:
# [1768668,
#  1773075,
#  1189911,
#  1778442,
#  1650211,
#  1778402,
#  1301533,
#  1891420,
#  1190204,
#  1772953,
#  1300841,
#  1299977,
#  1767137,
#  1648586,
#  1891196,
#  1648967,
#  1777820,
#  1533066,
#  1417199]

# %%
# These should be assigned basal (the rfc classifier was correct) n = 55
np.array(index11_right.mito_id.to_list())
# Out:
# array([3591662, 2245089, 3481010, 2243067, 3591624, 3481657, 2131044,
#        2484183, 2243516, 2359891, 2359574, 2361621, 2131052, 2243340,
#        2372677, 2372434, 2706882, 2825268, 2591923, 2243111, 2131054,
#        2130989, 2246789, 3263377, 2238180, 2232805, 2598246, 2130947,
#        2246159, 2245034, 2238455, 2010839, 2245938, 2608611, 2238315,
#        2728528, 2127971, 2251186, 2478162, 2130782, 2824951, 3370551,
#        2246163, 2251264, 3369210, 2607782, 2245148, 3153590, 2128360,
#        2245823, 2705507, 2475672, 2244740])

# %%
# reveal "left" apical or "right" basal dendrite for index 11 in neuroglancer 

cellid_iloc = 11

list_of_cellids = unknown_dendritic_df_basal.cellid.unique()
mito = unknown_dendritic_df_basal
lookup = list_of_cellids[cellid_iloc]
queryy = index11_right #mito[mito["cellid"] == lookup]
query_listy = queryy["mito_id"].to_list()
spacer = "%22%2C%22"
query_list_joiny = spacer.join(map(str,query_listy))
baseURL = 'https://neuromancer-seung-import.appspot.com/'
nglink_a = '#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22'
nglink_b = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%22'
nglink_c = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D'
neuroglancerURL = baseURL + nglink_a + str(lookup) + nglink_b + query_list_joiny + nglink_c
# uncomment to show link: 
print(neuroglancerURL)
# Out:
# https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349531254%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%223591662%22%2C%222245089%22%2C%223481010%22%2C%222243067%22%2C%223591624%22%2C%223481657%22%2C%222131044%22%2C%222484183%22%2C%222243516%22%2C%222359891%22%2C%222359574%22%2C%222361621%22%2C%222131052%22%2C%222243340%22%2C%222372677%22%2C%222372434%22%2C%222706882%22%2C%222825268%22%2C%222591923%22%2C%222243111%22%2C%222131054%22%2C%222130989%22%2C%222246789%22%2C%223263377%22%2C%222238180%22%2C%222232805%22%2C%222598246%22%2C%222130947%22%2C%222246159%22%2C%222245034%22%2C%222238455%22%2C%222010839%22%2C%222245938%22%2C%222608611%22%2C%222238315%22%2C%222728528%22%2C%222127971%22%2C%222251186%22%2C%222478162%22%2C%222130782%22%2C%222824951%22%2C%223370551%22%2C%222246163%22%2C%222251264%22%2C%223369210%22%2C%222607782%22%2C%222245148%22%2C%223153590%22%2C%222128360%22%2C%222245823%22%2C%222705507%22%2C%222475672%22%2C%222244740%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D

# %% [markdown]
# ### Additional processing of index 21: cellid 648518346349538235; number of mitos: 86
# Same separation point as index 12!
# See in [Neuroglancer](https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22colorSeed%22:1278570284%2C%22segments%22:%5B%22648518346349531254%22%2C%22648518346349538235%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22colorSeed%22:4131854015%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22colorSeed%22:3080909682%2C%22segments%22:%5B%221085740%22%2C%221200700%22%2C%221294492%22%2C%221301081%22%2C%221313348%22%2C%221423267%22%2C%221426237%22%2C%221427492%22%2C%221427974%22%2C%221429058%22%2C%221429169%22%2C%221430191%22%2C%221430283%22%2C%221430335%22%2C%221430744%22%2C%221548754%22%2C%221548987%22%2C%221549392%22%2C%221550799%22%2C%221664841%22%2C%221665919%22%2C%221670409%22%2C%221671421%22%2C%221671612%22%2C%221671719%22%2C%221783920%22%2C%221784076%22%2C%221788475%22%2C%221789310%22%2C%221789919%22%2C%222127620%22%2C%222131721%22%2C%222131795%22%2C%222132502%22%2C%222132530%22%2C%222135945%22%2C%222137607%22%2C%222137636%22%2C%222239853%22%2C%222249587%22%2C%222249873%22%2C%222249960%22%2C%222250108%22%2C%222250317%22%2C%222250463%22%2C%222254075%22%2C%222254127%22%2C%222254137%22%2C%222254503%22%2C%222254649%22%2C%222254817%22%2C%222355422%22%2C%222361375%22%2C%222361537%22%2C%222364459%22%2C%222366385%22%2C%222367180%22%2C%222368012%22%2C%222472501%22%2C%222480439%22%2C%222480572%22%2C%222481723%22%2C%222590705%22%2C%222591330%22%2C%222591502%22%2C%222594972%22%2C%222705414%22%2C%222706638%22%2C%222711495%22%2C%222828667%22%2C%222940168%22%2C%223157827%22%2C%223158855%22%2C%223376180%22%2C%223489544%22%2C%223600599%22%2C%223714251%22%2C%22545202%22%2C%22546333%22%2C%22649815%22%2C%22745428%22%2C%22745743%22%2C%22746186%22%2C%22854181%22%2C%22867111%22%2C%22974567%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22colorSeed%22:3424028769%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B77527.8671875%2C48919.4453125%2C750.2664184570312%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:1809.3829974256712%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22cell_segmentation_v185%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D) how these two neurons are close to one another

# %%
# analysis of index 21: cellid 648518346349538235; number of mitos: 86
# there are two processes with a good separation at x_position = 77,500
# Coincidentally, the same separation point as index 12!
# This one is tough to call; I picked the "right" side as the apical dendrite due to more vertical orientation, slightly larger diameter, and slightly shorter mitos than the putative basal dendrite on the "left"

index21_left = query[query['ctr_pos_x_vx'] < 77500] # I'm assigning this as a basal dendrite
index21_right = query[query['ctr_pos_x_vx'] >= 77500] # I'm assigning this as the apical dendrite

# %%
len(# there are two processes with a good separation at x_position = 77,500
# Coincidentally, the same separation point as index 12!
# This one is tough to call; I picked the "right" side as the apical dendrite due to more vertical orientation, slightly larger diameter, and slightly shorter mitos than the putative basal dendrite on the "left"

index21_left = query[query['ctr_pos_x_vx'] < 77500] # I'm assigning this as a basal dendrite
index21_right = query[query['ctr_pos_x_vx'] >= 77500] # I'm assigning this as the apical dendrite)
# Out:
#   File "C:\Users\drhan\AppData\Local\Temp\ipykernel_17556\3604461829.py", line 6
#     index21_right = query[query['ctr_pos_x_vx'] >= 77500] # I'm assigning this as the apical dendrite)
#                 ^
# SyntaxError: invalid syntax

# %%
# in withincone45 this is index 20
# there are two processes with a good separation at x_position = 77,500
# Coincidentally, the same separation point as index 12!
# This one is tough to call; I picked the "right" side as the apical dendrite due to more vertical orientation, slightly larger diameter, and slightly shorter mitos than the putative basal dendrite on the "left"

index20_left = query[query['ctr_pos_x_vx'] < 77500] # I'm assigning this as a basal dendrite
index20_right = query[query['ctr_pos_x_vx'] >= 77500] # I'm assigning this as the apical dendrite

# %%
len(index20_left)
# Out:
# 40

# %%
print(index20_left.mito_id.to_list())
# Out:
# [1085740, 1426237, 1430335, 1784076, 1550799, 1783920, 546333, 1788475, 1548987, 1789919, 745428, 854181, 745743, 1294492, 1430283, 1313348, 1671612, 746186, 1789310, 1427974, 974567, 1671421, 1429058, 1427492, 1429169, 1423267, 1548754, 649815, 746709, 1430744, 1301081, 1430191, 867111, 1671719, 1665919, 1549392, 545202, 1200700, 1670409, 1664841]

# %%
index20_left.mito_id.to_list()
# Out:
# [1085740,
#  1426237,
#  1430335,
#  1784076,
#  1550799,
#  1783920,
#  546333,
#  1788475,
#  1548987,
#  1789919,
#  745428,
#  854181,
#  745743,
#  1294492,
#  1430283,
#  1313348,
#  1671612,
#  746186,
#  1789310,
#  1427974,
#  974567,
#  1671421,
#  1429058,
#  1427492,
#  1429169,
#  1423267,
#  1548754,
#  649815,
#  746709,
#  1430744,
#  1301081,
#  1430191,
#  867111,
#  1671719,
#  1665919,
#  1549392,
#  545202,
#  1200700,
#  1670409,
#  1664841]

# %%
len(index20_right)
# Out:
# 21

# %%
print(index20_right.mito_id.to_list())
# Out:
# [2364459, 3376180, 2711495, 3489544, 2361537, 2706638, 2591502, 3157827, 2940168, 2480439, 2591330, 3158855, 3714251, 2705414, 2590705, 2361375, 3600599, 2828667, 2366385, 2480572, 2594972]

# %%
# visualize index20 in neuroglancer for the "left" basal dendrite and "right" apical dendrite

cellid_iloc = 20

list_of_cellids = unknown_dendritic_df_basal.cellid.unique()
mito = unknown_dendritic_df_basal
lookup = list_of_cellids[cellid_iloc]
queryy = index20_right #mito[mito["cellid"] == lookup]
query_listy = queryy["mito_id"].to_list()
spacer = "%22%2C%22"
query_list_joiny = spacer.join(map(str,query_listy))
baseURL = 'https://neuromancer-seung-import.appspot.com/'
nglink_a = '#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22'
nglink_b = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%22'
nglink_c = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D'
neuroglancerURL = baseURL + nglink_a + str(lookup) + nglink_b + query_list_joiny + nglink_c
# uncomment to show link: 
print(neuroglancerURL)
# Out:
# https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.15%2C%22segments%22:%5B%22648518346349538235%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%222364459%22%2C%223376180%22%2C%222711495%22%2C%223489544%22%2C%222361537%22%2C%222706638%22%2C%222591502%22%2C%223157827%22%2C%222940168%22%2C%222480439%22%2C%222591330%22%2C%223158855%22%2C%223714251%22%2C%222705414%22%2C%222590705%22%2C%222361375%22%2C%223600599%22%2C%222828667%22%2C%222366385%22%2C%222480572%22%2C%222594972%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B83222.921875%2C52981.34765625%2C824.9962768554688%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:3618.7659948513424%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D

# %%
# These should be assigned basal (the rfc classifier was correct) n = 39
np.array(index12_left.mito_id.to_list())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21684\3091992986.py in <module>
#       1 # These should be assigned basal (the rfc classifier was correct) n = 39
# ----> 2 np.array(index12_left.mito_id.to_list())
#
# NameError: name 'index12_left' is not defined

# %%
# These should be assigned apical (the rfc classifier was incorrect) n = 47
np.array(index12_left.mito_id.to_list())
# Out:
# array([1768668, 1890582, 1773075, 1189911, 1885913, 1778442, 1650211,
#        2010407, 1778402, 1301533, 1891420, 1190204, 1772953, 1891080,
#        1300841, 1299977, 1767137, 1648586, 1891196, 1886041, 1648967,
#        1777820, 1533066, 1417199])

# %% [markdown]
# # Summary of rfc for basal assignments
# ### Classified as basal and human inspection confirms basal assignment: 521+112+55+39 = 727
# - index 3: 112 mitos were correctly classified as basal
# - index 12: 55 mitos were correctly classified as basal
# - index 21: 39 mitos were correctly classified as basal
#
# ### Classified as basal and should have been classified as apical: 33 +46+24+47 = 150
# - index 3: 46 mitos should have been classified as apical
# - index 12: 24 mitos should have been classified as apical
# - index 21: 47 mitos should have been classified as apical
#
# ### Edge of volume neurons that can't be determined and should remain as unknown dendrite: 161
#
# ### Human inspection showed that the original classification by Turner et al was incorrect: 16+22+13 = 51
# - 16 mitos from index 5 are axon (and should not have been in the unknown dendrite category):
# - 22 mitos from index 6 and 17 should be reassigned to unknown compartment since these could be either axon or dendrite
# - 13 mitos from index 3 should have been classified as soma in the original Turner dataset
#
# ### Total: 727+150+161+51 = 1089
# All basal assignments accounted for!
#
# ## Accuracy of rfc for basal assignments
# - 727/1089 (0.6676) were correctly assigned as basal
# - 150/1089 (0.1377) were assigned basal and should have been assigned apical
# - 161/1089 (0.1478) were assigned as basal but the assignment cannot be verified due to edge problem
# - 51/1089 (0.0468) were assigned as basal but the original dataset assignment was incorrect to begin with
#
# ## Aggregate
# - 727/1089 (0.668) correct
# - 150+161+51/1089 = (1-0.668) = 0.332 incorrect

# %% [markdown]
# # Summary of apical and basal assignment accuracy by rfc
# Round 1
#
# ## Apical
# - 11/48 (0.229) classified as apical were true apical upon manual validation
# - 37/48 (0.771) classified as apical were actually basal dendrites as determined by manual inspection
#
# ## Basal
# - 727/1089 (0.668) classified as basal were true basal upon manual validation
# - 362/1089 = (1-0.668) = 0.332 classified as basal were actually other assignments (apical, axon, soma, unknown, or should remain unknown dendrite)
#
# # Overall accuracy of Random Forest Classifier (rfc)
# ## Correct assignments: 11+727 = 738/1137 (0.649)
# ## Incorrect assignments: 37+362 = 399/1137 (0.351)
# totals: 48+1089 = 1137
#
# # Overall accuracy of Random Forest Classifier (rfc)
# - Correct assignments:   738/1137 (0.649)
# - Incorrect assignments: 399/1137 (0.351)

# %% [markdown]
# ### Reveal in Neuroglancer one mito at a time

# %%
baseURL = 'https://neuromancer-seung-import.appspot.com/'
nglink_a = '#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.1%2C%22segments%22:%5B%22'
nglink_b = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%2C%22visible%22:false%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%22'
nglink_c = '%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%2C%22visible%22:false%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B'
nglink_d = '%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:904.6914987128356%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D'

# %%
iloc_value = 0

# %%
mito_id_lookup = unknown_dendritic_df.mito_id[iloc_value]
mito_id_lookup
# Out:
# 1547760

# %%
# match var name with my neuroglancer code
mito = unknown_dendritic_df

# %%
mito_id_query = mito["mito_id"] == mito_id_lookup
mito_id_query = mito[mito_id_query]
mito_id_query
# Out:
#    mito_id  mito_vx  ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  bbox_beg_x_vx  \
# 0  1547760   211468         70706         45080          1364          70248
#
#    bbox_beg_y_vx  bbox_beg_z_vx  bbox_end_x_vx  bbox_end_y_vx  bbox_end_z_vx  \
# 0          44874           1328          71030          45284           1393
#
#                cellid  ctr_pos_x_nm  ctr_pos_y_nm  ctr_pos_z_nm  surface_area  \
# 0  648518346349523993        282824        180320         54560       2.71677
#
#    complexityindex        compartment  centroid_x  centroid_y  centroid_z  \
# 0        10.804325  Unknown dendritic       70864       42368          24
#
#    ctr_distance_to_soma  bbox_dir_x  bbox_dir_y  bbox_dir_z  bbox_distance  \
# 0             3029.1101        -782        -410         -65     885.352472
#
#    above_soma  within_threshold_1500  count         mean          std  min  \
# 0           0                      0  196.0  6307.454632  5294.853299  0.0
#
#            25%          50%          75%           max  kurtosis      skew  \
# 0  2791.498779  4378.841631  8158.576625  26607.713618  5.541097  2.220513
#
#   rfc_predicted_compartment          cellid_str
# 0                     Basal  648518346349523993

# %%
cellid_of_interest = mito_id_query["cellid"].to_string(index=False)
mitoid_of_interest = mito_id_query["mito_id"].to_string(index=False)
mito_ctr_pos_x_vx = mito_id_query["ctr_pos_x_vx"].to_string(index=False)
mito_ctr_pos_y_vx = mito_id_query["ctr_pos_y_vx"].to_string(index=False)
mito_ctr_pos_z_vx = mito_id_query["ctr_pos_z_vx"].to_string(index=False)

# %%
cellid_of_interest
# Out:
# '648518346349523993'

# %%
neuroglancerURL = baseURL + nglink_a + str(cellid_of_interest) + nglink_b + str(mitoid_of_interest) + nglink_c + str(mito_ctr_pos_x_vx) + '%2C' + str(mito_ctr_pos_y_vx) + '%2C' + str(mito_ctr_pos_z_vx) + nglink_d

# %%
print(neuroglancerURL)
# Out:
# https://neuromancer-seung-import.appspot.com/#!%7B%22layers%22:%5B%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v0/son_of_alignment_v15_rechunked%22%2C%22type%22:%22image%22%2C%22blend%22:%22default%22%2C%22shaderControls%22:%7B%7D%2C%22name%22:%22EM%22%7D%2C%7B%22source%22:%22precomputed://gs://microns_public_datasets/pinky100_v185/seg%22%2C%22type%22:%22segmentation%22%2C%22selectedAlpha%22:0.51%2C%22objectAlpha%22:0.1%2C%22segments%22:%5B%22648518346349523993%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22cell_segmentation_v185%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-clefts/mip1_d2_1175k%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22synapses%22%2C%22visible%22:false%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-mito/seg_191220%22%2C%22type%22:%22segmentation%22%2C%22segments%22:%5B%221547760%22%5D%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22mitochondria%22%7D%2C%7B%22source%22:%22precomputed://matrix://sseung-archive/pinky100-nuclei/seg%22%2C%22type%22:%22segmentation%22%2C%22skeletonRendering%22:%7B%22mode2d%22:%22lines_and_points%22%2C%22mode3d%22:%22lines%22%7D%2C%22name%22:%22nuclei%22%2C%22visible%22:false%7D%5D%2C%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4%2C4%2C40%5D%2C%22voxelCoordinates%22:%5B70706%2C45080%2C1364%5D%7D%7D%2C%22zoomFactor%22:383.0066650796121%7D%2C%22perspectiveOrientation%22:%5B-0.00825042650103569%2C0.06130112707614899%2C-0.0012821174459531903%2C0.9980843663215637%5D%2C%22perspectiveZoom%22:904.6914987128356%2C%22showSlices%22:false%2C%22selectedLayer%22:%7B%22layer%22:%22mitochondria%22%2C%22visible%22:true%7D%2C%22layout%22:%7B%22type%22:%223d%22%2C%22orthographicProjection%22:true%7D%7D
