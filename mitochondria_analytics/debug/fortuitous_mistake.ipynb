# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# %%
pd.set_option('display.max_columns', None)

# %%
pyr_four = pd.read_csv('pyr_four_nostr.csv', index_col=[0])

# %%
# note: no normalization has been applied
pyr_four
# Out:
#         mito_id  mito_vx  ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  \
# 0       1783325   527936         75186         43844          1430
# 1       1780086  1597632         75086         43678          1032
# 2       2026719   141924         79378         47892           742
# 3       1540216     2780         69738         42838            21
# 5       2633343   363328         89636         57886           961
# ...         ...      ...           ...           ...           ...
# 210970  1649818   287444         72610         37220          2135
# 210971  2397704   336092         84174         56050          1975
# 210972  1667802   337984         72740         46280          1200
# 210973  1654227   495816         72104         39630          1908
# 210974  1088579  1012668         61868         43872           755
#
#         bbox_beg_x_vx  bbox_beg_y_vx  bbox_beg_z_vx  bbox_end_x_vx  \
# 0               74824          43668           1323          75472
# ...

# %% [markdown]
# # From Jose Portilla Machine Learning Course (Udemy)

# %% [markdown]
# # Train test split

# %%
X = pyr_four.drop('compartment',axis=1)
y = pyr_four['compartment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# # Decision Tree

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# removed presort argument which caused an error
dtree.fit(X_train,y_train)
dtree.fit(X_train,y_train)
DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
            max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            random_state=None, splitter='best')
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Prediction and evaluation

# %%
predictions = dtree.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#       Apical       0.78      0.79      0.78      5869
#       Axonal       0.73      0.73      0.73      3783
#        Basal       0.85      0.84      0.84     16513
#      Somatic       0.96      0.96      0.96     28107
#
#     accuracy                           0.89     54272
#    macro avg       0.83      0.83      0.83     54272
# weighted avg       0.89      0.89      0.89     54272

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[ 4625    74   940   230]
#  [   62  2775   802   144]
#  [ 1024   777 13909   803]
#  [  222   159   794 26932]]

# %% [markdown]
# # Random forests

# %%
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[ 4656    17   984   212]
#  [   44  2944   667   128]
#  [  693   440 14715   665]
#  [   44    11   338 27714]]

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Apical       0.86      0.79      0.82      5869
#       Axonal       0.86      0.78      0.82      3783
#        Basal       0.88      0.89      0.89     16513
#      Somatic       0.97      0.99      0.98     28107
#
#     accuracy                           0.92     54272
#    macro avg       0.89      0.86      0.88     54272
# weighted avg       0.92      0.92      0.92     54272

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Apical       0.86      0.79      0.82      5869
#       Axonal       0.86      0.78      0.82      3783
#        Basal       0.88      0.89      0.89     16513
#      Somatic       0.97      0.99      0.98     28107
#
#     accuracy                           0.92     54272
#    macro avg       0.89      0.86      0.88     54272
# weighted avg       0.92      0.92      0.92     54272

# %% [markdown]
# # I thought that I was re-running with the mito to mito stats but I didn't actually update the df name, so it re-ran the analysis again with the original df. However, the results of the running the random forest again now returned very high success rates

# %%
# I loaded the new df but forgot to update the df name in the following cell
pyr_four_nostr_mmstats = pd.read_csv('pyr_four_nostr_mmstats.csv', index_col=[0])
pyr_four_nostr_mmstats
# Out:
#         mito_id  mito_vx  ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  \
# 0       1783325   527936         75186         43844          1430
# 1       1780086  1597632         75086         43678          1032
# 2       2026719   141924         79378         47892           742
# 3       1540216     2780         69738         42838            21
# 4       2633343   363328         89636         57886           961
# ...         ...      ...           ...           ...           ...
# 180899  1649818   287444         72610         37220          2135
# 180900  2397704   336092         84174         56050          1975
# 180901  1667802   337984         72740         46280          1200
# 180902  1654227   495816         72104         39630          1908
# 180903  1088579  1012668         61868         43872           755
#
#         bbox_beg_x_vx  bbox_beg_y_vx  bbox_beg_z_vx  bbox_end_x_vx  \
# 0               74824          43668           1323          75472
# ...

# %% [markdown]
# # Train test split

# %%
# here's where I made the mistake of not updating the df name; it still has the original one
X = pyr_four.drop('compartment',axis=1)
y = pyr_four['compartment']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %% [markdown]
# # Decision tree

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)
dtree.fit(X_train,y_train)
DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
            max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            random_state=None, splitter='best')
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Predictions and evaluation

# %%
predictions = dtree.predict(X_test)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#       Apical       0.78      0.79      0.78      5921
#       Axonal       0.71      0.73      0.72      3678
#        Basal       0.84      0.84      0.84     16377
#      Somatic       0.96      0.96      0.96     28296
#
#     accuracy                           0.89     54272
#    macro avg       0.82      0.83      0.83     54272
# weighted avg       0.89      0.89      0.89     54272

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[ 4664    82   957   218]
#  [   67  2668   818   125]
#  [ 1016   844 13747   770]
#  [  219   166   835 27076]]

# %% [markdown]
# # Random forests

# %% [markdown]
# # Here's what the difference was: I didn't reset the rfc here. rfc here is using the rfc df from the first run.
#
# # I was supposed to add the following, but missed it, and as a result, rfc was the first run got used when running these cells for the second time
#
# rfc = RandomForestClassifier(n_estimators=100)
# rfc.fit(X_train, y_train)
#
# # If I would have included these lines here, it would have reset rfc to a new state.

# %%
rfc_pred = rfc.predict(X_test)
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[ 5568     5   294    54]
#  [    9  3441   189    39]
#  [  214   126 15852   185]
#  [   15     1   102 28178]]

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Apical       0.96      0.94      0.95      5921
#       Axonal       0.96      0.94      0.95      3678
#        Basal       0.96      0.97      0.97     16377
#      Somatic       0.99      1.00      0.99     28296
#
#     accuracy                           0.98     54272
#    macro avg       0.97      0.96      0.96     54272
# weighted avg       0.98      0.98      0.98     54272
