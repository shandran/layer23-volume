# %%
import pandas as pd

# %%
pyr = pd.read_csv("mitos_bycelltype_vectoranalysis_nodecount_pyr.csv", index_col=[0])
pyr
# Out:
#         mito_id  mito_vx  ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  \
# 0       1783325   527936         75186         43844          1430
# 1       1780086  1597632         75086         43678          1032
# 2       2026719   141924         79378         47892           742
# 3       1540216     2780         69738         42838            21
# 4       1547760   211468         70706         45080          1364
# ...         ...      ...           ...           ...           ...
# 183658  1649818   287444         72610         37220          2135
# 183659  2397704   336092         84174         56050          1975
# 183660  1667802   337984         72740         46280          1200
# 183661  1654227   495816         72104         39630          1908
# 183662  1088579  1012668         61868         43872           755
#
#         bbox_beg_x_vx  bbox_beg_y_vx  bbox_beg_z_vx  bbox_end_x_vx  \
# 0               74824          43668           1323          75472
# ...

# %%
pyr_train = pyr[pyr["compartment"] != "Unknown"]
pyr_train
# Out:
#         mito_id  mito_vx  ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  \
# 0       1783325   527936         75186         43844          1430
# 1       1780086  1597632         75086         43678          1032
# 2       2026719   141924         79378         47892           742
# 3       1540216     2780         69738         42838            21
# 4       1547760   211468         70706         45080          1364
# ...         ...      ...           ...           ...           ...
# 183658  1649818   287444         72610         37220          2135
# 183659  2397704   336092         84174         56050          1975
# 183660  1667802   337984         72740         46280          1200
# 183661  1654227   495816         72104         39630          1908
# 183662  1088579  1012668         61868         43872           755
#
#         bbox_beg_x_vx  bbox_beg_y_vx  bbox_beg_z_vx  bbox_end_x_vx  \
# 0               74824          43668           1323          75472
# ...

# %%
pyr_test = pyr[pyr["compartment"] == "Unknown"]
pyr_test
# Out:
#         mito_id  mito_vx  ctr_pos_x_vx  ctr_pos_y_vx  ctr_pos_z_vx  \
# 297     3191325   767412        100166         57548           234
# 542     3619521    43256        107044         54324           561
# 628     3404013    73876        102152         58418           172
# 654     3514532    86576        103894         58752           338
# 933     1796033   519668         74530         51448          2130
# ...         ...      ...           ...           ...           ...
# 181883  3828189    58704        111978         46112           348
# 182090  3947961   150188        112444         49214           426
# 182297  1653993   305840         73002         40588          1964
# 182943  3325821   102964        101750         70528           822
# 183619  1417127   123724         67454         37066          2033
#
#         bbox_beg_x_vx  bbox_beg_y_vx  bbox_beg_z_vx  bbox_end_x_vx  \
# 297             99640          57242            200         100470
# ...
